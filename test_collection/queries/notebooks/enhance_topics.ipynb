# %% [markdown]
# # Erweitern der Suchanfragen
#
# Originale Suchanfragen werden zu Freitext formuliert. Für beide Varianten (Original & Freitext) wird zusätzlich eine Synonym-Version erzeugt.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
RAW_DATA_PATH = "drive/MyDrive/Uni/Master/Masterthesis/Data/raw_data/"
PROD_DATA_PATH = "drive/MyDrive/Uni/Master/Masterthesis/Data/topics/"

# %%
import pandas as pd

# %%
import json

# Build file path for test collection.
file_path = PROD_DATA_PATH + "suchanfragen_testkollektion.json"

# Load raw query test collection from JSON.
with open(file_path, "r", encoding="utf-8") as f:
    raw_queries_testcollection = json.load(f)

# Basic structural validation.
print(type(raw_queries_testcollection))  # Expected: list or dict
print(len(raw_queries_testcollection))   # Number of entries
print(raw_queries_testcollection)        # Full content (use cautiously for large files)
# Out:
# <class 'list'>
# 11
# [{'id': 'c0', 'cluster': 'cluster_0', 'topic': 'IT-Management und Wissensmanagement', 'single': [{'id': 'c0_1_single', 'keyword': 'IT-Systemadministration', 'variations': [{'id': 'c0_1_single_keyword', 'query': 'IT-Systemadministration', 'type': 'single_keyword'}]}, {'id': 'c0_2_single', 'keyword': 'Information Technology', 'variations': [{'id': 'c0_2_single_keyword', 'query': 'Information Technology', 'type': 'single_keyword'}]}, {'id': 'c0_3_single', 'keyword': 'Wissensmanagement', 'variations': [{'id': 'c0_3_single_keyword', 'query': 'Wissensmanagement', 'type': 'single_keyword'}]}], 'combination': []}, {'id': 'c1', 'cluster': 'cluster_1', 'topic': 'Mechanik-, Elektro- und Automatisierungstechnik', 'single': [{'id': 'c1_1_single', 'keyword': 'Konstruktion', 'variations': [{'id': 'c1_1_single_keyword', 'query': 'Konstruktion', 'type': 'single_keyword'}]}, {'id': 'c1_2_single', 'keyword': 'Metallhandwerk', 'variations': [{'id': 'c1_2_single_keyword', 'query': 'Metallhandwerk', 'type': 'single_keyword'}]}, {'id': 'c1_3_single', 'keyword': 'Mechanik', 'variations': [{'id': 'c1_3_single_keyword', 'query': 'Mechanik', 'type': 'single_keyword'}]}, {'id': 'c1_4_single', 'keyword': 'Automatisierungstechnik', 'variations': [{'id': 'c1_4_single_keyword', 'query': 'Automatisierungstechnik', 'type': 'single_keyword'}]}, {'id': 'c1_5_single', 'keyword': 'Elektrotechnik', 'variations': [{'id': 'c1_5_single_keyword', 'query': 'Elektrotechnik', 'type': 'single_keyword'}]}], 'combination': [{'id': 'c1_1_combination', 'keywords': ['Konstruktion', 'Metallhandwerk'], 'variations': [{'id': 'c1_1_combination_keyword', 'query': 'Konstruktion, Metallhandwerk', 'type': 'combination_keyword'}]}, {'id': 'c1_2_combination', 'keywords': ['Mechanik', 'Elektrotechnik'], 'variations': [{'id': 'c1_2_combination_keyword', 'query': 'Mechanik, Elektrotechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_3_combination', 'keywords': ['Metallhandwerk', 'Mechanik'], 'variations': [{'id': 'c1_3_combination_keyword', 'query': 'Metallhandwerk, Mechanik', 'type': 'combination_keyword'}]}, {'id': 'c1_4_combination', 'keywords': ['Metallhandwerk', 'Elektrotechnik'], 'variations': [{'id': 'c1_4_combination_keyword', 'query': 'Metallhandwerk, Elektrotechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_5_combination', 'keywords': ['Mechanik', 'Automatisierungstechnik'], 'variations': [{'id': 'c1_5_combination_keyword', 'query': 'Mechanik, Automatisierungstechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_6_combination', 'keywords': ['Automatisierungstechnik', 'Elektrotechnik'], 'variations': [{'id': 'c1_6_combination_keyword', 'query': 'Automatisierungstechnik, Elektrotechnik', 'type': 'combination_keyword'}]}]}, {'id': 'c3', 'cluster': 'cluster_3', 'topic': 'Künstliche Intelligenz', 'single': [{'id': 'c3_1_single', 'keyword': 'KI', 'variations': [{'id': 'c3_1_single_keyword', 'query': 'KI', 'type': 'single_keyword'}]}], 'combination': []}, {'id': 'c5', 'cluster': 'cluster_5', 'topic': 'Verkauf, Kommunikation und Marketing', 'single': [{'id': 'c5_1_single', 'keyword': 'Public Relations', 'variations': [{'id': 'c5_1_single_keyword', 'query': 'Public Relations', 'type': 'single_keyword'}]}, {'id': 'c5_2_single', 'keyword': 'Sales', 'variations': [{'id': 'c5_2_single_keyword', 'query': 'Sales', 'type': 'single_keyword'}]}, {'id': 'c5_3_single', 'keyword': 'Social Media Marketing', 'variations': [{'id': 'c5_3_single_keyword', 'query': 'Social Media Marketing', 'type': 'single_keyword'}]}], 'combination': [{'id': 'c5_1_combination', 'keywords': ['Public Relations', 'Social Media Marketing'], 'variations': [{'id': 'c5_1_combination_keyword', 'query': 'Public Relations, Social Media Marketing', 'type': 'combination_keyword'}]}]}, {'id': 'c6', 'cluster': 'cluster_6', 'topic': 'Digitales Marketing und Markenkommunikation', 'single': [{'id': 'c6_1_single', 'keyword': 'Marketing', 'variations': [{'id': 'c6_1_single_keyword', 'query': 'Marketing', 'type': 'single_keyword'}]}, { ...

# %%
# Initialize global counters.
total_singles = 0
total_combinations = 0

# Iterate over clusters in test collection.
for cluster in raw_queries_testcollection:

    # Count variations for single-term queries.
    single_count = sum(
        len(s.get("variations", []))
        for s in cluster["single"]
    )

    # Count variations for combination queries.
    comb_count = sum(
        len(c.get("variations", []))
        for c in cluster["combination"]
    )

    # Aggregate totals.
    total_singles += single_count
    total_combinations += comb_count

    # Print per-cluster summary.
    print(
        cluster["id"],
        "| topic:", cluster["topic"],
        "| single_queries:", single_count,
        "| combination_queries:", comb_count,
        "| total:", single_count + comb_count,
    )

# Print overall totals across all clusters.
print("\n--- Gesamtzahlen über alle Cluster hinweg ---")
print("Total Single Variations:", total_singles)
print("Total Combination Variations:", total_combinations)
print("Total Queries:", total_singles + total_combinations)
# Out:
# c0 | topic: IT-Management und Wissensmanagement | single_queries: 3 | combination_queries: 0 | total: 3
# c1 | topic: Mechanik-, Elektro- und Automatisierungstechnik | single_queries: 5 | combination_queries: 6 | total: 11
# c3 | topic: Künstliche Intelligenz | single_queries: 1 | combination_queries: 0 | total: 1
# c5 | topic: Verkauf, Kommunikation und Marketing | single_queries: 3 | combination_queries: 1 | total: 4
# c6 | topic: Digitales Marketing und Markenkommunikation | single_queries: 2 | combination_queries: 3 | total: 5
# c7 | topic: Personal- und Organisationsentwicklung | single_queries: 4 | combination_queries: 10 | total: 14
# c8 | topic: Bau- und Handwerkstechnik | single_queries: 3 | combination_queries: 1 | total: 4
# c10 | topic: Finanzmanagement und Unternehmensplanung | single_queries: 3 | combination_queries: 10 | total: 13
# c11 | topic: Strategische Unternehmensführung und Veränderungsmanagement | single_queries: 3 | combination_queries: 5 | total: 8
# c12 | topic: Digitales Management und IT-Systeme | single_queries: 5 | combination_queries: 8 | total: 13
# c13 | topic: Digitale Transformations- und Innovationsstrategie | single_queries: 3 | combination_queries: 5 | total: 8
#
# --- Gesamtzahlen über alle Cluster hinweg ---
# Total Single Variations: 35
# Total Combination Variations: 49
# Total Queries: 84

# %% [markdown]
# ## Hinzufügen von Freitext-Anfragen

# %%
ENHANCED_DATA = PROD_DATA_PATH + "suchanfragen_testkollektion_freetext.json"

# %%
def make_freetext_variation(base_variation, freetext: str):
    # Extract original variation ID and normalize suffix.
    id = base_variation["id"]
    base_id = id.replace("_keyword", "")

    # Extract original type and normalize suffix.
    typ = base_variation["type"]
    base_type = typ.replace("_keyword", "")

    # Return freetext-based variation with adjusted ID and type.
    return {
        "id": base_id + "_freetext",
        "query": freetext,
        "type": base_type + "_free",
    }

# %%
from copy import deepcopy
from tqdm import tqdm

# Create deep copy to avoid mutating original test collection.
queries_with_freetext = deepcopy(raw_queries_testcollection)

print(queries_with_freetext)

# Iterate over clusters and extend with freetext variations.
for cluster in tqdm(queries_with_freetext, desc="Add Freetext"):

    # ---------- SINGLE ----------
    for single in cluster["single"]:
        keyword = single["keyword"]

        # Build simple freetext formulation for single keyword.
        freetext = f"Gesucht wird ein Experte mit Fähigkeiten im Bereich {keyword}"

        # Add exactly one freetext variation per keyword (based on keyword baseline).
        for var in single["variations"]:
            if var["type"] == "single_keyword":
                new_var = make_freetext_variation(var, freetext)
                single["variations"].append(new_var)
                break  # ensure only one freetext variation per keyword

    # ---------- COMBINATION ----------
    for comb in cluster["combination"]:
        keywords = comb["keywords"]  # e.g. ["Public Relations", "Social Media Marketing"]

        # Build freetext query for two-keyword combination.
        freetext = (
            f"Gesucht wird ein Experte mit Fähigkeiten in den Bereichen "
            f"{keywords[0]} und {keywords[1]}"
        )

        # Add exactly one freetext variation per combination (based on keyword baseline).
        for var in comb["variations"]:
            if var["type"] == "combination_keyword":
                new_var = make_freetext_variation(var, freetext)
                comb["variations"].append(new_var)
                break  # ensure only one freetext variation per combination
# Out:
# [{'id': 'c0', 'cluster': 'cluster_0', 'topic': 'IT-Management und Wissensmanagement', 'single': [{'id': 'c0_1_single', 'keyword': 'IT-Systemadministration', 'variations': [{'id': 'c0_1_single_keyword', 'query': 'IT-Systemadministration', 'type': 'single_keyword'}]}, {'id': 'c0_2_single', 'keyword': 'Information Technology', 'variations': [{'id': 'c0_2_single_keyword', 'query': 'Information Technology', 'type': 'single_keyword'}]}, {'id': 'c0_3_single', 'keyword': 'Wissensmanagement', 'variations': [{'id': 'c0_3_single_keyword', 'query': 'Wissensmanagement', 'type': 'single_keyword'}]}], 'combination': []}, {'id': 'c1', 'cluster': 'cluster_1', 'topic': 'Mechanik-, Elektro- und Automatisierungstechnik', 'single': [{'id': 'c1_1_single', 'keyword': 'Konstruktion', 'variations': [{'id': 'c1_1_single_keyword', 'query': 'Konstruktion', 'type': 'single_keyword'}]}, {'id': 'c1_2_single', 'keyword': 'Metallhandwerk', 'variations': [{'id': 'c1_2_single_keyword', 'query': 'Metallhandwerk', 'type': 'single_keyword'}]}, {'id': 'c1_3_single', 'keyword': 'Mechanik', 'variations': [{'id': 'c1_3_single_keyword', 'query': 'Mechanik', 'type': 'single_keyword'}]}, {'id': 'c1_4_single', 'keyword': 'Automatisierungstechnik', 'variations': [{'id': 'c1_4_single_keyword', 'query': 'Automatisierungstechnik', 'type': 'single_keyword'}]}, {'id': 'c1_5_single', 'keyword': 'Elektrotechnik', 'variations': [{'id': 'c1_5_single_keyword', 'query': 'Elektrotechnik', 'type': 'single_keyword'}]}], 'combination': [{'id': 'c1_1_combination', 'keywords': ['Konstruktion', 'Metallhandwerk'], 'variations': [{'id': 'c1_1_combination_keyword', 'query': 'Konstruktion, Metallhandwerk', 'type': 'combination_keyword'}]}, {'id': 'c1_2_combination', 'keywords': ['Mechanik', 'Elektrotechnik'], 'variations': [{'id': 'c1_2_combination_keyword', 'query': 'Mechanik, Elektrotechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_3_combination', 'keywords': ['Metallhandwerk', 'Mechanik'], 'variations': [{'id': 'c1_3_combination_keyword', 'query': 'Metallhandwerk, Mechanik', 'type': 'combination_keyword'}]}, {'id': 'c1_4_combination', 'keywords': ['Metallhandwerk', 'Elektrotechnik'], 'variations': [{'id': 'c1_4_combination_keyword', 'query': 'Metallhandwerk, Elektrotechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_5_combination', 'keywords': ['Mechanik', 'Automatisierungstechnik'], 'variations': [{'id': 'c1_5_combination_keyword', 'query': 'Mechanik, Automatisierungstechnik', 'type': 'combination_keyword'}]}, {'id': 'c1_6_combination', 'keywords': ['Automatisierungstechnik', 'Elektrotechnik'], 'variations': [{'id': 'c1_6_combination_keyword', 'query': 'Automatisierungstechnik, Elektrotechnik', 'type': 'combination_keyword'}]}]}, {'id': 'c3', 'cluster': 'cluster_3', 'topic': 'Künstliche Intelligenz', 'single': [{'id': 'c3_1_single', 'keyword': 'KI', 'variations': [{'id': 'c3_1_single_keyword', 'query': 'KI', 'type': 'single_keyword'}]}], 'combination': []}, {'id': 'c5', 'cluster': 'cluster_5', 'topic': 'Verkauf, Kommunikation und Marketing', 'single': [{'id': 'c5_1_single', 'keyword': 'Public Relations', 'variations': [{'id': 'c5_1_single_keyword', 'query': 'Public Relations', 'type': 'single_keyword'}]}, {'id': 'c5_2_single', 'keyword': 'Sales', 'variations': [{'id': 'c5_2_single_keyword', 'query': 'Sales', 'type': 'single_keyword'}]}, {'id': 'c5_3_single', 'keyword': 'Social Media Marketing', 'variations': [{'id': 'c5_3_single_keyword', 'query': 'Social Media Marketing', 'type': 'single_keyword'}]}], 'combination': [{'id': 'c5_1_combination', 'keywords': ['Public Relations', 'Social Media Marketing'], 'variations': [{'id': 'c5_1_combination_keyword', 'query': 'Public Relations, Social Media Marketing', 'type': 'combination_keyword'}]}]}, {'id': 'c6', 'cluster': 'cluster_6', 'topic': 'Digitales Marketing und Markenkommunikation', 'single': [{'id': 'c6_1_single', 'keyword': 'Marketing', 'variations': [{'id': 'c6_1_single_keyword', 'query': 'Marketing', 'type': 'single_keyword'}]}, { ...
# Add Freetext: 100%|██████████| 11/11 [00:00<00:00, 24308.40it/s]

# %%
queries_with_freetext
# Out:
# [{'id': 'c0',
#   'cluster': 'cluster_0',
#   'topic': 'IT-Management und Wissensmanagement',
#   'single': [{'id': 'c0_1_single',
#     'keyword': 'IT-Systemadministration',
#     'variations': [{'id': 'c0_1_single_keyword',
#       'query': 'IT-Systemadministration',
#       'type': 'single_keyword'},
#      {'id': 'c0_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich IT-Systemadministration',
#       'type': 'single_free'}]},
#    {'id': 'c0_2_single',
#     'keyword': 'Information Technology',
#     'variations': [{'id': 'c0_2_single_keyword',
#       'query': 'Information Technology',
#       'type': 'single_keyword'},
#      {'id': 'c0_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Information Technology',
#       'type': 'single_free'}]},
#    {'id': 'c0_3_single',
#     'keyword': 'Wissensmanagement',
#     'variations': [{'id': 'c0_3_single_keyword',
#       'query': 'Wissensmanagement',
#       'type': 'single_keyword'},
#      {'id': 'c0_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wissensmanagement',
#       'type': 'single_free'}]}],
#   'combination': []},
#  {'id': 'c1',
#   'cluster': 'cluster_1',
#   'topic': 'Mechanik-, Elektro- und Automatisierungstechnik',
#   'single': [{'id': 'c1_1_single',
#     'keyword': 'Konstruktion',
#     'variations': [{'id': 'c1_1_single_keyword',
#       'query': 'Konstruktion',
#       'type': 'single_keyword'},
#      {'id': 'c1_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Konstruktion',
#       'type': 'single_free'}]},
#    {'id': 'c1_2_single',
#     'keyword': 'Metallhandwerk',
#     'variations': [{'id': 'c1_2_single_keyword',
#       'query': 'Metallhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c1_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Metallhandwerk',
#       'type': 'single_free'}]},
#    {'id': 'c1_3_single',
#     'keyword': 'Mechanik',
#     'variations': [{'id': 'c1_3_single_keyword',
#       'query': 'Mechanik',
#       'type': 'single_keyword'},
#      {'id': 'c1_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Mechanik',
#       'type': 'single_free'}]},
#    {'id': 'c1_4_single',
#     'keyword': 'Automatisierungstechnik',
#     'variations': [{'id': 'c1_4_single_keyword',
#       'query': 'Automatisierungstechnik',
#       'type': 'single_keyword'},
#      {'id': 'c1_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Automatisierungstechnik',
#       'type': 'single_free'}]},
#    {'id': 'c1_5_single',
#     'keyword': 'Elektrotechnik',
#     'variations': [{'id': 'c1_5_single_keyword',
#       'query': 'Elektrotechnik',
#       'type': 'single_keyword'},
#      {'id': 'c1_5_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Elektrotechnik',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c1_1_combination',
#     'keywords': ['Konstruktion', 'Metallhandwerk'],
#     'variations': [{'id': 'c1_1_combination_keyword',
#       'query': 'Konstruktion, Metallhandwerk',
#       'type': 'combination_keyword'},
#      {'id': 'c1_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Konstruktion und Metallhandwerk',
#       'type': 'combination_free'}]},
#    {'id': 'c1_2_combination',
#     'keywords': ['Mechanik', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_2_combination_keyword',
#       'query': 'Mechanik, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mechanik und Elektrotechnik',
#       'type': 'combination_free'}]},
#    {'id': 'c1_3_combination',
#     'keywords': ['Metallhandwerk', 'Mechanik'],
#     'variations': [{'id': 'c1_3_combination_keyword',
#       'query': 'Metallhandwerk, Mechanik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallhandwerk und Mechanik',
#       'type': 'combination_free'}]},
#    {'id': 'c1_4_combination',
#     'keywords': ['Metallhandwerk', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_4_combination_keyword',
#       'query': 'Metallhandwerk, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallhandwerk und Elektrotechnik',
#       'type': 'combination_free'}]},
#    {'id': 'c1_5_combination',
#     'keywords': ['Mechanik', 'Automatisierungstechnik'],
#     'variations': [{'id': 'c1_5_combination_keyword',
#       'query': 'Mechanik, Automatisierungstechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mechanik und Automatisierungstechnik',
#       'type': 'combination_free'}]},
#    {'id': 'c1_6_combination',
#     'keywords': ['Automatisierungstechnik', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_6_combination_keyword',
#       'query': 'Automatisierungstechnik, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Automatisierungstechnik und Elektrotechnik',
#       'type': 'combination_free'}]}]},
#  {'id': 'c3',
#   'cluster': 'cluster_3',
#   'topic': 'Künstliche Intelligenz',
#   'single': [{'id': 'c3_1_single',
#     'keyword': 'KI',
#     'variations': [{'id': 'c3_1_single_keyword',
#       'query': 'KI',
#       'type': 'single_keyword'},
#      {'id': 'c3_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich KI',
#       'type': 'single_free'}]}],
#   'combination': []},
#  {'id': 'c5',
#   'cluster': 'cluster_5',
#   'topic': 'Verkauf, Kommunikation und Marketing',
#   'single': [{'id': 'c5_1_single',
#     'keyword': 'Public Relations',
#     'variations': [{'id': 'c5_1_single_keyword',
#       'query': 'Public Relations',
#       'type': 'single_keyword'},
#      {'id': 'c5_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Public Relations',
#       'type': 'single_free'}]},
#    {'id': 'c5_2_single',
#     'keyword': 'Sales',
#     'variations': [{'id': 'c5_2_single_keyword',
#       'query': 'Sales',
#       'type': 'single_keyword'},
#      {'id': 'c5_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Sales',
#       'type': 'single_free'}]},
#    {'id': 'c5_3_single',
#     'keyword': 'Social Media Marketing',
#     'variations': [{'id': 'c5_3_single_keyword',
#       'query': 'Social Media Marketing',
#       'type': 'single_keyword'},
#      {'id': 'c5_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Social Media Marketing',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c5_1_combination',
#     'keywords': ['Public Relations', 'Social Media Marketing'],
#     'variations': [{'id': 'c5_1_combination_keyword',
#       'query': 'Public Relations, Social Media Marketing',
#       'type': 'combination_keyword'},
#      {'id': 'c5_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Public Relations und Social Media Marketing',
#       'type': 'combination_free'}]}]},
#  {'id': 'c6',
#   'cluster': 'cluster_6',
#   'topic': 'Digitales Marketing und Markenkommunikation',
#   'single': [{'id': 'c6_1_single',
#     'keyword': 'Marketing',
#     'variations': [{'id': 'c6_1_single_keyword',
#       'query': 'Marketing',
#       'type': 'single_keyword'},
#      {'id': 'c6_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Marketing',
#       'type': 'single_free'}]},
#    {'id': 'c6_2_single',
#     'keyword': 'Brand Management',
#     'variations': [{'id': 'c6_2_single_keyword',
#       'query': 'Brand Management',
#       'type': 'single_keyword'},
#      {'id': 'c6_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Brand Management',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c6_1_combination',
#     'keywords': ['Marketing', 'Social Media Marketing'],
#     'variations': [{'id': 'c6_1_combination_keyword',
#       'query': 'Marketing, Social Media Marketing',
#       'type': 'combination_keyword'},
#      {'id': 'c6_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Marketing und Social Media Marketing',
#       'type': 'combination_free'}]},
#    {'id': 'c6_2_combination',
#     'keywords': ['Marketing', 'Brand Management'],
#     'variations': [{'id': 'c6_2_combination_keyword',
#       'query': 'Marketing, Brand Management',
#       'type': 'combination_keyword'},
#      {'id': 'c6_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Marketing und Brand Management',
#       'type': 'combination_free'}]},
#    {'id': 'c6_3_combination',
#     'keywords': ['Social Media Marketing', 'Brand Management'],
#     'variations': [{'id': 'c6_3_combination_keyword',
#       'query': 'Social Media Marketing, Brand Management',
#       'type': 'combination_keyword'},
#      {'id': 'c6_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Social Media Marketing und Brand Management',
#       'type': 'combination_free'}]}]},
#  {'id': 'c7',
#   'cluster': 'cluster_7',
#   'topic': 'Personal- und Organisationsentwicklung',
#   'single': [{'id': 'c7_1_single',
#     'keyword': 'Employee Development',
#     'variations': [{'id': 'c7_1_single_keyword',
#       'query': 'Employee Development',
#       'type': 'single_keyword'},
#      {'id': 'c7_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Employee Development',
#       'type': 'single_free'}]},
#    {'id': 'c7_2_single',
#     'keyword': 'Personalentwicklung und Mentoring',
#     'variations': [{'id': 'c7_2_single_keyword',
#       'query': 'Personalentwicklung und Mentoring',
#       'type': 'single_keyword'},
#      {'id': 'c7_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Personalentwicklung und Mentoring',
#       'type': 'single_free'}]},
#    {'id': 'c7_3_single',
#     'keyword': 'Human Resources',
#     'variations': [{'id': 'c7_3_single_keyword',
#       'query': 'Human Resources',
#       'type': 'single_keyword'},
#      {'id': 'c7_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Human Resources',
#       'type': 'single_free'}]},
#    {'id': 'c7_4_single',
#     'keyword': 'Coaching',
#     'variations': [{'id': 'c7_4_single_keyword',
#       'query': 'Coaching',
#       'type': 'single_keyword'},
#      {'id': 'c7_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Coaching',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c7_1_combination',
#     'keywords': ['Business Development', 'Employee Development'],
#     'variations': [{'id': 'c7_1_combination_keyword',
#       'query': 'Business Development, Employee Development',
#       'type': 'combination_keyword'},
#      {'id': 'c7_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Employee Development',
#       'type': 'combination_free'}]},
#    {'id': 'c7_2_combination',
#     'keywords': ['Business Development', 'Personalentwicklung und Mentoring'],
#     'variations': [{'id': 'c7_2_combination_keyword',
#       'query': 'Business Development, Personalentwicklung und Mentoring',
#       'type': 'combination_keyword'},
#      {'id': 'c7_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Personalentwicklung und Mentoring',
#       'type': 'combination_free'}]},
#    {'id': 'c7_3_combination',
#     'keywords': ['Business Development', 'Human Resources'],
#     'variations': [{'id': 'c7_3_combination_keyword',
#       'query': 'Business Development, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Human Resources',
#       'type': 'combination_free'}]},
#    {'id': 'c7_4_combination',
#     'keywords': ['Business Development', 'Coaching'],
#     'variations': [{'id': 'c7_4_combination_keyword',
#       'query': 'Business Development, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Coaching',
#       'type': 'combination_free'}]},
#    {'id': 'c7_5_combination',
#     'keywords': ['Employee Development', 'Personalentwicklung und Mentoring'],
#     'variations': [{'id': 'c7_5_combination_keyword',
#       'query': 'Employee Development, Personalentwicklung und Mentoring',
#       'type': 'combination_keyword'},
#      {'id': 'c7_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Personalentwicklung und Mentoring',
#       'type': 'combination_free'}]},
#    {'id': 'c7_6_combination',
#     'keywords': ['Employee Development', 'Human Resources'],
#     'variations': [{'id': 'c7_6_combination_keyword',
#       'query': 'Employee Development, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Human Resources',
#       'type': 'combination_free'}]},
#    {'id': 'c7_7_combination',
#     'keywords': ['Employee Development', 'Coaching'],
#     'variations': [{'id': 'c7_7_combination_keyword',
#       'query': 'Employee Development, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Coaching',
#       'type': 'combination_free'}]},
#    {'id': 'c7_8_combination',
#     'keywords': ['Personalentwicklung und Mentoring', 'Human Resources'],
#     'variations': [{'id': 'c7_8_combination_keyword',
#       'query': 'Personalentwicklung und Mentoring, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalentwicklung und Mentoring und Human Resources',
#       'type': 'combination_free'}]},
#    {'id': 'c7_9_combination',
#     'keywords': ['Personalentwicklung und Mentoring', 'Coaching'],
#     'variations': [{'id': 'c7_9_combination_keyword',
#       'query': 'Personalentwicklung und Mentoring, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_9_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalentwicklung und Mentoring und Coaching',
#       'type': 'combination_free'}]},
#    {'id': 'c7_10_combination',
#     'keywords': ['Human Resources', 'Coaching'],
#     'variations': [{'id': 'c7_10_combination_keyword',
#       'query': 'Human Resources, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_10_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Human Resources und Coaching',
#       'type': 'combination_free'}]}]},
#  {'id': 'c8',
#   'cluster': 'cluster_8',
#   'topic': 'Bau- und Handwerkstechnik',
#   'single': [{'id': 'c8_1_single',
#     'keyword': 'Bau- und Ausbauhandwerk',
#     'variations': [{'id': 'c8_1_single_keyword',
#       'query': 'Bau- und Ausbauhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c8_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Bau- und Ausbauhandwerk',
#       'type': 'single_free'}]},
#    {'id': 'c8_2_single',
#     'keyword': 'Holzhandwerk',
#     'variations': [{'id': 'c8_2_single_keyword',
#       'query': 'Holzhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c8_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Holzhandwerk',
#       'type': 'single_free'}]},
#    {'id': 'c8_3_single',
#     'keyword': 'Anlagenbau',
#     'variations': [{'id': 'c8_3_single_keyword',
#       'query': 'Anlagenbau',
#       'type': 'single_keyword'},
#      {'id': 'c8_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Anlagenbau',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c8_1_combination',
#     'keywords': ['Bau- und Ausbauhandwerk', 'Anlagenbau'],
#     'variations': [{'id': 'c8_1_combination_keyword',
#       'query': 'Bau- und Ausbauhandwerk, Anlagenbau',
#       'type': 'combination_keyword'},
#      {'id': 'c8_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Bau- und Ausbauhandwerk und Anlagenbau',
#       'type': 'combination_free'}]}]},
#  {'id': 'c10',
#   'cluster': 'cluster_10',
#   'topic': 'Finanzmanagement und Unternehmensplanung',
#   'single': [{'id': 'c10_1_single',
#     'keyword': 'Finance',
#     'variations': [{'id': 'c10_1_single_keyword',
#       'query': 'Finance',
#       'type': 'single_keyword'},
#      {'id': 'c10_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Finance',
#       'type': 'single_free'}]},
#    {'id': 'c10_2_single',
#     'keyword': 'Financial Management',
#     'variations': [{'id': 'c10_2_single_keyword',
#       'query': 'Financial Management',
#       'type': 'single_keyword'},
#      {'id': 'c10_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Financial Management',
#       'type': 'single_free'}]},
#    {'id': 'c10_3_single',
#     'keyword': 'Budget Planning',
#     'variations': [{'id': 'c10_3_single_keyword',
#       'query': 'Budget Planning',
#       'type': 'single_keyword'},
#      {'id': 'c10_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Budget Planning',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c10_1_combination',
#     'keywords': ['Business Planning', 'Finance'],
#     'variations': [{'id': 'c10_1_combination_keyword',
#       'query': 'Business Planning, Finance',
#       'type': 'combination_keyword'},
#      {'id': 'c10_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Finance',
#       'type': 'combination_free'}]},
#    {'id': 'c10_2_combination',
#     'keywords': ['Business Planning', 'Financial Management'],
#     'variations': [{'id': 'c10_2_combination_keyword',
#       'query': 'Business Planning, Financial Management',
#       'type': 'combination_keyword'},
#      {'id': 'c10_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Financial Management',
#       'type': 'combination_free'}]},
#    {'id': 'c10_3_combination',
#     'keywords': ['Business Planning', 'Budget Planning'],
#     'variations': [{'id': 'c10_3_combination_keyword',
#       'query': 'Business Planning, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Budget Planning',
#       'type': 'combination_free'}]},
#    {'id': 'c10_4_combination',
#     'keywords': ['Business Planning', 'Business Development'],
#     'variations': [{'id': 'c10_4_combination_keyword',
#       'query': 'Business Planning, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Business Development',
#       'type': 'combination_free'}]},
#    {'id': 'c10_5_combination',
#     'keywords': ['Finance', 'Financial Management'],
#     'variations': [{'id': 'c10_5_combination_keyword',
#       'query': 'Finance, Financial Management',
#       'type': 'combination_keyword'},
#      {'id': 'c10_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Financial Management',
#       'type': 'combination_free'}]},
#    {'id': 'c10_6_combination',
#     'keywords': ['Finance', 'Budget Planning'],
#     'variations': [{'id': 'c10_6_combination_keyword',
#       'query': 'Finance, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Budget Planning',
#       'type': 'combination_free'}]},
#    {'id': 'c10_7_combination',
#     'keywords': ['Finance', 'Business Development'],
#     'variations': [{'id': 'c10_7_combination_keyword',
#       'query': 'Finance, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Business Development',
#       'type': 'combination_free'}]},
#    {'id': 'c10_8_combination',
#     'keywords': ['Financial Management', 'Budget Planning'],
#     'variations': [{'id': 'c10_8_combination_keyword',
#       'query': 'Financial Management, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Financial Management und Budget Planning',
#       'type': 'combination_free'}]},
#    {'id': 'c10_9_combination',
#     'keywords': ['Financial Management', 'Business Development'],
#     'variations': [{'id': 'c10_9_combination_keyword',
#       'query': 'Financial Management, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_9_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Financial Management und Business Development',
#       'type': 'combination_free'}]},
#    {'id': 'c10_10_combination',
#     'keywords': ['Budget Planning', 'Business Development'],
#     'variations': [{'id': 'c10_10_combination_keyword',
#       'query': 'Budget Planning, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_10_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Budget Planning und Business Development',
#       'type': 'combination_free'}]}]},
#  {'id': 'c11',
#   'cluster': 'cluster_11',
#   'topic': 'Strategische Unternehmensführung und Veränderungsmanagement',
#   'single': [{'id': 'c11_1_single',
#     'keyword': 'Business Planning',
#     'variations': [{'id': 'c11_1_single_keyword',
#       'query': 'Business Planning',
#       'type': 'single_keyword'},
#      {'id': 'c11_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Planning',
#       'type': 'single_free'}]},
#    {'id': 'c11_2_single',
#     'keyword': 'Business Development',
#     'variations': [{'id': 'c11_2_single_keyword',
#       'query': 'Business Development',
#       'type': 'single_keyword'},
#      {'id': 'c11_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Development',
#       'type': 'single_free'}]},
#    {'id': 'c11_3_single',
#     'keyword': 'Controlling',
#     'variations': [{'id': 'c11_3_single_keyword',
#       'query': 'Controlling',
#       'type': 'single_keyword'},
#      {'id': 'c11_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Controlling',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c11_1_combination',
#     'keywords': ['Change Management', 'Business Planning'],
#     'variations': [{'id': 'c11_1_combination_keyword',
#       'query': 'Change Management, Business Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c11_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Planning',
#       'type': 'combination_free'}]},
#    {'id': 'c11_2_combination',
#     'keywords': ['Change Management', 'Business Development'],
#     'variations': [{'id': 'c11_2_combination_keyword',
#       'query': 'Change Management, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c11_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Development',
#       'type': 'combination_free'}]},
#    {'id': 'c11_3_combination',
#     'keywords': ['Change Management', 'Controlling'],
#     'variations': [{'id': 'c11_3_combination_keyword',
#       'query': 'Change Management, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Controlling',
#       'type': 'combination_free'}]},
#    {'id': 'c11_4_combination',
#     'keywords': ['Business Planning', 'Controlling'],
#     'variations': [{'id': 'c11_4_combination_keyword',
#       'query': 'Business Planning, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Controlling',
#       'type': 'combination_free'}]},
#    {'id': 'c11_5_combination',
#     'keywords': ['Business Development', 'Controlling'],
#     'variations': [{'id': 'c11_5_combination_keyword',
#       'query': 'Business Development, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Controlling',
#       'type': 'combination_free'}]}]},
#  {'id': 'c12',
#   'cluster': 'cluster_12',
#   'topic': 'Digitales Management und IT-Systeme',
#   'single': [{'id': 'c12_1_single',
#     'keyword': 'Cloud-Computing',
#     'variations': [{'id': 'c12_1_single_keyword',
#       'query': 'Cloud-Computing',
#       'type': 'single_keyword'},
#      {'id': 'c12_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Cloud-Computing',
#       'type': 'single_free'}]},
#    {'id': 'c12_2_single',
#     'keyword': 'IT-Management',
#     'variations': [{'id': 'c12_2_single_keyword',
#       'query': 'IT-Management',
#       'type': 'single_keyword'},
#      {'id': 'c12_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich IT-Management',
#       'type': 'single_free'}]},
#    {'id': 'c12_3_single',
#     'keyword': 'Datenbankverwaltung',
#     'variations': [{'id': 'c12_3_single_keyword',
#       'query': 'Datenbankverwaltung',
#       'type': 'single_keyword'},
#      {'id': 'c12_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Datenbankverwaltung',
#       'type': 'single_free'}]},
#    {'id': 'c12_4_single',
#     'keyword': 'Softwareentwicklung',
#     'variations': [{'id': 'c12_4_single_keyword',
#       'query': 'Softwareentwicklung',
#       'type': 'single_keyword'},
#      {'id': 'c12_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Softwareentwicklung',
#       'type': 'single_free'}]},
#    {'id': 'c12_5_single',
#     'keyword': 'Data Analysis',
#     'variations': [{'id': 'c12_5_single_keyword',
#       'query': 'Data Analysis',
#       'type': 'single_keyword'},
#      {'id': 'c12_5_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Data Analysis',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c12_1_combination',
#     'keywords': ['Cloud-Computing', 'IT-Management'],
#     'variations': [{'id': 'c12_1_combination_keyword',
#       'query': 'Cloud-Computing, IT-Management',
#       'type': 'combination_keyword'},
#      {'id': 'c12_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und IT-Management',
#       'type': 'combination_free'}]},
#    {'id': 'c12_2_combination',
#     'keywords': ['Cloud-Computing', 'Digital Ethics'],
#     'variations': [{'id': 'c12_2_combination_keyword',
#       'query': 'Cloud-Computing, Digital Ethics',
#       'type': 'combination_keyword'},
#      {'id': 'c12_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Digital Ethics',
#       'type': 'combination_free'}]},
#    {'id': 'c12_3_combination',
#     'keywords': ['Cloud-Computing', 'Datenbankverwaltung'],
#     'variations': [{'id': 'c12_3_combination_keyword',
#       'query': 'Cloud-Computing, Datenbankverwaltung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Datenbankverwaltung',
#       'type': 'combination_free'}]},
#    {'id': 'c12_4_combination',
#     'keywords': ['Cloud-Computing', 'Softwareentwicklung'],
#     'variations': [{'id': 'c12_4_combination_keyword',
#       'query': 'Cloud-Computing, Softwareentwicklung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Softwareentwicklung',
#       'type': 'combination_free'}]},
#    {'id': 'c12_5_combination',
#     'keywords': ['Cloud-Computing', 'Data Analysis'],
#     'variations': [{'id': 'c12_5_combination_keyword',
#       'query': 'Cloud-Computing, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Data Analysis',
#       'type': 'combination_free'}]},
#    {'id': 'c12_6_combination',
#     'keywords': ['IT-Management', 'Softwareentwicklung'],
#     'variations': [{'id': 'c12_6_combination_keyword',
#       'query': 'IT-Management, Softwareentwicklung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Management und Softwareentwicklung',
#       'type': 'combination_free'}]},
#    {'id': 'c12_7_combination',
#     'keywords': ['IT-Management', 'Data Analysis'],
#     'variations': [{'id': 'c12_7_combination_keyword',
#       'query': 'IT-Management, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Management und Data Analysis',
#       'type': 'combination_free'}]},
#    {'id': 'c12_8_combination',
#     'keywords': ['Softwareentwicklung', 'Data Analysis'],
#     'variations': [{'id': 'c12_8_combination_keyword',
#       'query': 'Softwareentwicklung, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Softwareentwicklung und Data Analysis',
#       'type': 'combination_free'}]}]},
#  {'id': 'c13',
#   'cluster': 'cluster_13',
#   'topic': 'Digitale Transformations- und Innovationsstrategie',
#   'single': [{'id': 'c13_1_single',
#     'keyword': 'Change Management',
#     'variations': [{'id': 'c13_1_single_keyword',
#       'query': 'Change Management',
#       'type': 'single_keyword'},
#      {'id': 'c13_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Change Management',
#       'type': 'single_free'}]},
#    {'id': 'c13_2_single',
#     'keyword': 'Digital Ethics',
#     'variations': [{'id': 'c13_2_single_keyword',
#       'query': 'Digital Ethics',
#       'type': 'single_keyword'},
#      {'id': 'c13_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Digital Ethics',
#       'type': 'single_free'}]},
#    {'id': 'c13_3_single',
#     'keyword': 'Business Process Analysis',
#     'variations': [{'id': 'c13_3_single_keyword',
#       'query': 'Business Process Analysis',
#       'type': 'single_keyword'},
#      {'id': 'c13_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Process Analysis',
#       'type': 'single_free'}]}],
#   'combination': [{'id': 'c13_1_combination',
#     'keywords': ['Change Management', 'Digital Ethics'],
#     'variations': [{'id': 'c13_1_combination_keyword',
#       'query': 'Change Management, Digital Ethics',
#       'type': 'combination_keyword'},
#      {'id': 'c13_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Digital Ethics',
#       'type': 'combination_free'}]},
#    {'id': 'c13_2_combination',
#     'keywords': ['Change Management', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_2_combination_keyword',
#       'query': 'Change Management, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Process Analysis',
#       'type': 'combination_free'}]},
#    {'id': 'c13_3_combination',
#     'keywords': ['Digital Ethics', 'Business Development'],
#     'variations': [{'id': 'c13_3_combination_keyword',
#       'query': 'Digital Ethics, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c13_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Digital Ethics und Business Development',
#       'type': 'combination_free'}]},
#    {'id': 'c13_4_combination',
#     'keywords': ['Business Planning', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_4_combination_keyword',
#       'query': 'Business Planning, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Business Process Analysis',
#       'type': 'combination_free'}]},
#    {'id': 'c13_5_combination',
#     'keywords': ['Business Development', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_5_combination_keyword',
#       'query': 'Business Development, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Business Process Analysis',
#       'type': 'combination_free'}]}]}]

# %% [markdown]
# ## Hinzufügen von Synonymen Versionen der Anfragen

# %%
# install langchain
# !pip install -U langchain
# !pip install -U "langchain[openai]"
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.47)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: langchain[openai] in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain[openai]) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain[openai]) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain[openai]) (2.12.3)
# Collecting langchain-openai (from langchain[openai])
#   Downloading langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (0.4.47)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain[openai]) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain-openai->langchain[openai]) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai->langchain[openai]) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2025.11.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[openai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[openai]) (2.5.0)
# Downloading langchain_openai-1.1.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-1.1.0

# %%
# imports
import os
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate

# %%
# add api key for OPENAI
os.environ["OPENAI_API_KEY"] = input("Bitte gib deinen OpenAI API Key ein: ")
print("API Key erfolgreich gesetzt!")

# %%
model = ChatOpenAI(
    model="gpt-5-nano-2025-08-07",
    temperature=0.1,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
SYSTEM_PROMPT_SYNONYM_SINGLE = """
Du bist Experte für die Optimierung von Suchanfragen.
Deine Aufgabe ist es, aus einem einzelnen Stichwort eine alternative Suchanfrage zu erzeugen, indem du ein bedeutungsgleiches Synonym verwendest.

Regeln:
1. Das ursprüngliche Stichwort darf nicht in der Ausgabe vorkommen.
2. Verwende ein echtes Synonym mit gleicher oder sehr ähnlicher Bedeutung.
3. Nutze keine umfangreichen Umschreibungen oder Satzkonstruktionen – bleibe beim Charakter einer Stichwort-Suchanfrage.
4. Begriffe aus der Blacklist dürfen nicht enthalten sein.
5. Falls kein sinnvolles Synonym existiert, gib "NO_VALID_SYN" zurück.

"""

# %%
HUMAN_PROMPT_SYNONYM_SINGLE = """
Ersetze das folgende Stichwort durch ein bedeutungsgleiches Synonym, um daraus eine neue Suchanfrage zu erzeugen.
Verwende keines der Wörter aus der bereitgestellten Blacklist.
Die Ausgabe darf nur aus einem einzigen Wort bestehen – dem gewählten Synonym.

Stichwort:
{query}

Blacklist:
{blacklist}
"""

# %%
SYSTEM_PROMPT_SYNONYM_COMBINATION = """
Du bist Experte für die Optimierung von Suchanfragen.
Dir wird eine Kombination aus zwei Stichwörtern übergeben.
Erstelle darauf basierend eine alternative Suchanfrage, indem du beide Stichwörter durch bedeutungsgleiche Synonyme ersetzt.

Regeln:
1. Keines der ursprünglichen Stichwörter darf in der Ausgabe vorkommen.
2. Verwende echte Synonyme mit gleicher oder sehr ähnlicher Bedeutung.
3. Nutze keine umfangreichen Umschreibungen oder Satzkonstruktionen – bleibe beim Charakter einer Stichwort-Suchanfrage.
4. Begriffe aus der Blacklist dürfen nicht enthalten sein.
5. Falls kein sinnvolles Synonym existiert, gib "NO_VALID_SYN" zurück.

"""

# %%
HUMAN_PROMPT_SYNONYM_COMBINATION = """
Ersetze die folgende Stichwörter durch bedeutungsgleiche Synonyme, um daraus eine neue Suchanfrage zu erzeugen.
Verwende keines der Wörter aus der bereitgestellten Blacklist.
Die Ausgabe darf nur aus zwei Stichwörtern bestehen – den gewählten Synonymen.

Stichwörter:
{query}

Blacklist:
{blacklist}
"""

# %%
from typing import List, Literal

# Structured output model for single-keyword synonym generation.
class Synonym_Keyword_Query(BaseModel):
    """Ausgabe der Erstellung von Synonymen-Versionen der Anfragen."""

    # Single synonym for a given keyword.
    synonym_keyword: str = Field(
        description="Eine synonyme Version des relevanten Stichwortes"
    )


# Structured output model for multi-keyword (combination) synonym generation.
class Synonym_Keywords_Combination_Query(BaseModel):
    """Ausgabe der Erstellung von Synonymen-Versionen der Anfragen."""

    # Synonym list corresponding to the original keyword combination.
    synonym_keywords: List[str] = Field(
        description="Eine synonyme Version der beiden relevanten Stichwörter"
    )

# %%
chat_prompt_single = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT_SYNONYM_SINGLE),
    ("human", HUMAN_PROMPT_SYNONYM_SINGLE)
  ])

chat_prompt_combi = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT_SYNONYM_COMBINATION),
    ("human", HUMAN_PROMPT_SYNONYM_COMBINATION)
  ])

# %%
model_with_structure_single_keyword = model.with_structured_output(Synonym_Keyword_Query)

model_with_structure_combinations = model.with_structured_output(Synonym_Keywords_Combination_Query)

# %%
def make_synonym_variation(base_variation, synonym_query: str):
    # Create synonym-based variation derived from base variation.
    # ID and type are extended with "_synonym" suffix.
    return {
        "id": base_variation["id"] + "_synonym",
        "query": synonym_query,
        "type": base_variation["type"] + "_synonym",
    }

# %%
PROFILES_DATA = "drive/MyDrive/Uni/Master/Masterthesis/Data/enhanced_expert_profiles.json"

# %%
## load enhanced profile data
df_profiles = pd.read_json(PROFILES_DATA)
df_profiles.head()
# Out:
#                                             branches companyLocationCity  \
# 0  [Technologie, Medien & Werbung, Unternehmensdi...          Lennestadt
# 1                     [Unternehmensdienstleistungen]         Lüdenscheid
# 2  [Automobilindustrie, Maschinenbau und Industri...         Lüdenscheid
# 3  [Unternehmensdienstleistungen, Investor (Eigen...         Lüdenscheid
# 4                      [Logistik, Konsum und Handel]         Ludenscheid
#
#    companyLocationStreet  companyLocationZip            companyName  \
# 0      Hagener Straße 64             57368.0        lenne.Tech GmbH
# 1   Sauerfelder Straße 5             58511.0            RegioKonneX
# 2   Sauerfelder Straße 5             58511.0            RegioKonneX
# 3  Sauerfelder Straße 4              58511.0            RegioKonneX
# 4   Wefelshohler Str 48a             58511.0  Karl Koerschulte GmbH
#
#        companyTypes      companyWebsite  \
# 0  [Dienstleistung]  https://lenne.tech
# 1  [Dienstleistung]  www.regiokonnex.de
# 2  [Dienstleistung]                None
# 3  [Dienstleistung]  www.regiokonnex.de
# 4  [Dienstleistung]  www.koerschulte.de
#
#                                          description  \
# 0  Seit über 15 Jahren begleite ich digitale Proj...
# 1  Ich bin Mitglied von Team RegioKonneX und steh...
# 2  Als Relationship-Manager unterstütze ich Gründ...
# 3  Der Themenwelt rund um Start-Ups bin ich schon...
# 4                                               None
#
#   employeeOfInstitutionNames firstName  ...  lastName  \
# 0                         []       Ege  ...   Siebert
# 1              [RegioKonneX]   Hendrik  ...       Nöh
# 2              [RegioKonneX]     Deniz  ...  Buchholz
# 3              [RegioKonneX]     Klara  ...    Bozsik
# 4                         []    Melvin  ...   Molitor
#
#                                  projectsDescription  \
# 0  lenne.Tech unterstützt Unternehmen, Selbststän...
# 1  Als Angebot der SWF Beratung GmbH unterstützen...
# 2                                               None
# 3  RegioKonneX möchte das die unternehmerische La...
# 4  Die Molitor-GROUP ist ein Produktionsverbindun...
#
#                                               skills title  \
# 0  [Softwareentwicklung, Web-Entwicklung, IT-Syst...  None
# 1  [Financial Management, Cybersecurity, Finance,...  None
# 2  [Benchmarking, Budget Planning, Budgeting, Bus...  None
# 3  [Business Planning, Business Development, Coac...  None
# 4  [Logistik, Supply Chain Management, Controllin...  None
#
#                                            full_text  \
# 0  Ege Siebert ist Softwareentwickler mit umfangr...
# 1  Hendrik Nöh ist Administrator und Projektmanag...
# 2  Deniz Buchholz ist Relationship-Manager (Gründ...
# 3  Klara Bozsik arbeitet als Firmenkundenbetreuun...
# 4  Melvin Molitor ist Geschäftsführer der Karl Ko...
#
#                                full_text_fields_used validation_issues  \
# 0  [branches, description, jobTitle, projectsDesc...                OK
# 1  [branches, description, jobTitle, projectsDesc...                OK
# 2          [branches, description, jobTitle, skills]                OK
# 3  [branches, description, jobTitle, projectsDesc...                OK
# 4  [branches, jobTitle, projectsDescription, skills]                OK
#
#                          full_text_fields_used_fixed full_text_word_count  \
# 0  [skills, branches, description, projectsDescri...                116.0
# 1  [skills, branches, description, projectsDescri...                 77.0
# 2          [branches, jobTitle, skills, description]                 61.0
# 3  [skills, branches, description, projectsDescri...                 84.0
# 4  [projectsDescription, branches, jobTitle, skills]                 78.0
#
#                         full_text_fields_used_sorted
# 0  [branches, description, jobTitle, projectsDesc...
# 1  [branches, description, jobTitle, projectsDesc...
# 2          [branches, description, jobTitle, skills]
# 3  [branches, description, jobTitle, projectsDesc...
# 4  [branches, jobTitle, projectsDescription, skills]
#
# [5 rows x 23 columns]

# %%
def get_synonym_blacklist(keywords, df):
    """
    keywords: str oder List[str]
    df: DataFrame mit Spalten 'skills', 'description', 'projectsDescription'
    return: Set mit geblacklisteten Skills
    """

    # Normalize input to list.
    if isinstance(keywords, str):
        keywords = [keywords]

    # Lowercase keyword list for case-insensitive matching.
    keywords = [k.lower() for k in keywords if isinstance(k, str)]

    def cell_contains_keyword(value, kws):
        """Prüft, ob eines der Keywords in value vorkommt (case-insensitive)."""

        # Skip None/NaN values.
        if value is None or (isinstance(value, float) and pd.isna(value)):
            return False

        # Handle list-type fields (e.g., skills).
        if isinstance(value, list):
            for item in value:
                if item is None:
                    continue
                text = str(item).lower()
                if any(k in text for k in kws):
                    return True
            return False

        # Fallback: treat value as string.
        text = str(value).lower()
        return any(k in text for k in kws)

    # Build mask: keyword appears in at least one relevant column.
    mask = df.apply(
        lambda row: (
            cell_contains_keyword(row.get("skills"), keywords) or
            cell_contains_keyword(row.get("description"), keywords) or
            cell_contains_keyword(row.get("projectsDescription"), keywords)
        ),
        axis=1
    )

    # Collect all skills from matched profiles into blacklist set.
    blacklist = set()
    for skills_list in df.loc[mask, "skills"]:
        if isinstance(skills_list, list):
            for skill in skills_list:
                if isinstance(skill, str):
                    blacklist.add(skill.strip())

    return list(blacklist)

# %%
unique_skills = sorted({skill for skills_list in df_profiles["skills"] for skill in skills_list})
unique_skills
# Out:
# ['AI-gestützte Kundenbetreuung (Chatbots)',
#  'Accounting',
#  'Adobe Creative Cloud',
#  'Ambulanzmanagement (LabCentre)',
#  'Anlagenbau',
#  'Antriebstechnik',
#  'Asset Management',
#  'Autodesk Inventor',
#  'Automatisierte Produktions- & Montagelinien',
#  'Automatisierungstechnik',
#  'Bau- und Ausbauhandwerk',
#  'Bauinformatik',
#  'Bedrucken & Lackieren von Metalloberflächen',
#  'Behavioral Finance',
#  'Bekleidungs-, Textil- und Lederhandwerk',
#  'Benchmarking',
#  'Benutzeroberflächen-Design',
#  'Beratung & Bildungscoaching',
#  'Blockchain',
#  'Brand Management',
#  'Buchhaltung',
#  'Budget Control',
#  'Budget Planning',
#  'Budgeting',
#  'Business Analysis',
#  'Business Continuity',
#  'Business Development',
#  'Business English',
#  'Business Planning',
#  'Business Process Analysis',
#  'Business Process Management (BPM) & Automatisierung',
#  'CAD-Systeme',
#  'CRM-Plattformen',
#  'Capacity Planning',
#  'Change Management',
#  'Change Management im digitalen Wandel',
#  'Cloud-Computing',
#  'Coaching',
#  'Communication',
#  'Competitive Analysis',
#  'Compliance',
#  'Conflict Management',
#  'Content Management',
#  'Content-Marketing & Storytelling',
#  'Controlling',
#  'Cost Analysis and Control',
#  'Customer Advocacy',
#  'Customer Analytics & Insights',
#  'Customer Relationship Management',
#  'Cybersecurity',
#  'Data Analysis',
#  'Data Warehousing & Data Lake Management',
#  'Datenbankanbindung',
#  'Datenbankverwaltung',
#  'Datenschutztechnologien (DSGVO-konform, Privacy by Design)',
#  'Datentechnik',
#  'Design',
#  'Design Thinking',
#  'DevOps',
#  'Digital Ethics',
#  'Digitale Bildung & Medienkompetenz',
#  'Digitale Geschäftsmodellentwicklung',
#  'Digitale Reifegradmodelle & Digital Maturity Assessment',
#  'Digitale Transformationsstrategie',
#  'Digitale Zahlungsabwicklung',
#  'Digitalisierung in der Unternehmensorganisation',
#  'Dokumentenerstellung (B/L, Manifest etc.)',
#  'E-Mail-Marketing & Marketing Automation',
#  'Economics',
#  'Einführung digitaler Plattformlösungen',
#  'Elektroinstallation',
#  'Elektrotechnik',
#  'Employee Development',
#  'Entrepreneurship',
#  'Estimates',
#  'Executive Management',
#  'Fach- und Methodenkenntnisse',
#  'Fahrzeug- und Maschinentechnik',
#  'Farbtechnik',
#  'Finance',
#  'Financial Analysis',
#  'Financial Management',
#  'Finanzplanung',
#  'Fliesenlegen',
#  'Forschung',
#  'Frontend-Entwicklung',
#  'Gap Analysis',
#  'Geschäftsmodellentwicklung',
#  'Glas- und Keramikhandwerk',
#  'Goal Planning',
#  'Google AdWords',
#  'Google Analytics',
#  'Grafikprogramme',
#  'Handwerk in der Gesundheitsbranche',
#  'Handwerk in der Schönheitsbranche',
#  'Hausverwaltung',
#  'Holzhandwerk',
#  'Human Resources',
#  'IT-Management',
#  'IT-Sicherheitsarchitektur',
#  'IT-Systemadministration',
#  'Influencing',
#  'Information Technology',
#  'Ingenieurwesen',
#  'Installationstechnik',
#  'Investing',
#  'IoT-Anbindung automatisierter Systeme (Edge-Integration)',
#  'Java',
#  'JavaScript',
#  'Kampagnenplanung & Media Buying',
#  'Klempnerarbeiten',
#  'Knowledge Management',
#  'Konstruktion',
#  'Kunststoffverarbeitung (Spritzguss, Blasformen, Thermoformen)',
#  'Lebensmittelhandwerk',
#  'Logistik',
#  'Malen',
#  'Markenstrategie & Positionierung',
#  'Market Differentiation & Positioning',
#  'Market Research',
#  'Marketing',
#  'Marketinganalyse',
#  'Marktanalyse',
#  'Marktforschung',
#  'Maurern',
#  'Mechanik',
#  'Mediation',
#  'Metallhandwerk',
#  'Mobile App-Entwicklung (iOS, Android, Cross-Platform',
#  'Musikproduktion & Tonstudiomanagement',
#  'Natural Language Processing (NLP) für Textanalysen',
#  'Networking',
#  'Online-Shop-Management & Plattformbetrieb',
#  'Open Source Entwicklung',
#  'Operations Analysis',
#  'Operations Management',
#  'Papierhandwerk',
#  'Patienten- und Klinikmanagement-Software',
#  'Performance Management',
#  'Performance Marketing & Conversion-Optimierung',
#  'Personalentwicklung und Mentoring',
#  'Personalmanagement',
#  'Planning',
#  'Planung & Projektmanagement',
#  'Product Development',
#  'Product Management',
#  'Programmierkenntnisse',
#  'Programmiersprachen',
#  'Projektmanagement',
#  'Prototyping',
#  'Prozessdigitalisierung & Workflow-Automatisierung',
#  'Public Relations',
#  'Quality Assurance',
#  'Qualitätssicherung',
#  'Rechnungs- und Mahnwesen',
#  'Recruiting',
#  'Relationship Management',
#  'Reporting',
#  'Risikomanagement',
#  'Risk Assessment',
#  'SAP',
#  'SEA, SEO & Online-Marketingstrategien',
#  'SWOT Analysis',
#  'Sales',
#  'Sales Funnel-Management',
#  'Sanitär- und Versorgungstechnik',
#  'Schreinern',
#  'Schweißen',
#  'Smart Services & servicelastige Geschäftsmodelle',
#  'Social Media Management & Plattformstrategie',
#  'Social Media Marketing',
#  'Softwareentwicklung',
#  'Stakeholder Management',
#  'Stein- und Plattenlegehandwerk',
#  'Storytelling',
#  'Strategy Planning',
#  'Suchmaschinenmarketing (SEO & SEA / Google)',
#  'Suchmaschinenoptimierung (SEO)',
#  'Supply Chain Management',
#  'Systems Analysis',
#  'Systemverwaltung',
#  'Texterstellung',
#  'UX / UI Design',
#  'Unternehmensführung',
#  'Vendor Management',
#  'Vermarktung von Wohn- und Gewerbeimmobilien im Bestand',
#  'Videoproduktion',
#  'Visual Design',
#  'Web-Entwicklung',
#  'WebSocket',
#  'Webentwicklung',
#  'Wettbewerbsanalyse',
#  'Wissensmanagement',
#  'Zielgruppenanalyse',
#  'Zielgruppenanalyse & Konsumentenverhalten']

# %%
from copy import deepcopy
from tqdm import tqdm

# Create deep copy to avoid mutating freetext-enhanced baseline.
queries_with_synonyms = deepcopy(queries_with_freetext)

# Iterate over clusters and enrich with synonym-based variations.
for cluster in tqdm(queries_with_synonyms, desc="Add Synonyms"):

    # ---------- SINGLE ----------
    for single in cluster["single"]:
        keyword = single["keyword"]
        print("Original Keyword: ", keyword)

        # Generate synonym for single keyword via structured LLM call.
        formatted_messages = chat_prompt_single.format_messages(
            query=keyword,
            blacklist=unique_skills
        )
        response = model_with_structure_single_keyword.invoke(formatted_messages)
        print(response)

        synonym_keyword = response.synonym_keyword

        # Build freetext formulation based on synonym.
        freetext = (
            f"Gesucht wird ein Experte mit Fähigkeiten im Bereich "
            f"{synonym_keyword}"
        )

        # Extend baseline variations with synonym-based variants.
        for var in single["variations"]:
            print(var["type"])

            # Keyword-based variant.
            if var["type"] == "single_keyword":
                new_var = make_synonym_variation(var, synonym_keyword)
                single["variations"].append(new_var)

            # Freetext-based variant.
            if var["type"] == "single_free":
                new_var = make_synonym_variation(var, freetext)
                single["variations"].append(new_var)

    # ---------- COMBINATION ----------
    for comb in cluster["combination"]:
        keywords = comb["keywords"]
        print("Original Keywords: ", keywords)

        # Generate synonym pair for keyword combination.
        formatted_messages = chat_prompt_combi.format_messages(
            query=keywords,
            blacklist=unique_skills
        )
        response = model_with_structure_combinations.invoke(formatted_messages)
        print(response)

        synonym_keywords = response.synonym_keywords

        # Build freetext formulation for synonym combination.
        freetext = (
            f"Gesucht wird ein Experte mit Fähigkeiten in den Bereichen "
            f"{synonym_keywords[0]} und {synonym_keywords[1]}"
        )

        # Extend baseline variations with synonym-based variants.
        for var in comb["variations"]:

            if var["type"] == "combination_keyword":
                print("create variation")
                new_var = make_synonym_variation(var, freetext)
                comb["variations"].append(new_var)

            if var["type"] == "combination_free":
                print("create variation")
                new_var = make_synonym_variation(var, freetext)
                comb["variations"].append(new_var)
# Out:
# Add Synonyms:   0%|          | 0/11 [00:00<?, ?it/s]
# Original Keyword:  IT-Systemadministration
# synonym_keyword='Serveradministration'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Information Technology
# synonym_keyword='Computing'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Wissensmanagement
# Add Synonyms:   9%|▉         | 1/11 [00:42<07:07, 42.78s/it]
# synonym_keyword='Wissensverwaltung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Konstruktion
# synonym_keyword='Aufbau'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Metallhandwerk
# synonym_keyword='Metallbearbeitung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Mechanik
# synonym_keyword='Maschinenbau'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Automatisierungstechnik
# synonym_keyword='Automatisierungstechnologie'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Elektrotechnik
# synonym_keyword='Elektroingenieurwesen'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Konstruktion', 'Metallhandwerk']
# synonym_keywords=['Errichtung', 'Metallverarbeitung']
# create variation
# create variation
# Original Keywords:  ['Mechanik', 'Elektrotechnik']
# synonym_keywords=['Machinenbau', 'Elektronik']
# create variation
# create variation
# Original Keywords:  ['Metallhandwerk', 'Mechanik']
# synonym_keywords=['Metallbearbeitung', 'Maschinentechnik']
# create variation
# create variation
# Original Keywords:  ['Metallhandwerk', 'Elektrotechnik']
# synonym_keywords=['Metallverarbeitung', 'Elektroniktechnik']
# create variation
# create variation
# Original Keywords:  ['Mechanik', 'Automatisierungstechnik']
# synonym_keywords=['Kinematik', 'Fabrikautomatisierung']
# create variation
# create variation
# Original Keywords:  ['Automatisierungstechnik', 'Elektrotechnik']
# Add Synonyms:  18%|█▊        | 2/11 [04:59<25:19, 168.86s/it]
# synonym_keywords=['Automatisierung', 'Elektronik']
# create variation
# create variation
# Original Keyword:  KI
# Add Synonyms:  27%|██▋       | 3/11 [05:11<12:56, 97.11s/it]
# synonym_keyword='AI'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Public Relations
# synonym_keyword='Öffentlichkeitsarbeit'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Sales
# synonym_keyword='Verkauf'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Social Media Marketing
# synonym_keyword='SoMeWerbung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Public Relations', 'Social Media Marketing']
# Add Synonyms:  36%|███▋      | 4/11 [06:45<11:09, 95.69s/it]
# synonym_keywords=['Pressearbeit', 'Social-Media-Werbung']
# create variation
# create variation
# Original Keyword:  Marketing
# synonym_keyword='Absatzförderung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Brand Management
# synonym_keyword='Markenführung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Marketing', 'Social Media Marketing']
# synonym_keywords=['Absatzförderung', 'Werbung in sozialen Netzwerken']
# create variation
# create variation
# Original Keywords:  ['Marketing', 'Brand Management']
# synonym_keywords=['Vermarktung', 'Markenführung']
# create variation
# create variation
# Original Keywords:  ['Social Media Marketing', 'Brand Management']
# Add Synonyms:  45%|████▌     | 5/11 [08:59<10:57, 109.54s/it]
# synonym_keywords=['Soziale Netzwerke-Werbung', 'Markenführung']
# create variation
# create variation
# Original Keyword:  Employee Development
# synonym_keyword='Mitarbeiterentwicklung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Personalentwicklung und Mentoring
# synonym_keyword='Mitarbeiterentwicklung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Human Resources
# synonym_keyword='Personalwesen'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Coaching
# synonym_keyword='Mentoring'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Business Development', 'Employee Development']
# synonym_keywords=['Geschäftsentwicklung', 'Mitarbeiterentwicklung']
# create variation
# create variation
# Original Keywords:  ['Business Development', 'Personalentwicklung und Mentoring']
# synonym_keywords=['Unternehmensentwicklung', 'Mitarbeiterentwicklung und Begleitung']
# create variation
# create variation
# Original Keywords:  ['Business Development', 'Human Resources']
# synonym_keywords=['Geschäftsentwicklung', 'Personalwesen']
# create variation
# create variation
# Original Keywords:  ['Business Development', 'Coaching']
# synonym_keywords=['Geschäftsentwicklung', 'Beratung']
# create variation
# create variation
# Original Keywords:  ['Employee Development', 'Personalentwicklung und Mentoring']
# synonym_keywords=['Mitarbeiterentwicklung', 'Mitarbeiterentwicklung und Begleitung']
# create variation
# create variation
# Original Keywords:  ['Employee Development', 'Human Resources']
# synonym_keywords=['Talent Development', 'People Operations']
# create variation
# create variation
# Original Keywords:  ['Employee Development', 'Coaching']
# synonym_keywords=['Staff Development', 'Mentoring']
# create variation
# create variation
# Original Keywords:  ['Personalentwicklung und Mentoring', 'Human Resources']
# synonym_keywords=['Belegschaftsentwicklung und Begleitung', 'Personalwesen']
# create variation
# create variation
# Original Keywords:  ['Personalentwicklung und Mentoring', 'Coaching']
# synonym_keywords=['Mitarbeiterentwicklung und Begleitung', 'Beratung']
# create variation
# create variation
# Original Keywords:  ['Human Resources', 'Coaching']
# Add Synonyms:  55%|█████▍    | 6/11 [13:40<14:00, 168.09s/it]
# synonym_keywords=['Personalwesen', 'Mentoring']
# create variation
# create variation
# Original Keyword:  Bau- und Ausbauhandwerk
# synonym_keyword='Bauberufe'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Holzhandwerk
# synonym_keyword='Schreinerei'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Anlagenbau
# synonym_keyword='Industrieanlagenbau'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Bau- und Ausbauhandwerk', 'Anlagenbau']
# Add Synonyms:  64%|██████▎   | 7/11 [14:45<08:57, 134.39s/it]
# synonym_keywords=['Baugewerbe', 'Anlagentechnik']
# create variation
# create variation
# Original Keyword:  Finance
# synonym_keyword='Finances'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Financial Management
# synonym_keyword='Finanzmanagement'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Budget Planning
# synonym_keyword='Budgetierung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Business Planning', 'Finance']
# synonym_keywords=['Unternehmensplanung', 'Finanzen']
# create variation
# create variation
# Original Keywords:  ['Business Planning', 'Financial Management']
# synonym_keywords=['Unternehmensplanung', 'Finanzsteuerung']
# create variation
# create variation
# Original Keywords:  ['Business Planning', 'Budget Planning']
# synonym_keywords=['Corporate Strategy', 'Cost Forecasting']
# create variation
# create variation
# Original Keywords:  ['Business Planning', 'Business Development']
# synonym_keywords=['Unternehmensplanung', 'Unternehmensentwicklung']
# create variation
# create variation
# Original Keywords:  ['Finance', 'Financial Management']
# synonym_keywords=['Treasury management', 'Fiscal management']
# create variation
# create variation
# Original Keywords:  ['Finance', 'Budget Planning']
# synonym_keywords=['Finances', 'Budget Management']
# create variation
# create variation
# Original Keywords:  ['Finance', 'Business Development']
# synonym_keywords=['Funding', 'Expansion']
# create variation
# create variation
# Original Keywords:  ['Financial Management', 'Budget Planning']
# synonym_keywords=['Fiscal Management', 'Budget Forecasting']
# create variation
# create variation
# Original Keywords:  ['Financial Management', 'Business Development']
# synonym_keywords=['Finanzmanagement', 'Geschäftsentwicklung']
# create variation
# create variation
# Original Keywords:  ['Budget Planning', 'Business Development']
# Add Synonyms:  73%|███████▎  | 8/11 [19:32<09:08, 182.77s/it]
# synonym_keywords=['Budget forecasting', 'Corporate growth']
# create variation
# create variation
# Original Keyword:  Business Planning
# synonym_keyword='Unternehmensplanung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Business Development
# synonym_keyword='Geschäftsentwicklung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Controlling
# synonym_keyword='Steuerung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Change Management', 'Business Planning']
# synonym_keywords=['Veränderungsmanagement', 'Unternehmensplanung']
# create variation
# create variation
# Original Keywords:  ['Change Management', 'Business Development']
# synonym_keywords=['Veränderungsmanagement', 'Geschäftsentwicklung']
# create variation
# create variation
# Original Keywords:  ['Change Management', 'Controlling']
# synonym_keywords=['Veränderungsmanagement', 'Kostenkontrolle']
# create variation
# create variation
# Original Keywords:  ['Business Planning', 'Controlling']
# synonym_keywords=['Unternehmensplanung', 'Kostenkontrolle']
# create variation
# create variation
# Original Keywords:  ['Business Development', 'Controlling']
# Add Synonyms:  82%|████████▏ | 9/11 [22:02<05:45, 172.52s/it]
# synonym_keywords=['Geschäftsentwicklung', 'Finanzsteuerung']
# create variation
# create variation
# Original Keyword:  Cloud-Computing
# synonym_keyword='Wolkenrechenleistung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  IT-Management
# synonym_keyword='Informationsmanagement'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Datenbankverwaltung
# synonym_keyword='Datenbankadministration'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Softwareentwicklung
# synonym_keyword='Anwendungsentwicklung'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Data Analysis
# synonym_keyword='Datenanalyse'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Cloud-Computing', 'IT-Management']
# synonym_keywords=['Cloud-Dienste', 'IT-Führung']
# create variation
# create variation
# Original Keywords:  ['Cloud-Computing', 'Digital Ethics']
# synonym_keywords=['Cloud-Dienste', 'Digitale Ethik']
# create variation
# create variation
# Original Keywords:  ['Cloud-Computing', 'Datenbankverwaltung']
# synonym_keywords=['Cloud-Dienste', 'Datenbankadministration']
# create variation
# create variation
# Original Keywords:  ['Cloud-Computing', 'Softwareentwicklung']
# synonym_keywords=['Wolkenbasierte Dienste', 'Anwendungsentwicklung']
# create variation
# create variation
# Original Keywords:  ['Cloud-Computing', 'Data Analysis']
# synonym_keywords=['Wolkenbasierte Dienste', 'Datenanalyse']
# create variation
# create variation
# Original Keywords:  ['IT-Management', 'Softwareentwicklung']
# synonym_keywords=['IT-Governance', 'Anwendungsentwicklung']
# create variation
# create variation
# Original Keywords:  ['IT-Management', 'Data Analysis']
# synonym_keywords=['Informationsmanagement', 'Datenanalyse']
# create variation
# create variation
# Original Keywords:  ['Softwareentwicklung', 'Data Analysis']
# Add Synonyms:  91%|█████████ | 10/11 [25:54<03:10, 190.89s/it]
# synonym_keywords=['Softwaretechnik', 'Datenanalyse']
# create variation
# create variation
# Original Keyword:  Change Management
# synonym_keyword='Veränderungsmanagement'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Digital Ethics
# synonym_keyword='Digitalethik'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keyword:  Business Process Analysis
# synonym_keyword='Prozessanalyse'
# single_keyword
# single_free
# single_keyword_synonym
# single_free_synonym
# Original Keywords:  ['Change Management', 'Digital Ethics']
# synonym_keywords=['Veränderungsmanagement', 'Ethik der Digitalisierung']
# create variation
# create variation
# Original Keywords:  ['Change Management', 'Business Process Analysis']
# synonym_keywords=['Veränderungsmanagement', 'Geschäftsprozessanalyse']
# create variation
# create variation
# Original Keywords:  ['Digital Ethics', 'Business Development']
# synonym_keywords=['Technologieethik', 'Geschäftsentwicklung']
# create variation
# create variation
# Original Keywords:  ['Business Planning', 'Business Process Analysis']
# synonym_keywords=['Strategic Planning', 'Workflow Analysis']
# create variation
# create variation
# Original Keywords:  ['Business Development', 'Business Process Analysis']
# Add Synonyms: 100%|██████████| 11/11 [28:26<00:00, 155.17s/it]
# synonym_keywords=['Geschäftsentwicklung', 'Geschäftsprozessanalyse']
# create variation
# create variation

# %%
queries_with_synonyms
# Out:
# [{'id': 'c0',
#   'cluster': 'cluster_0',
#   'topic': 'IT-Management und Wissensmanagement',
#   'single': [{'id': 'c0_1_single',
#     'keyword': 'IT-Systemadministration',
#     'variations': [{'id': 'c0_1_single_keyword',
#       'query': 'IT-Systemadministration',
#       'type': 'single_keyword'},
#      {'id': 'c0_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich IT-Systemadministration',
#       'type': 'single_free'},
#      {'id': 'c0_1_single_keyword_synonym',
#       'query': 'Netzwerkadministration',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c0_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Netzwerkadministration',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c0_2_single',
#     'keyword': 'Information Technology',
#     'variations': [{'id': 'c0_2_single_keyword',
#       'query': 'Information Technology',
#       'type': 'single_keyword'},
#      {'id': 'c0_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Information Technology',
#       'type': 'single_free'},
#      {'id': 'c0_2_single_keyword_synonym',
#       'query': 'Computing',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c0_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Computing',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c0_3_single',
#     'keyword': 'Wissensmanagement',
#     'variations': [{'id': 'c0_3_single_keyword',
#       'query': 'Wissensmanagement',
#       'type': 'single_keyword'},
#      {'id': 'c0_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wissensmanagement',
#       'type': 'single_free'},
#      {'id': 'c0_3_single_keyword_synonym',
#       'query': 'Wissenverwaltung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c0_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wissenverwaltung',
#       'type': 'single_free_synonym'}]}],
#   'combination': []},
#  {'id': 'c1',
#   'cluster': 'cluster_1',
#   'topic': 'Mechanik-, Elektro- und Automatisierungstechnik',
#   'single': [{'id': 'c1_1_single',
#     'keyword': 'Konstruktion',
#     'variations': [{'id': 'c1_1_single_keyword',
#       'query': 'Konstruktion',
#       'type': 'single_keyword'},
#      {'id': 'c1_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Konstruktion',
#       'type': 'single_free'},
#      {'id': 'c1_1_single_keyword_synonym',
#       'query': 'Aufbau',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c1_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Aufbau',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c1_2_single',
#     'keyword': 'Metallhandwerk',
#     'variations': [{'id': 'c1_2_single_keyword',
#       'query': 'Metallhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c1_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Metallhandwerk',
#       'type': 'single_free'},
#      {'id': 'c1_2_single_keyword_synonym',
#       'query': 'Metallbearbeitung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c1_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Metallbearbeitung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c1_3_single',
#     'keyword': 'Mechanik',
#     'variations': [{'id': 'c1_3_single_keyword',
#       'query': 'Mechanik',
#       'type': 'single_keyword'},
#      {'id': 'c1_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Mechanik',
#       'type': 'single_free'},
#      {'id': 'c1_3_single_keyword_synonym',
#       'query': 'Kinematik',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c1_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Kinematik',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c1_4_single',
#     'keyword': 'Automatisierungstechnik',
#     'variations': [{'id': 'c1_4_single_keyword',
#       'query': 'Automatisierungstechnik',
#       'type': 'single_keyword'},
#      {'id': 'c1_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Automatisierungstechnik',
#       'type': 'single_free'},
#      {'id': 'c1_4_single_keyword_synonym',
#       'query': 'Automatisierung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c1_4_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Automatisierung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c1_5_single',
#     'keyword': 'Elektrotechnik',
#     'variations': [{'id': 'c1_5_single_keyword',
#       'query': 'Elektrotechnik',
#       'type': 'single_keyword'},
#      {'id': 'c1_5_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Elektrotechnik',
#       'type': 'single_free'},
#      {'id': 'c1_5_single_keyword_synonym',
#       'query': 'Elektronik',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c1_5_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Elektronik',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c1_1_combination',
#     'keywords': ['Konstruktion', 'Metallhandwerk'],
#     'variations': [{'id': 'c1_1_combination_keyword',
#       'query': 'Konstruktion, Metallhandwerk',
#       'type': 'combination_keyword'},
#      {'id': 'c1_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Konstruktion und Metallhandwerk',
#       'type': 'combination_free'},
#      {'id': 'c1_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Aufbau und Metallbearbeitung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Aufbau und Metallbearbeitung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c1_2_combination',
#     'keywords': ['Mechanik', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_2_combination_keyword',
#       'query': 'Mechanik, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mechanik und Elektrotechnik',
#       'type': 'combination_free'},
#      {'id': 'c1_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Maschinenbau und Elektronik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Maschinenbau und Elektronik',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c1_3_combination',
#     'keywords': ['Metallhandwerk', 'Mechanik'],
#     'variations': [{'id': 'c1_3_combination_keyword',
#       'query': 'Metallhandwerk, Mechanik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallhandwerk und Mechanik',
#       'type': 'combination_free'},
#      {'id': 'c1_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallbearbeitung und Maschinenbau',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallbearbeitung und Maschinenbau',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c1_4_combination',
#     'keywords': ['Metallhandwerk', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_4_combination_keyword',
#       'query': 'Metallhandwerk, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallhandwerk und Elektrotechnik',
#       'type': 'combination_free'},
#      {'id': 'c1_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallbearbeitung und Elektroniktechnik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Metallbearbeitung und Elektroniktechnik',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c1_5_combination',
#     'keywords': ['Mechanik', 'Automatisierungstechnik'],
#     'variations': [{'id': 'c1_5_combination_keyword',
#       'query': 'Mechanik, Automatisierungstechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mechanik und Automatisierungstechnik',
#       'type': 'combination_free'},
#      {'id': 'c1_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Kinematik und Steuerungstechnik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_5_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Kinematik und Steuerungstechnik',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c1_6_combination',
#     'keywords': ['Automatisierungstechnik', 'Elektrotechnik'],
#     'variations': [{'id': 'c1_6_combination_keyword',
#       'query': 'Automatisierungstechnik, Elektrotechnik',
#       'type': 'combination_keyword'},
#      {'id': 'c1_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Automatisierungstechnik und Elektrotechnik',
#       'type': 'combination_free'},
#      {'id': 'c1_6_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Robotik und Elektrische Technik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c1_6_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Robotik und Elektrische Technik',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c3',
#   'cluster': 'cluster_3',
#   'topic': 'Künstliche Intelligenz',
#   'single': [{'id': 'c3_1_single',
#     'keyword': 'KI',
#     'variations': [{'id': 'c3_1_single_keyword',
#       'query': 'KI',
#       'type': 'single_keyword'},
#      {'id': 'c3_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich KI',
#       'type': 'single_free'},
#      {'id': 'c3_1_single_keyword_synonym',
#       'query': 'KünstlicheIntelligenz',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c3_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich KünstlicheIntelligenz',
#       'type': 'single_free_synonym'}]}],
#   'combination': []},
#  {'id': 'c5',
#   'cluster': 'cluster_5',
#   'topic': 'Verkauf, Kommunikation und Marketing',
#   'single': [{'id': 'c5_1_single',
#     'keyword': 'Public Relations',
#     'variations': [{'id': 'c5_1_single_keyword',
#       'query': 'Public Relations',
#       'type': 'single_keyword'},
#      {'id': 'c5_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Public Relations',
#       'type': 'single_free'},
#      {'id': 'c5_1_single_keyword_synonym',
#       'query': 'Öffentlichkeitsarbeit',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c5_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Öffentlichkeitsarbeit',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c5_2_single',
#     'keyword': 'Sales',
#     'variations': [{'id': 'c5_2_single_keyword',
#       'query': 'Sales',
#       'type': 'single_keyword'},
#      {'id': 'c5_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Sales',
#       'type': 'single_free'},
#      {'id': 'c5_2_single_keyword_synonym',
#       'query': 'Vertrieb',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c5_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Vertrieb',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c5_3_single',
#     'keyword': 'Social Media Marketing',
#     'variations': [{'id': 'c5_3_single_keyword',
#       'query': 'Social Media Marketing',
#       'type': 'single_keyword'},
#      {'id': 'c5_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Social Media Marketing',
#       'type': 'single_free'},
#      {'id': 'c5_3_single_keyword_synonym',
#       'query': 'SMM',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c5_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich SMM',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c5_1_combination',
#     'keywords': ['Public Relations', 'Social Media Marketing'],
#     'variations': [{'id': 'c5_1_combination_keyword',
#       'query': 'Public Relations, Social Media Marketing',
#       'type': 'combination_keyword'},
#      {'id': 'c5_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Public Relations und Social Media Marketing',
#       'type': 'combination_free'},
#      {'id': 'c5_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Öffentlichkeitsarbeit und Soziale-Medien-Werbung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c5_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Öffentlichkeitsarbeit und Soziale-Medien-Werbung',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c6',
#   'cluster': 'cluster_6',
#   'topic': 'Digitales Marketing und Markenkommunikation',
#   'single': [{'id': 'c6_1_single',
#     'keyword': 'Marketing',
#     'variations': [{'id': 'c6_1_single_keyword',
#       'query': 'Marketing',
#       'type': 'single_keyword'},
#      {'id': 'c6_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Marketing',
#       'type': 'single_free'},
#      {'id': 'c6_1_single_keyword_synonym',
#       'query': 'Vermarktung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c6_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Vermarktung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c6_2_single',
#     'keyword': 'Brand Management',
#     'variations': [{'id': 'c6_2_single_keyword',
#       'query': 'Brand Management',
#       'type': 'single_keyword'},
#      {'id': 'c6_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Brand Management',
#       'type': 'single_free'},
#      {'id': 'c6_2_single_keyword_synonym',
#       'query': 'Markenführung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c6_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Markenführung',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c6_1_combination',
#     'keywords': ['Marketing', 'Social Media Marketing'],
#     'variations': [{'id': 'c6_1_combination_keyword',
#       'query': 'Marketing, Social Media Marketing',
#       'type': 'combination_keyword'},
#      {'id': 'c6_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Marketing und Social Media Marketing',
#       'type': 'combination_free'},
#      {'id': 'c6_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung und Online-Werbung in sozialen Netzwerken',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c6_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung und Online-Werbung in sozialen Netzwerken',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c6_2_combination',
#     'keywords': ['Marketing', 'Brand Management'],
#     'variations': [{'id': 'c6_2_combination_keyword',
#       'query': 'Marketing, Brand Management',
#       'type': 'combination_keyword'},
#      {'id': 'c6_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Marketing und Brand Management',
#       'type': 'combination_free'},
#      {'id': 'c6_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung und Markenführung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c6_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung und Markenführung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c6_3_combination',
#     'keywords': ['Social Media Marketing', 'Brand Management'],
#     'variations': [{'id': 'c6_3_combination_keyword',
#       'query': 'Social Media Marketing, Brand Management',
#       'type': 'combination_keyword'},
#      {'id': 'c6_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Social Media Marketing und Brand Management',
#       'type': 'combination_free'},
#      {'id': 'c6_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung sozialer Netzwerke und Markenführung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c6_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Vermarktung sozialer Netzwerke und Markenführung',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c7',
#   'cluster': 'cluster_7',
#   'topic': 'Personal- und Organisationsentwicklung',
#   'single': [{'id': 'c7_1_single',
#     'keyword': 'Employee Development',
#     'variations': [{'id': 'c7_1_single_keyword',
#       'query': 'Employee Development',
#       'type': 'single_keyword'},
#      {'id': 'c7_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Employee Development',
#       'type': 'single_free'},
#      {'id': 'c7_1_single_keyword_synonym',
#       'query': 'Mitarbeiterentwicklung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c7_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Mitarbeiterentwicklung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c7_2_single',
#     'keyword': 'Personalentwicklung und Mentoring',
#     'variations': [{'id': 'c7_2_single_keyword',
#       'query': 'Personalentwicklung und Mentoring',
#       'type': 'single_keyword'},
#      {'id': 'c7_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Personalentwicklung und Mentoring',
#       'type': 'single_free'},
#      {'id': 'c7_2_single_keyword_synonym',
#       'query': 'Mitarbeiterentwicklung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c7_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Mitarbeiterentwicklung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c7_3_single',
#     'keyword': 'Human Resources',
#     'variations': [{'id': 'c7_3_single_keyword',
#       'query': 'Human Resources',
#       'type': 'single_keyword'},
#      {'id': 'c7_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Human Resources',
#       'type': 'single_free'},
#      {'id': 'c7_3_single_keyword_synonym',
#       'query': 'Personalabteilung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c7_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Personalabteilung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c7_4_single',
#     'keyword': 'Coaching',
#     'variations': [{'id': 'c7_4_single_keyword',
#       'query': 'Coaching',
#       'type': 'single_keyword'},
#      {'id': 'c7_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Coaching',
#       'type': 'single_free'},
#      {'id': 'c7_4_single_keyword_synonym',
#       'query': 'Begleitung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c7_4_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Begleitung',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c7_1_combination',
#     'keywords': ['Business Development', 'Employee Development'],
#     'variations': [{'id': 'c7_1_combination_keyword',
#       'query': 'Business Development, Employee Development',
#       'type': 'combination_keyword'},
#      {'id': 'c7_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Employee Development',
#       'type': 'combination_free'},
#      {'id': 'c7_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mitarbeiterentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mitarbeiterentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_2_combination',
#     'keywords': ['Business Development', 'Personalentwicklung und Mentoring'],
#     'variations': [{'id': 'c7_2_combination_keyword',
#       'query': 'Business Development, Personalentwicklung und Mentoring',
#       'type': 'combination_keyword'},
#      {'id': 'c7_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Personalentwicklung und Mentoring',
#       'type': 'combination_free'},
#      {'id': 'c7_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mitarbeiterentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mitarbeiterentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_3_combination',
#     'keywords': ['Business Development', 'Human Resources'],
#     'variations': [{'id': 'c7_3_combination_keyword',
#       'query': 'Business Development, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Human Resources',
#       'type': 'combination_free'},
#      {'id': 'c7_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Corporate Growth und Talent Acquisition',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Corporate Growth und Talent Acquisition',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_4_combination',
#     'keywords': ['Business Development', 'Coaching'],
#     'variations': [{'id': 'c7_4_combination_keyword',
#       'query': 'Business Development, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Coaching',
#       'type': 'combination_free'},
#      {'id': 'c7_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mentoring',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Mentoring',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_5_combination',
#     'keywords': ['Employee Development', 'Personalentwicklung und Mentoring'],
#     'variations': [{'id': 'c7_5_combination_keyword',
#       'query': 'Employee Development, Personalentwicklung und Mentoring',
#       'type': 'combination_keyword'},
#      {'id': 'c7_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Personalentwicklung und Mentoring',
#       'type': 'combination_free'},
#      {'id': 'c7_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mitarbeiterförderung und Mentoring',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_5_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mitarbeiterförderung und Mentoring',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_6_combination',
#     'keywords': ['Employee Development', 'Human Resources'],
#     'variations': [{'id': 'c7_6_combination_keyword',
#       'query': 'Employee Development, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Human Resources',
#       'type': 'combination_free'},
#      {'id': 'c7_6_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Personalwesen',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_6_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Personalwesen',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_7_combination',
#     'keywords': ['Employee Development', 'Coaching'],
#     'variations': [{'id': 'c7_7_combination_keyword',
#       'query': 'Employee Development, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Employee Development und Coaching',
#       'type': 'combination_free'},
#      {'id': 'c7_7_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mentoring',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_7_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mentoring',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_8_combination',
#     'keywords': ['Personalentwicklung und Mentoring', 'Human Resources'],
#     'variations': [{'id': 'c7_8_combination_keyword',
#       'query': 'Personalentwicklung und Mentoring, Human Resources',
#       'type': 'combination_keyword'},
#      {'id': 'c7_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalentwicklung und Mentoring und Human Resources',
#       'type': 'combination_free'},
#      {'id': 'c7_8_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Begleitung und Personalwesen',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_8_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Begleitung und Personalwesen',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_9_combination',
#     'keywords': ['Personalentwicklung und Mentoring', 'Coaching'],
#     'variations': [{'id': 'c7_9_combination_keyword',
#       'query': 'Personalentwicklung und Mentoring, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_9_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalentwicklung und Mentoring und Coaching',
#       'type': 'combination_free'},
#      {'id': 'c7_9_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mentoring',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_9_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Mitarbeiterentwicklung und Mentoring',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c7_10_combination',
#     'keywords': ['Human Resources', 'Coaching'],
#     'variations': [{'id': 'c7_10_combination_keyword',
#       'query': 'Human Resources, Coaching',
#       'type': 'combination_keyword'},
#      {'id': 'c7_10_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Human Resources und Coaching',
#       'type': 'combination_free'},
#      {'id': 'c7_10_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalwesen und Mentoring',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c7_10_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Personalwesen und Mentoring',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c8',
#   'cluster': 'cluster_8',
#   'topic': 'Bau- und Handwerkstechnik',
#   'single': [{'id': 'c8_1_single',
#     'keyword': 'Bau- und Ausbauhandwerk',
#     'variations': [{'id': 'c8_1_single_keyword',
#       'query': 'Bau- und Ausbauhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c8_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Bau- und Ausbauhandwerk',
#       'type': 'single_free'},
#      {'id': 'c8_1_single_keyword_synonym',
#       'query': 'Bauhandwerk',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c8_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Bauhandwerk',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c8_2_single',
#     'keyword': 'Holzhandwerk',
#     'variations': [{'id': 'c8_2_single_keyword',
#       'query': 'Holzhandwerk',
#       'type': 'single_keyword'},
#      {'id': 'c8_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Holzhandwerk',
#       'type': 'single_free'},
#      {'id': 'c8_2_single_keyword_synonym',
#       'query': 'Holzverarbeitung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c8_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Holzverarbeitung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c8_3_single',
#     'keyword': 'Anlagenbau',
#     'variations': [{'id': 'c8_3_single_keyword',
#       'query': 'Anlagenbau',
#       'type': 'single_keyword'},
#      {'id': 'c8_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Anlagenbau',
#       'type': 'single_free'},
#      {'id': 'c8_3_single_keyword_synonym',
#       'query': 'Anlagentechnik',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c8_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Anlagentechnik',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c8_1_combination',
#     'keywords': ['Bau- und Ausbauhandwerk', 'Anlagenbau'],
#     'variations': [{'id': 'c8_1_combination_keyword',
#       'query': 'Bau- und Ausbauhandwerk, Anlagenbau',
#       'type': 'combination_keyword'},
#      {'id': 'c8_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Bau- und Ausbauhandwerk und Anlagenbau',
#       'type': 'combination_free'},
#      {'id': 'c8_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Baugewerbe und Anlagentechnik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c8_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Baugewerbe und Anlagentechnik',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c10',
#   'cluster': 'cluster_10',
#   'topic': 'Finanzmanagement und Unternehmensplanung',
#   'single': [{'id': 'c10_1_single',
#     'keyword': 'Finance',
#     'variations': [{'id': 'c10_1_single_keyword',
#       'query': 'Finance',
#       'type': 'single_keyword'},
#      {'id': 'c10_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Finance',
#       'type': 'single_free'},
#      {'id': 'c10_1_single_keyword_synonym',
#       'query': 'Finanzen',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c10_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Finanzen',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c10_2_single',
#     'keyword': 'Financial Management',
#     'variations': [{'id': 'c10_2_single_keyword',
#       'query': 'Financial Management',
#       'type': 'single_keyword'},
#      {'id': 'c10_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Financial Management',
#       'type': 'single_free'},
#      {'id': 'c10_2_single_keyword_synonym',
#       'query': 'Finanzmanagement',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c10_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Finanzmanagement',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c10_3_single',
#     'keyword': 'Budget Planning',
#     'variations': [{'id': 'c10_3_single_keyword',
#       'query': 'Budget Planning',
#       'type': 'single_keyword'},
#      {'id': 'c10_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Budget Planning',
#       'type': 'single_free'},
#      {'id': 'c10_3_single_keyword_synonym',
#       'query': 'Forecasting',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c10_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Forecasting',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c10_1_combination',
#     'keywords': ['Business Planning', 'Finance'],
#     'variations': [{'id': 'c10_1_combination_keyword',
#       'query': 'Business Planning, Finance',
#       'type': 'combination_keyword'},
#      {'id': 'c10_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Finance',
#       'type': 'combination_free'},
#      {'id': 'c10_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Strategy und Funding',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Strategy und Funding',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_2_combination',
#     'keywords': ['Business Planning', 'Financial Management'],
#     'variations': [{'id': 'c10_2_combination_keyword',
#       'query': 'Business Planning, Financial Management',
#       'type': 'combination_keyword'},
#      {'id': 'c10_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Financial Management',
#       'type': 'combination_free'},
#      {'id': 'c10_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Finanzmanagement',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Finanzmanagement',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_3_combination',
#     'keywords': ['Business Planning', 'Budget Planning'],
#     'variations': [{'id': 'c10_3_combination_keyword',
#       'query': 'Business Planning, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Budget Planning',
#       'type': 'combination_free'},
#      {'id': 'c10_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Budgetierung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Budgetierung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_4_combination',
#     'keywords': ['Business Planning', 'Business Development'],
#     'variations': [{'id': 'c10_4_combination_keyword',
#       'query': 'Business Planning, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c10_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Unternehmensentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Unternehmensentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_5_combination',
#     'keywords': ['Finance', 'Financial Management'],
#     'variations': [{'id': 'c10_5_combination_keyword',
#       'query': 'Finance, Financial Management',
#       'type': 'combination_keyword'},
#      {'id': 'c10_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Financial Management',
#       'type': 'combination_free'},
#      {'id': 'c10_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Capital und Administration',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_5_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Capital und Administration',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_6_combination',
#     'keywords': ['Finance', 'Budget Planning'],
#     'variations': [{'id': 'c10_6_combination_keyword',
#       'query': 'Finance, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Budget Planning',
#       'type': 'combination_free'},
#      {'id': 'c10_6_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Funding und Budget Allocation',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_6_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Funding und Budget Allocation',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_7_combination',
#     'keywords': ['Finance', 'Business Development'],
#     'variations': [{'id': 'c10_7_combination_keyword',
#       'query': 'Finance, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Finance und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c10_7_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Treasury und Growth',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_7_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Treasury und Growth',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_8_combination',
#     'keywords': ['Financial Management', 'Budget Planning'],
#     'variations': [{'id': 'c10_8_combination_keyword',
#       'query': 'Financial Management, Budget Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c10_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Financial Management und Budget Planning',
#       'type': 'combination_free'},
#      {'id': 'c10_8_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Fiscal Administration und Budget Forecasting',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_8_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Fiscal Administration und Budget Forecasting',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_9_combination',
#     'keywords': ['Financial Management', 'Business Development'],
#     'variations': [{'id': 'c10_9_combination_keyword',
#       'query': 'Financial Management, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_9_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Financial Management und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c10_9_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Fiscal Management und Market Development',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_9_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Fiscal Management und Market Development',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c10_10_combination',
#     'keywords': ['Budget Planning', 'Business Development'],
#     'variations': [{'id': 'c10_10_combination_keyword',
#       'query': 'Budget Planning, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c10_10_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Budget Planning und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c10_10_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Funding und Expansion',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c10_10_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Funding und Expansion',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c11',
#   'cluster': 'cluster_11',
#   'topic': 'Strategische Unternehmensführung und Veränderungsmanagement',
#   'single': [{'id': 'c11_1_single',
#     'keyword': 'Business Planning',
#     'variations': [{'id': 'c11_1_single_keyword',
#       'query': 'Business Planning',
#       'type': 'single_keyword'},
#      {'id': 'c11_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Planning',
#       'type': 'single_free'},
#      {'id': 'c11_1_single_keyword_synonym',
#       'query': 'Unternehmensplanung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c11_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Unternehmensplanung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c11_2_single',
#     'keyword': 'Business Development',
#     'variations': [{'id': 'c11_2_single_keyword',
#       'query': 'Business Development',
#       'type': 'single_keyword'},
#      {'id': 'c11_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Development',
#       'type': 'single_free'},
#      {'id': 'c11_2_single_keyword_synonym',
#       'query': 'Geschäftsentwicklung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c11_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Geschäftsentwicklung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c11_3_single',
#     'keyword': 'Controlling',
#     'variations': [{'id': 'c11_3_single_keyword',
#       'query': 'Controlling',
#       'type': 'single_keyword'},
#      {'id': 'c11_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Controlling',
#       'type': 'single_free'},
#      {'id': 'c11_3_single_keyword_synonym',
#       'query': 'Steuerung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c11_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Steuerung',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c11_1_combination',
#     'keywords': ['Change Management', 'Business Planning'],
#     'variations': [{'id': 'c11_1_combination_keyword',
#       'query': 'Change Management, Business Planning',
#       'type': 'combination_keyword'},
#      {'id': 'c11_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Planning',
#       'type': 'combination_free'},
#      {'id': 'c11_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Unternehmenskonzeption',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c11_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Unternehmenskonzeption',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c11_2_combination',
#     'keywords': ['Change Management', 'Business Development'],
#     'variations': [{'id': 'c11_2_combination_keyword',
#       'query': 'Change Management, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c11_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c11_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Geschäftsentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c11_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Geschäftsentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c11_3_combination',
#     'keywords': ['Change Management', 'Controlling'],
#     'variations': [{'id': 'c11_3_combination_keyword',
#       'query': 'Change Management, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Controlling',
#       'type': 'combination_free'},
#      {'id': 'c11_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Kostenkontrolle',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c11_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Kostenkontrolle',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c11_4_combination',
#     'keywords': ['Business Planning', 'Controlling'],
#     'variations': [{'id': 'c11_4_combination_keyword',
#       'query': 'Business Planning, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Controlling',
#       'type': 'combination_free'},
#      {'id': 'c11_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Kostenkontrolle',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c11_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Kostenkontrolle',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c11_5_combination',
#     'keywords': ['Business Development', 'Controlling'],
#     'variations': [{'id': 'c11_5_combination_keyword',
#       'query': 'Business Development, Controlling',
#       'type': 'combination_keyword'},
#      {'id': 'c11_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Controlling',
#       'type': 'combination_free'},
#      {'id': 'c11_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Markterschließung und Kostenkontrolle',
#       'type': 'combination_keyword_synonym'},
# ...
#      {'id': 'c12_1_single_keyword_synonym',
#       'query': 'Wolkencomputing',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c12_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wolkencomputing',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c12_2_single',
#     'keyword': 'IT-Management',
#     'variations': [{'id': 'c12_2_single_keyword',
#       'query': 'IT-Management',
#       'type': 'single_keyword'},
#      {'id': 'c12_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich IT-Management',
#       'type': 'single_free'},
#      {'id': 'c12_2_single_keyword_synonym',
#       'query': 'Informationsmanagement',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c12_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Informationsmanagement',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c12_3_single',
#     'keyword': 'Datenbankverwaltung',
#     'variations': [{'id': 'c12_3_single_keyword',
#       'query': 'Datenbankverwaltung',
#       'type': 'single_keyword'},
#      {'id': 'c12_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Datenbankverwaltung',
#       'type': 'single_free'},
#      {'id': 'c12_3_single_keyword_synonym',
#       'query': 'Datenbankmanagement',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c12_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Datenbankmanagement',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c12_4_single',
#     'keyword': 'Softwareentwicklung',
#     'variations': [{'id': 'c12_4_single_keyword',
#       'query': 'Softwareentwicklung',
#       'type': 'single_keyword'},
#      {'id': 'c12_4_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Softwareentwicklung',
#       'type': 'single_free'},
#      {'id': 'c12_4_single_keyword_synonym',
#       'query': 'Anwendungsentwicklung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c12_4_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Anwendungsentwicklung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c12_5_single',
#     'keyword': 'Data Analysis',
#     'variations': [{'id': 'c12_5_single_keyword',
#       'query': 'Data Analysis',
#       'type': 'single_keyword'},
#      {'id': 'c12_5_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Data Analysis',
#       'type': 'single_free'},
#      {'id': 'c12_5_single_keyword_synonym',
#       'query': 'Analytics',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c12_5_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Analytics',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c12_1_combination',
#     'keywords': ['Cloud-Computing', 'IT-Management'],
#     'variations': [{'id': 'c12_1_combination_keyword',
#       'query': 'Cloud-Computing, IT-Management',
#       'type': 'combination_keyword'},
#      {'id': 'c12_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und IT-Management',
#       'type': 'combination_free'},
#      {'id': 'c12_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolken-Dienste und IT-Führung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolken-Dienste und IT-Führung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_2_combination',
#     'keywords': ['Cloud-Computing', 'Digital Ethics'],
#     'variations': [{'id': 'c12_2_combination_keyword',
#       'query': 'Cloud-Computing, Digital Ethics',
#       'type': 'combination_keyword'},
#      {'id': 'c12_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Digital Ethics',
#       'type': 'combination_free'},
#      {'id': 'c12_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolkenbasierte Infrastruktur und Digitale Ethik',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolkenbasierte Infrastruktur und Digitale Ethik',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_3_combination',
#     'keywords': ['Cloud-Computing', 'Datenbankverwaltung'],
#     'variations': [{'id': 'c12_3_combination_keyword',
#       'query': 'Cloud-Computing, Datenbankverwaltung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Datenbankverwaltung',
#       'type': 'combination_free'},
#      {'id': 'c12_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolkenrechnen und Datenbankadministration',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolkenrechnen und Datenbankadministration',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_4_combination',
#     'keywords': ['Cloud-Computing', 'Softwareentwicklung'],
#     'variations': [{'id': 'c12_4_combination_keyword',
#       'query': 'Cloud-Computing, Softwareentwicklung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Softwareentwicklung',
#       'type': 'combination_free'},
#      {'id': 'c12_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Dienste und Anwendungsentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Dienste und Anwendungsentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_5_combination',
#     'keywords': ['Cloud-Computing', 'Data Analysis'],
#     'variations': [{'id': 'c12_5_combination_keyword',
#       'query': 'Cloud-Computing, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Cloud-Computing und Data Analysis',
#       'type': 'combination_free'},
#      {'id': 'c12_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolken-Dienste und Datenanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_5_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Wolken-Dienste und Datenanalyse',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_6_combination',
#     'keywords': ['IT-Management', 'Softwareentwicklung'],
#     'variations': [{'id': 'c12_6_combination_keyword',
#       'query': 'IT-Management, Softwareentwicklung',
#       'type': 'combination_keyword'},
#      {'id': 'c12_6_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Management und Softwareentwicklung',
#       'type': 'combination_free'},
#      {'id': 'c12_6_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Governance und Anwendungsentwicklung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_6_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Governance und Anwendungsentwicklung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_7_combination',
#     'keywords': ['IT-Management', 'Data Analysis'],
#     'variations': [{'id': 'c12_7_combination_keyword',
#       'query': 'IT-Management, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_7_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen IT-Management und Data Analysis',
#       'type': 'combination_free'},
#      {'id': 'c12_7_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Informationsmanagement und Datenanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_7_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Informationsmanagement und Datenanalyse',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c12_8_combination',
#     'keywords': ['Softwareentwicklung', 'Data Analysis'],
#     'variations': [{'id': 'c12_8_combination_keyword',
#       'query': 'Softwareentwicklung, Data Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c12_8_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Softwareentwicklung und Data Analysis',
#       'type': 'combination_free'},
#      {'id': 'c12_8_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Anwendungsentwicklung und Datenanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c12_8_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Anwendungsentwicklung und Datenanalyse',
#       'type': 'combination_free_synonym'}]}]},
#  {'id': 'c13',
#   'cluster': 'cluster_13',
#   'topic': 'Digitale Transformations- und Innovationsstrategie',
#   'single': [{'id': 'c13_1_single',
#     'keyword': 'Change Management',
#     'variations': [{'id': 'c13_1_single_keyword',
#       'query': 'Change Management',
#       'type': 'single_keyword'},
#      {'id': 'c13_1_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Change Management',
#       'type': 'single_free'},
#      {'id': 'c13_1_single_keyword_synonym',
#       'query': 'Organisationsentwicklung',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c13_1_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Organisationsentwicklung',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c13_2_single',
#     'keyword': 'Digital Ethics',
#     'variations': [{'id': 'c13_2_single_keyword',
#       'query': 'Digital Ethics',
#       'type': 'single_keyword'},
#      {'id': 'c13_2_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Digital Ethics',
#       'type': 'single_free'},
#      {'id': 'c13_2_single_keyword_synonym',
#       'query': 'Datenethik',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c13_2_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Datenethik',
#       'type': 'single_free_synonym'}]},
#    {'id': 'c13_3_single',
#     'keyword': 'Business Process Analysis',
#     'variations': [{'id': 'c13_3_single_keyword',
#       'query': 'Business Process Analysis',
#       'type': 'single_keyword'},
#      {'id': 'c13_3_single_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Business Process Analysis',
#       'type': 'single_free'},
#      {'id': 'c13_3_single_keyword_synonym',
#       'query': 'Prozessanalyse',
#       'type': 'single_keyword_synonym'},
#      {'id': 'c13_3_single_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Prozessanalyse',
#       'type': 'single_free_synonym'}]}],
#   'combination': [{'id': 'c13_1_combination',
#     'keywords': ['Change Management', 'Digital Ethics'],
#     'variations': [{'id': 'c13_1_combination_keyword',
#       'query': 'Change Management, Digital Ethics',
#       'type': 'combination_keyword'},
#      {'id': 'c13_1_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Digital Ethics',
#       'type': 'combination_free'},
#      {'id': 'c13_1_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Ethik der Digitalisierung',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c13_1_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Ethik der Digitalisierung',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c13_2_combination',
#     'keywords': ['Change Management', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_2_combination_keyword',
#       'query': 'Change Management, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_2_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Change Management und Business Process Analysis',
#       'type': 'combination_free'},
#      {'id': 'c13_2_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Geschäftsprozessanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c13_2_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Veränderungsmanagement und Geschäftsprozessanalyse',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c13_3_combination',
#     'keywords': ['Digital Ethics', 'Business Development'],
#     'variations': [{'id': 'c13_3_combination_keyword',
#       'query': 'Digital Ethics, Business Development',
#       'type': 'combination_keyword'},
#      {'id': 'c13_3_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Digital Ethics und Business Development',
#       'type': 'combination_free'},
#      {'id': 'c13_3_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Tech Ethics und Market Expansion',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c13_3_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Tech Ethics und Market Expansion',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c13_4_combination',
#     'keywords': ['Business Planning', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_4_combination_keyword',
#       'query': 'Business Planning, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_4_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Planning und Business Process Analysis',
#       'type': 'combination_free'},
#      {'id': 'c13_4_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Unternehmensprozessanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c13_4_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Unternehmensplanung und Unternehmensprozessanalyse',
#       'type': 'combination_free_synonym'}]},
#    {'id': 'c13_5_combination',
#     'keywords': ['Business Development', 'Business Process Analysis'],
#     'variations': [{'id': 'c13_5_combination_keyword',
#       'query': 'Business Development, Business Process Analysis',
#       'type': 'combination_keyword'},
#      {'id': 'c13_5_combination_freetext',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Business Development und Business Process Analysis',
#       'type': 'combination_free'},
#      {'id': 'c13_5_combination_keyword_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Geschäftsprozessanalyse',
#       'type': 'combination_keyword_synonym'},
#      {'id': 'c13_5_combination_freetext_synonym',
#       'query': 'Gesucht wird ein Experte mit Fähigkeiten in den Bereichen Geschäftsentwicklung und Geschäftsprozessanalyse',
#       'type': 'combination_free_synonym'}]}]}]

# %%
import json

# Build output file path for final test collection.
file_path = PROD_DATA_PATH + "suchanfragen_testkollektion_final.json"

# Persist enriched query collection to JSON.
with open(file_path, "w", encoding="utf-8") as f:
    json.dump(queries_with_synonyms, f)

# Confirm successful write operation.
print(f"Saved data to {file_path}")
# Out:
# Saved data to drive/MyDrive/Uni/Master/Masterthesis/Data/topics/suchanfragen_testkollektion_final.json
