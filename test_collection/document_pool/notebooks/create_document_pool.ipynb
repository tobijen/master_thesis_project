# %% [markdown]
# # Pooling
#
# In diesem Notebook sollen relevante Dokumente für die Testkollektion gepooled werden

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "drive/MyDrive/Uni/Master/Masterthesis/Data/"
PROD_DATA_PATH = "drive/MyDrive/Uni/Master/Masterthesis/Data/topics/"
PATH_TEST_COLLECTION_DATA="drive/MyDrive/Uni/Master/Masterthesis/Data/test_collection/"

# %%
import pandas as pd

# %% [markdown]
# ## Import Queries

# %%
import json

# Build file path for final test collection.
file_path = PROD_DATA_PATH + "suchanfragen_testkollektion_final.json"

# Load enriched test collection from JSON.
with open(file_path, "r", encoding="utf-8") as f:
    queries_testcollection = json.load(f)

# Basic structural validation.
print(type(queries_testcollection))   # Expected: list or dict
print(len(queries_testcollection))    # Number of clusters
print(queries_testcollection[:2])     # Preview first two entries
# Out:
# <class 'list'>
# 11
# [{'id': 'c0', 'cluster': 'cluster_0', 'topic': 'IT-Management und Wissensmanagement', 'single': [{'id': 'c0_1_single', 'keyword': 'IT-Systemadministration', 'variations': [{'id': 'c0_1_single_keyword', 'query': 'IT-Systemadministration', 'type': 'single_keyword'}, {'id': 'c0_1_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich IT-Systemadministration', 'type': 'single_free'}, {'id': 'c0_1_single_keyword_synonym', 'query': 'Serveradministration', 'type': 'single_keyword_synonym'}, {'id': 'c0_1_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Serveradministration', 'type': 'single_free_synonym'}]}, {'id': 'c0_2_single', 'keyword': 'Information Technology', 'variations': [{'id': 'c0_2_single_keyword', 'query': 'Information Technology', 'type': 'single_keyword'}, {'id': 'c0_2_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Information Technology', 'type': 'single_free'}, {'id': 'c0_2_single_keyword_synonym', 'query': 'Computing', 'type': 'single_keyword_synonym'}, {'id': 'c0_2_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Computing', 'type': 'single_free_synonym'}]}, {'id': 'c0_3_single', 'keyword': 'Wissensmanagement', 'variations': [{'id': 'c0_3_single_keyword', 'query': 'Wissensmanagement', 'type': 'single_keyword'}, {'id': 'c0_3_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wissensmanagement', 'type': 'single_free'}, {'id': 'c0_3_single_keyword_synonym', 'query': 'Wissensverwaltung', 'type': 'single_keyword_synonym'}, {'id': 'c0_3_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Wissensverwaltung', 'type': 'single_free_synonym'}]}], 'combination': []}, {'id': 'c1', 'cluster': 'cluster_1', 'topic': 'Mechanik-, Elektro- und Automatisierungstechnik', 'single': [{'id': 'c1_1_single', 'keyword': 'Konstruktion', 'variations': [{'id': 'c1_1_single_keyword', 'query': 'Konstruktion', 'type': 'single_keyword'}, {'id': 'c1_1_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Konstruktion', 'type': 'single_free'}, {'id': 'c1_1_single_keyword_synonym', 'query': 'Aufbau', 'type': 'single_keyword_synonym'}, {'id': 'c1_1_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Aufbau', 'type': 'single_free_synonym'}]}, {'id': 'c1_2_single', 'keyword': 'Metallhandwerk', 'variations': [{'id': 'c1_2_single_keyword', 'query': 'Metallhandwerk', 'type': 'single_keyword'}, {'id': 'c1_2_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Metallhandwerk', 'type': 'single_free'}, {'id': 'c1_2_single_keyword_synonym', 'query': 'Metallbearbeitung', 'type': 'single_keyword_synonym'}, {'id': 'c1_2_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Metallbearbeitung', 'type': 'single_free_synonym'}]}, {'id': 'c1_3_single', 'keyword': 'Mechanik', 'variations': [{'id': 'c1_3_single_keyword', 'query': 'Mechanik', 'type': 'single_keyword'}, {'id': 'c1_3_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Mechanik', 'type': 'single_free'}, {'id': 'c1_3_single_keyword_synonym', 'query': 'Maschinenbau', 'type': 'single_keyword_synonym'}, {'id': 'c1_3_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Maschinenbau', 'type': 'single_free_synonym'}]}, {'id': 'c1_4_single', 'keyword': 'Automatisierungstechnik', 'variations': [{'id': 'c1_4_single_keyword', 'query': 'Automatisierungstechnik', 'type': 'single_keyword'}, {'id': 'c1_4_single_freetext', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Automatisierungstechnik', 'type': 'single_free'}, {'id': 'c1_4_single_keyword_synonym', 'query': 'Automatisierungstechnologie', 'type': 'single_keyword_synonym'}, {'id': 'c1_4_single_freetext_synonym', 'query': 'Gesucht wird ein Experte mit Fähigkeiten im Bereich Aut ...

# %% [markdown]
# ## Import Expertprofiles

# %%
import json

# Build file path for enhanced expert profiles.
file_path = DATA_PATH + "enhanced_expert_profiles.json"

# Load expert profile dataset from JSON.
with open(file_path, "r", encoding="utf-8") as f:
    expert_data = json.load(f)

# Basic structural validation.
print(type(expert_data))        # Expected: list or dict
print(len(expert_data))         # Number of expert entries
print(expert_data[0])           # Inspect first record
print(expert_data[0].keys())    # Inspect available fields
# Out:
# <class 'list'>
# 307
# {'branches': ['Technologie', 'Medien & Werbung', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Lennestadt', 'companyLocationStreet': 'Hagener Straße 64', 'companyLocationZip': 57368.0, 'companyName': 'lenne.Tech GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'https://lenne.tech', 'description': 'Seit über 15 Jahren begleite ich digitale Projekte von der Konzeption bis zur "schlüsselfertigen" Anwendung. Als Mitglied im Team von lenne.Tech (https://lenne.tech) entwickle ich Apps & Webanwendungen und unterstütze Unternehmen beim Aufbau sowie bei der Weiterbildung von Entwicklungsteams. Im Rahmen unserer lenne.Learning Akademie (https://lennelearning.de) organisiere ich gemeinsam mit anderen Tutoren & Mentoren das Recruiting sowie das Onboarding neuer Entwickler für Partnerunternehmen.', 'employeeOfInstitutionNames': [], 'firstName': 'Ege', 'gender': 'MALE', 'id': '65acfb5a3897d6f0e6506db1', 'jobTitle': 'Softwareentwickler', 'lastName': 'Siebert', 'projectsDescription': 'lenne.Tech unterstützt Unternehmen, Selbstständige, Bildungsinstitutionen und Gründungs- sowie Technikinteressierte bei allen Fragen rund um die Themen App- & Webentwicklung sowie Digitalisierung.', 'skills': ['Softwareentwicklung', 'Web-Entwicklung', 'IT-Systemadministration', 'Programmierkenntnisse', 'Design', 'Cloud-Computing', 'DevOps', 'Content Management', 'Data Analysis', 'Systemverwaltung'], 'title': None, 'full_text': 'Ege Siebert ist Softwareentwickler mit umfangreichen Kompetenzen in Softwareentwicklung, Web-Entwicklung, IT-Systemadministration, Programmierkenntnissen, Design, Cloud-Computing, DevOps, Content Management, Data Analysis und Systemverwaltung. Seit über 15 Jahren begleitet er digitale Projekte von der Konzeption bis zur schlüsselfertigen Anwendung. Als Mitglied des Teams von lenne.Tech (https://lenne.tech) entwickelt er Apps und Webanwendungen und unterstützt Unternehmen beim Aufbau sowie bei der Weiterbildung von Entwicklungsteams. Im Rahmen der lenne.Learning Akademie (https://lennelearning.de) organisiert er gemeinsam mit anderen Tutoren & Mentoren das Recruiting sowie das Onboarding neuer Entwickler für Partnerunternehmen. Die von lenne.Tech betreuten Projekte richten sich an Unternehmen, Selbstständige, Bildungsinstitutionen sowie Gründungs- und Technikinteressierte und behandeln Fragen rund um App- und Webentwicklung sowie Digitalisierung. Der Arbeitskontext umfasst Technologie, Medien & Werbung sowie Unternehmensdienstleistungen.', 'full_text_fields_used': ['branches', 'description', 'jobTitle', 'projectsDescription', 'skills'], 'validation_issues': 'OK', 'full_text_fields_used_fixed': ['skills', 'branches', 'description', 'projectsDescription', 'jobTitle'], 'full_text_word_count': 116.0, 'full_text_fields_used_sorted': ['branches', 'description', 'jobTitle', 'projectsDescription', 'skills']}
# dict_keys(['branches', 'companyLocationCity', 'companyLocationStreet', 'companyLocationZip', 'companyName', 'companyTypes', 'companyWebsite', 'description', 'employeeOfInstitutionNames', 'firstName', 'gender', 'id', 'jobTitle', 'lastName', 'projectsDescription', 'skills', 'title', 'full_text', 'full_text_fields_used', 'validation_issues', 'full_text_fields_used_fixed', 'full_text_word_count', 'full_text_fields_used_sorted'])

# %%
# only keep original data fields from experts
keys_to_remove = ["full_text_fields_used", "full_text_fields_used_fixed", "full_text_word_count", "full_text_fields_used_sorted", "validation_issues"]

expert_data = [
    {k: v for k, v in obj.items() if k not in keys_to_remove}
    for obj in expert_data
]

expert_data[0].keys()
# Out:
# dict_keys(['branches', 'companyLocationCity', 'companyLocationStreet', 'companyLocationZip', 'companyName', 'companyTypes', 'companyWebsite', 'description', 'employeeOfInstitutionNames', 'firstName', 'gender', 'id', 'jobTitle', 'lastName', 'projectsDescription', 'skills', 'title', 'full_text'])

# %% [markdown]
# ## Extract queries for pooling

# %%
def extract_keyword_queries(data):
    """
    Extrahiert alle Queries mit type == 'single_keyword' oder 'combination_keyword'
    aus der gegebenen JSON-Struktur.

    Args:
        data (list): JSON-Daten (Liste von Clustern)

    Returns:
        list: Liste der extrahierten Query-Strings
    """

    # Target variation types to extract.
    target_types = {"single_keyword", "combination_keyword"}

    queries = []

    # Iterate over clusters.
    for cluster in data:

        # Process single keyword variations.
        for single in cluster.get("single", []):
            for variation in single.get("variations", []):
                if variation.get("type") in target_types:
                    queries.append(variation.get("query"))

        # Process combination keyword variations.
        for combination in cluster.get("combination", []):
            for variation in combination.get("variations", []):
                if variation.get("type") in target_types:
                    queries.append(variation.get("query"))

    return queries

# %%
queries_for_pooling = extract_keyword_queries(queries_testcollection)
print(len(queries_for_pooling))
print(queries_for_pooling)
# Out:
# 84
# ['IT-Systemadministration', 'Information Technology', 'Wissensmanagement', 'Konstruktion', 'Metallhandwerk', 'Mechanik', 'Automatisierungstechnik', 'Elektrotechnik', 'Konstruktion, Metallhandwerk', 'Mechanik, Elektrotechnik', 'Metallhandwerk, Mechanik', 'Metallhandwerk, Elektrotechnik', 'Mechanik, Automatisierungstechnik', 'Automatisierungstechnik, Elektrotechnik', 'KI', 'Public Relations', 'Sales', 'Social Media Marketing', 'Public Relations, Social Media Marketing', 'Marketing', 'Brand Management', 'Marketing, Social Media Marketing', 'Marketing, Brand Management', 'Social Media Marketing, Brand Management', 'Employee Development', 'Personalentwicklung und Mentoring', 'Human Resources', 'Coaching', 'Business Development, Employee Development', 'Business Development, Personalentwicklung und Mentoring', 'Business Development, Human Resources', 'Business Development, Coaching', 'Employee Development, Personalentwicklung und Mentoring', 'Employee Development, Human Resources', 'Employee Development, Coaching', 'Personalentwicklung und Mentoring, Human Resources', 'Personalentwicklung und Mentoring, Coaching', 'Human Resources, Coaching', 'Bau- und Ausbauhandwerk', 'Holzhandwerk', 'Anlagenbau', 'Bau- und Ausbauhandwerk, Anlagenbau', 'Finance', 'Financial Management', 'Budget Planning', 'Business Planning, Finance', 'Business Planning, Financial Management', 'Business Planning, Budget Planning', 'Business Planning, Business Development', 'Finance, Financial Management', 'Finance, Budget Planning', 'Finance, Business Development', 'Financial Management, Budget Planning', 'Financial Management, Business Development', 'Budget Planning, Business Development', 'Business Planning', 'Business Development', 'Controlling', 'Change Management, Business Planning', 'Change Management, Business Development', 'Change Management, Controlling', 'Business Planning, Controlling', 'Business Development, Controlling', 'Cloud-Computing', 'IT-Management', 'Datenbankverwaltung', 'Softwareentwicklung', 'Data Analysis', 'Cloud-Computing, IT-Management', 'Cloud-Computing, Digital Ethics', 'Cloud-Computing, Datenbankverwaltung', 'Cloud-Computing, Softwareentwicklung', 'Cloud-Computing, Data Analysis', 'IT-Management, Softwareentwicklung', 'IT-Management, Data Analysis', 'Softwareentwicklung, Data Analysis', 'Change Management', 'Digital Ethics', 'Business Process Analysis', 'Change Management, Digital Ethics', 'Change Management, Business Process Analysis', 'Digital Ethics, Business Development', 'Business Planning, Business Process Analysis', 'Business Development, Business Process Analysis']

# %% [markdown]
# ## Import Qdrant Client

# %%
# !pip install -U sentence-transformers
# !pip install -U qdrant-client
# !pip install fastembed
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: qdrant-client in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (1.76.0)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (2.0.2)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (5.29.5)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (2.12.3)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.12/dist-packages (from qdrant-client) (2.5.0)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio>=1.41.0->qdrant-client) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.4.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: fastembed in /usr/local/lib/python3.12/dist-packages (0.7.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.20 in /usr/local/lib/python3.12/dist-packages (from fastembed) (0.36.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from fastembed) (0.7.3)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from fastembed) (5.2.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from fastembed) (2.0.2)
# Requirement already satisfied: onnxruntime!=1.20.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from fastembed) (1.23.2)
# Requirement already satisfied: pillow<12.0,>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from fastembed) (11.3.0)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from fastembed) (0.1.5)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.12/dist-packages (from fastembed) (2.32.4)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from fastembed) (0.22.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.12/dist-packages (from fastembed) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed) (1.2.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->fastembed) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->fastembed) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->fastembed) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->fastembed) (2025.11.12)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.3.0)

# %%
from qdrant_client import QdrantClient, models

client = QdrantClient(
    url="url_to_cluster_here",
    api_key="qdrant_key_here",
)

# %% [markdown]
# ## Build Pooling Dataframe

# %%
import pandas as pd

def append_retrieval_results_to_pool(
    pool_df: pd.DataFrame,
    *,
    search_method: str,
    query: str,
    rel_docs,
) -> pd.DataFrame:
    """
    Hängt Retrieval-Ergebnisse (z.B. Qdrant query_points().points ODER
    klassische IR-Ergebnisse wie TF-IDF / BM25) als neue Zeilen an ein Pooling-DF an.

    Unterstützte Eingabeformate je Treffer:

    1) Qdrant Point:
       - doc.payload (dict)
       - doc.score (float)
       - doc.id (optional)

    2) Klassische IR (TF-IDF / BM25):
       - dict mit Keys:
         - "payload" (dict, z.B. Expertenprofil)
         - "score" (float)
         - "id" (optional, z.B. Experten-ID)

    Spalten im Output:
      search_method, query, doc_id, doc_raw, score
    """

    rows = []

    # Iterate over retrieved documents (heterogeneous input supported).
    for doc in rel_docs:

        # --- Case 1: classical IR result (dict-based)
        if isinstance(doc, dict):
            payload = doc.get("payload", None)
            score = doc.get("score", None)
            doc_id = doc.get("id", None)

        # --- Case 2: Qdrant Point (object-based)
        else:
            payload = getattr(doc, "payload", None)
            score = getattr(doc, "score", None)
            doc_id = getattr(doc, "id", None)

        # Prefer ID from payload if available (canonical expert ID).
        if isinstance(payload, dict) and "id" in payload:
            doc_id = payload["id"]

        # Append normalized row.
        rows.append({
            "search_method": search_method,
            "query": query,
            "doc_id": doc_id,
            "doc_raw": payload,   # full expert profile / payload
            "score": score,
        })

    # Create DataFrame for new results.
    add_df = pd.DataFrame(
        rows,
        columns=["search_method", "query", "doc_id", "doc_raw", "score"]
    )

    # Initialize pool if empty.
    if pool_df is None or pool_df.empty:
        return add_df.reset_index(drop=True)

    # Append to existing pool.
    return pd.concat([pool_df, add_df], ignore_index=True)

# %%
import pandas as pd
from pathlib import Path

# Build path to pooling results file.
pool_path = Path(PATH_TEST_COLLECTION_DATA) / "pooling_results_raw.csv"

# Load existing pooling results if file exists.
if pool_path.exists():
    print("Found")
    pool_df = pd.read_csv(pool_path)
else:
    print("Not Found")
    # Initialize empty pooling DataFrame with predefined schema.
    pool_df = pd.DataFrame(
        columns=["search_method", "query", "doc_id", "doc_raw", "score"]
    )
# Out:
# Found

# %%
pool_df
# Out:
#                                           search_method  \
# 0                  distiluse-base-multilingual-cased-v2
# 1                  distiluse-base-multilingual-cased-v2
# 2                  distiluse-base-multilingual-cased-v2
# 3                  distiluse-base-multilingual-cased-v2
# 4                  distiluse-base-multilingual-cased-v2
# ...                                                 ...
# 1255  opensearch-neural-sparse-encoding-multilingual-v1
# 1256  opensearch-neural-sparse-encoding-multilingual-v1
# 1257  opensearch-neural-sparse-encoding-multilingual-v1
# 1258  opensearch-neural-sparse-encoding-multilingual-v1
# 1259  opensearch-neural-sparse-encoding-multilingual-v1
#
#                                                 query  \
# 0                             IT-Systemadministration
# 1                             IT-Systemadministration
# 2                             IT-Systemadministration
# 3                             IT-Systemadministration
# 4                             IT-Systemadministration
# ...                                               ...
# 1255  Business Development, Business Process Analysis
# 1256  Business Development, Business Process Analysis
# 1257  Business Development, Business Process Analysis
# 1258  Business Development, Business Process Analysis
# 1259  Business Development, Business Process Analysis
#
#                         doc_id  \
# 0     67251b202f496742be0ea207
# 1     671f67692f496742be0b1d80
# 2     6670848036b0c2e419593c7c
# 3     65b0d5453897d6f0e6516f88
# 4     671f67082f496742be0b1d07
# ...                        ...
# 1255  67d44084b5308acb98802c45
# 1256  65c5352ec8a0f67c4c5cfdb0
# 1257  66d1a5de528e751260e38ff3
# 1258  67487abbb546838eefc5467d
# 1259  65b24b733897d6f0e651f94b
#
#                                                 doc_raw     score
# 0     {"branches": [], "companyLocationCity": "Wuppe...  0.207031
# 1     {"branches": ["Technologie"], "companyLocation...  0.109566
# 2     {"branches": ["Technologie"], "companyLocation...  0.107298
# 3     {"branches": ["Technologie"], "companyLocation...  0.105019
# 4     {"branches": ["Technologie", "Unternehmensdien...  0.094808
# ...                                                 ...       ...
# 1255  {"branches": ["Technologie", "Immobilien", "Me...  9.613712
# 1256  {"branches": ["Immobilien"], "companyLocationC...  9.471822
# 1257  {"branches": ["Technologie"], "companyLocation...  9.155007
# 1258  {"branches": ["Unternehmensdienstleistungen"],...  8.847045
# 1259  {"branches": ["Technologie", "Immobilien", "Me...  8.823762
#
# [1260 rows x 5 columns]

# %%
import os
import json
import pandas as pd

def append_pool_df_to_csv(pool_df: pd.DataFrame, csv_path: str):
    """
    Schreibt ein Pooling-DataFrame in eine CSV-Datei.

    Logik:
    - Falls die CSV existiert:
        - prüfe, welche search_methods bereits enthalten sind
        - hänge nur Daten für neue search_methods an
    - Falls die CSV nicht existiert:
        - schreibe das komplette DataFrame

    Erwartete Spalten:
    - search_method
    - query
    - doc_id
    - doc_raw (dict)
    - score
    """

    # Skip if nothing to persist.
    if pool_df is None or pool_df.empty:
        return

    df = pool_df.copy()

    # Serialize dict payloads to JSON string for CSV compatibility.
    if "doc_raw" in df.columns:
        df["doc_raw"] = df["doc_raw"].apply(
            lambda x: json.dumps(x, ensure_ascii=False)
            if isinstance(x, dict) else x
        )

    # If CSV already exists: append only new search methods.
    if os.path.exists(csv_path):

        # Load existing search methods (minimal I/O).
        existing_df = pd.read_csv(csv_path, usecols=["search_method"])
        existing_methods = set(existing_df["search_method"].unique())

        # Filter out already persisted search methods.
        df = df[~df["search_method"].isin(existing_methods)]

        # Abort if no new data remains.
        if df.empty:
            print("No data to add")
            return

        print("Added data from ", set(df["search_method"].to_list()))

        # Append without header.
        df.to_csv(
            csv_path,
            mode="a",
            header=False,
            index=False
        )

    # If CSV does not exist: write full DataFrame with header.
    else:
        df.to_csv(
            csv_path,
            mode="w",
            header=True,
            index=False
        )

# %% [markdown]
# ## Top-K Limit

# %%
LIMIT = 5

# %% [markdown]
# ## Fetch pool documents for BI-Encoder

# %%
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v2')

# %%
# Iterate over evaluation queries for pooling.
for query in queries_for_pooling:
    print(query)

    # Execute dense vector search against Qdrant collection.
    rel_docs = client.query_points(
        collection_name="expert_data_structured_and_fulltext_dense",
        query=encoder.encode(query).tolist(),  # Encode query to dense vector.
        limit=LIMIT,
    ).points

    # Append retrieval results to pooling DataFrame.
    pool_df = append_retrieval_results_to_pool(
        pool_df,
        search_method="distiluse-base-multilingual-cased-v2",
        query=query,
        rel_docs=rel_docs,
    )
# Out:
# IT-Systemadministration
# Information Technology
# Wissensmanagement
# Konstruktion
# Metallhandwerk
# Mechanik
# Automatisierungstechnik
# Elektrotechnik
# Konstruktion, Metallhandwerk
# Mechanik, Elektrotechnik
# Metallhandwerk, Mechanik
# Metallhandwerk, Elektrotechnik
# Mechanik, Automatisierungstechnik
# Automatisierungstechnik, Elektrotechnik
# KI
# Public Relations
# Sales
# Social Media Marketing
# Public Relations, Social Media Marketing
# Marketing
# Brand Management
# Marketing, Social Media Marketing
# Marketing, Brand Management
# Social Media Marketing, Brand Management
# Employee Development
# Personalentwicklung und Mentoring
# Human Resources
# Coaching
# Business Development, Employee Development
# Business Development, Personalentwicklung und Mentoring
# Business Development, Human Resources
# Business Development, Coaching
# Employee Development, Personalentwicklung und Mentoring
# Employee Development, Human Resources
# Employee Development, Coaching
# Personalentwicklung und Mentoring, Human Resources
# Personalentwicklung und Mentoring, Coaching
# Human Resources, Coaching
# Bau- und Ausbauhandwerk
# Holzhandwerk
# Anlagenbau
# Bau- und Ausbauhandwerk, Anlagenbau
# Finance
# Financial Management
# Budget Planning
# Business Planning, Finance
# Business Planning, Financial Management
# Business Planning, Budget Planning
# Business Planning, Business Development
# Finance, Financial Management
# Finance, Budget Planning
# Finance, Business Development
# Financial Management, Budget Planning
# Financial Management, Business Development
# Budget Planning, Business Development
# Business Planning
# Business Development
# Controlling
# Change Management, Business Planning
# Change Management, Business Development
# Change Management, Controlling
# Business Planning, Controlling
# Business Development, Controlling
# Cloud-Computing
# IT-Management
# Datenbankverwaltung
# Softwareentwicklung
# Data Analysis
# Cloud-Computing, IT-Management
# Cloud-Computing, Digital Ethics
# Cloud-Computing, Datenbankverwaltung
# Cloud-Computing, Softwareentwicklung
# Cloud-Computing, Data Analysis
# IT-Management, Softwareentwicklung
# IT-Management, Data Analysis
# Softwareentwicklung, Data Analysis
# Change Management
# Digital Ethics
# Business Process Analysis
# Change Management, Digital Ethics
# Change Management, Business Process Analysis
# Digital Ethics, Business Development
# Business Planning, Business Process Analysis
# Business Development, Business Process Analysis

# %%
pool_df
# Out:
#                             search_method  \
# 0    distiluse-base-multilingual-cased-v2
# 1    distiluse-base-multilingual-cased-v2
# 2    distiluse-base-multilingual-cased-v2
# 3    distiluse-base-multilingual-cased-v2
# 4    distiluse-base-multilingual-cased-v2
# ..                                    ...
# 415  distiluse-base-multilingual-cased-v2
# 416  distiluse-base-multilingual-cased-v2
# 417  distiluse-base-multilingual-cased-v2
# 418  distiluse-base-multilingual-cased-v2
# 419  distiluse-base-multilingual-cased-v2
#
#                                                query  \
# 0                            IT-Systemadministration
# 1                            IT-Systemadministration
# 2                            IT-Systemadministration
# 3                            IT-Systemadministration
# 4                            IT-Systemadministration
# ..                                               ...
# 415  Business Development, Business Process Analysis
# 416  Business Development, Business Process Analysis
# 417  Business Development, Business Process Analysis
# 418  Business Development, Business Process Analysis
# 419  Business Development, Business Process Analysis
#
#                        doc_id  \
# 0    67251b202f496742be0ea207
# 1    671f67692f496742be0b1d80
# 2    6670848036b0c2e419593c7c
# 3    65b0d5453897d6f0e6516f88
# 4    671f67082f496742be0b1d07
# ..                        ...
# 415  682adab50b2e403ede03a46a
# 416  67501be2cc9cf2f9a1e5d829
# 417  65b7691a3897d6f0e6533c32
# 418  65c4d290c8a0f67c4c5ce5fb
# 419  660fe785b5bb2b1c9a9440b3
#
#                                                doc_raw     score
# 0    {'branches': [], 'companyLocationCity': 'Wuppe...  0.207031
# 1    {'branches': ['Technologie'], 'companyLocation...  0.109566
# 2    {'branches': ['Technologie'], 'companyLocation...  0.107298
# 3    {'branches': ['Technologie'], 'companyLocation...  0.105019
# 4    {'branches': ['Technologie', 'Unternehmensdien...  0.094808
# ..                                                 ...       ...
# 415  {'branches': ['Unternehmensdienstleistungen'],...  0.225938
# 416  {'branches': ['Technologie'], 'companyLocation...  0.200533
# 417  {'branches': ['Unternehmensdienstleistungen', ...  0.197369
# 418  {'branches': ['Technologie', 'Medien & Werbung...  0.185413
# 419  {'branches': ['Technologie', 'Unternehmensdien...  0.181274
#
# [420 rows x 5 columns]

# %%
# after every run
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# No data to add

# %% [markdown]
# ## Fetch pool documents for Cross-Encoder

# %%
from sentence_transformers import CrossEncoder

cross_model = CrossEncoder("cross-encoder/mmarco-mMiniLMv2-L12-H384-v1")

# Model: https://huggingface.co/cross-encoder/mmarco-mMiniLMv2-L12-H384-v1

print(cross_model)
# Out:
# CrossEncoder(
#   (model): XLMRobertaForSequenceClassification(
#     (roberta): XLMRobertaModel(
#       (embeddings): XLMRobertaEmbeddings(
#         (word_embeddings): Embedding(250002, 384, padding_idx=1)
#         (position_embeddings): Embedding(514, 384, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 384)
#         (LayerNorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): XLMRobertaEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x XLMRobertaLayer(
#             (attention): XLMRobertaAttention(
#               (self): XLMRobertaSdpaSelfAttention(
#                 (query): Linear(in_features=384, out_features=384, bias=True)
#                 (key): Linear(in_features=384, out_features=384, bias=True)
#                 (value): Linear(in_features=384, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): XLMRobertaSelfOutput(
#                 (dense): Linear(in_features=384, out_features=384, bias=True)
#                 (LayerNorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): XLMRobertaIntermediate(
#               (dense): Linear(in_features=384, out_features=1536, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): XLMRobertaOutput(
#               (dense): Linear(in_features=1536, out_features=384, bias=True)
#               (LayerNorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (classifier): XLMRobertaClassificationHead(
#       (dense): Linear(in_features=384, out_features=384, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (out_proj): Linear(in_features=384, out_features=1, bias=True)
#     )
#   )
#   (activation_fn): Identity()
# )

# %%
import json
from types import SimpleNamespace

def doc_to_text(doc: dict) -> str:
    # Serialize document to deterministic JSON string representation.
    # Ensures consistent input format across retrieval pipelines.
    return json.dumps(doc, ensure_ascii=False)


def crossencoder_query_points(
    cross_encoder,
    *,
    query: str,
    documents: list,        # Liste deiner Expert-JSONs
    limit: int = 5,
    batch_size: int = 32,
    text_fn=doc_to_text,
):
    """
    Cross-Encoder 'Standalone Retrieval':
    scored alle Dokumente (query, doc_text) und gibt Top-k zurück
    als Liste von Objekten mit .payload und .score (Qdrant-like).
    """

    # Build (query, document_text) pairs for scoring.
    pairs = [(query, text_fn(doc)) for doc in documents]

    # Compute relevance scores using cross-encoder.
    scores = cross_encoder.predict(pairs, batch_size=batch_size)

    # Select top-k indices sorted by descending score.
    top_idx = sorted(
        range(len(scores)),
        key=lambda i: scores[i],
        reverse=True
    )[:limit]

    # Construct Qdrant-like result objects (.payload, .score, .id).
    hits = []
    for i in top_idx:
        payload = documents[i]
        hits.append(SimpleNamespace(
            payload=payload,
            score=float(scores[i]),
            id=payload.get("id", i)  # Prefer explicit document ID.
        ))

    return hits

# %%
from sentence_transformers import CrossEncoder
import pandas as pd

# Iterate over evaluation queries and apply Cross-Encoder retrieval.
for idx, query in enumerate(queries_for_pooling):

    # Score all documents with cross-encoder and retrieve top-k.
    rel_docs = crossencoder_query_points(
        cross_model,
        query=query,
        documents=expert_data,
        limit=LIMIT,
        batch_size=32,
    )

    # Basic logging.
    print(idx)
    print(query)
    print("Found Docs: ", len(rel_docs))

    # Append results to pooling DataFrame.
    pool_df = append_retrieval_results_to_pool(
        pool_df,
        search_method="mmarco-mMiniLMv2-L12-H384-v1",
        query=query,
        rel_docs=rel_docs,
    )
# Out:
# 0
# IT-Systemadministration
# Found Docs:  5
# 1
# Information Technology
# Found Docs:  5
# 2
# Wissensmanagement
# Found Docs:  5
# 3
# Konstruktion
# Found Docs:  5
# 4
# Metallhandwerk
# Found Docs:  5
# 5
# Mechanik
# Found Docs:  5
# 6
# Automatisierungstechnik
# Found Docs:  5
# 7
# Elektrotechnik
# Found Docs:  5
# 8
# Konstruktion, Metallhandwerk
# Found Docs:  5
# 9
# Mechanik, Elektrotechnik
# Found Docs:  5
# 10
# Metallhandwerk, Mechanik
# Found Docs:  5
# 11
# Metallhandwerk, Elektrotechnik
# Found Docs:  5
# 12
# Mechanik, Automatisierungstechnik
# Found Docs:  5
# 13
# Automatisierungstechnik, Elektrotechnik
# Found Docs:  5
# 14
# KI
# Found Docs:  5
# 15
# Public Relations
# Found Docs:  5
# 16
# Sales
# Found Docs:  5
# 17
# Social Media Marketing
# Found Docs:  5
# 18
# Public Relations, Social Media Marketing
# Found Docs:  5
# 19
# Marketing
# Found Docs:  5
# 20
# Brand Management
# Found Docs:  5
# 21
# Marketing, Social Media Marketing
# Found Docs:  5
# 22
# Marketing, Brand Management
# Found Docs:  5
# 23
# Social Media Marketing, Brand Management
# Found Docs:  5
# 24
# Employee Development
# Found Docs:  5
# 25
# Personalentwicklung und Mentoring
# Found Docs:  5
# 26
# Human Resources
# Found Docs:  5
# 27
# Coaching
# Found Docs:  5
# 28
# Business Development, Employee Development
# Found Docs:  5
# 29
# Business Development, Personalentwicklung und Mentoring
# Found Docs:  5
# 30
# Business Development, Human Resources
# Found Docs:  5
# 31
# Business Development, Coaching
# Found Docs:  5
# 32
# Employee Development, Personalentwicklung und Mentoring
# Found Docs:  5
# 33
# Employee Development, Human Resources
# Found Docs:  5
# 34
# Employee Development, Coaching
# Found Docs:  5
# 35
# Personalentwicklung und Mentoring, Human Resources
# Found Docs:  5
# 36
# Personalentwicklung und Mentoring, Coaching
# Found Docs:  5
# 37
# Human Resources, Coaching
# Found Docs:  5
# 38
# Bau- und Ausbauhandwerk
# Found Docs:  5
# 39
# Holzhandwerk
# Found Docs:  5
# 40
# Anlagenbau
# Found Docs:  5
# 41
# Bau- und Ausbauhandwerk, Anlagenbau
# Found Docs:  5
# 42
# Finance
# Found Docs:  5
# 43
# Financial Management
# Found Docs:  5
# 44
# Budget Planning
# Found Docs:  5
# 45
# Business Planning, Finance
# Found Docs:  5
# 46
# Business Planning, Financial Management
# Found Docs:  5
# 47
# Business Planning, Budget Planning
# Found Docs:  5
# 48
# Business Planning, Business Development
# Found Docs:  5
# 49
# Finance, Financial Management
# Found Docs:  5
# 50
# Finance, Budget Planning
# Found Docs:  5
# 51
# Finance, Business Development
# Found Docs:  5
# 52
# Financial Management, Budget Planning
# Found Docs:  5
# 53
# Financial Management, Business Development
# Found Docs:  5
# 54
# Budget Planning, Business Development
# Found Docs:  5
# 55
# Business Planning
# Found Docs:  5
# 56
# Business Development
# Found Docs:  5
# 57
# Controlling
# Found Docs:  5
# 58
# Change Management, Business Planning
# Found Docs:  5
# 59
# Change Management, Business Development
# Found Docs:  5
# 60
# Change Management, Controlling
# Found Docs:  5
# 61
# Business Planning, Controlling
# Found Docs:  5
# 62
# Business Development, Controlling
# Found Docs:  5
# 63
# Cloud-Computing
# Found Docs:  5
# 64
# IT-Management
# Found Docs:  5
# 65
# Datenbankverwaltung
# Found Docs:  5
# 66
# Softwareentwicklung
# Found Docs:  5
# 67
# Data Analysis
# Found Docs:  5
# 68
# Cloud-Computing, IT-Management
# Found Docs:  5
# 69
# Cloud-Computing, Digital Ethics
# Found Docs:  5
# 70
# Cloud-Computing, Datenbankverwaltung
# Found Docs:  5
# 71
# Cloud-Computing, Softwareentwicklung
# Found Docs:  5
# 72
# Cloud-Computing, Data Analysis
# Found Docs:  5
# 73
# IT-Management, Softwareentwicklung
# Found Docs:  5
# 74
# IT-Management, Data Analysis
# Found Docs:  5
# 75
# Softwareentwicklung, Data Analysis
# Found Docs:  5
# 76
# Change Management
# Found Docs:  5
# 77
# Digital Ethics
# Found Docs:  5
# 78
# Business Process Analysis
# Found Docs:  5
# 79
# Change Management, Digital Ethics
# Found Docs:  5
# 80
# Change Management, Business Process Analysis
# Found Docs:  5
# 81
# Digital Ethics, Business Development
# Found Docs:  5
# 82
# Business Planning, Business Process Analysis
# Found Docs:  5
# 83
# Business Development, Business Process Analysis
# Found Docs:  5

# %%
pool_df
# Out:
#                             search_method  \
# 0    distiluse-base-multilingual-cased-v2
# 1    distiluse-base-multilingual-cased-v2
# 2    distiluse-base-multilingual-cased-v2
# 3    distiluse-base-multilingual-cased-v2
# 4    distiluse-base-multilingual-cased-v2
# ..                                    ...
# 835          mmarco-mMiniLMv2-L12-H384-v1
# 836          mmarco-mMiniLMv2-L12-H384-v1
# 837          mmarco-mMiniLMv2-L12-H384-v1
# 838          mmarco-mMiniLMv2-L12-H384-v1
# 839          mmarco-mMiniLMv2-L12-H384-v1
#
#                                                query  \
# 0                            IT-Systemadministration
# 1                            IT-Systemadministration
# 2                            IT-Systemadministration
# 3                            IT-Systemadministration
# 4                            IT-Systemadministration
# ..                                               ...
# 835  Business Development, Business Process Analysis
# 836  Business Development, Business Process Analysis
# 837  Business Development, Business Process Analysis
# 838  Business Development, Business Process Analysis
# 839  Business Development, Business Process Analysis
#
#                        doc_id  \
# 0    67251b202f496742be0ea207
# 1    671f67692f496742be0b1d80
# 2    6670848036b0c2e419593c7c
# 3    65b0d5453897d6f0e6516f88
# 4    671f67082f496742be0b1d07
# ..                        ...
# 835  65c5e1d861580d8db5fe02d4
# 836  67d44084b5308acb98802c45
# 837  66eacb9b41f659468bdda50c
# 838  6695032d5199a106e76ad753
# 839  665ef38ad89259daa7080a70
#
#                                                doc_raw     score
# 0    {'branches': [], 'companyLocationCity': 'Wuppe...  0.207031
# 1    {'branches': ['Technologie'], 'companyLocation...  0.109566
# 2    {'branches': ['Technologie'], 'companyLocation...  0.107298
# 3    {'branches': ['Technologie'], 'companyLocation...  0.105019
# 4    {'branches': ['Technologie', 'Unternehmensdien...  0.094808
# ..                                                 ...       ...
# 835  {'branches': ['Investor (Eigenkapital)', 'Unte...  4.049880
# 836  {'branches': ['Technologie', 'Immobilien', 'Me...  3.989550
# 837  {'branches': ['Automobilindustrie'], 'companyL...  3.393510
# 838  {'branches': ['Unternehmensdienstleistungen'],...  3.121296
# 839  {'branches': ['Konsum und Handel', 'Verpackung...  3.070448
#
# [840 rows x 5 columns]

# %%
# nach jedem Methodenlauf oder Query
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# Added data from  {'mmarco-mMiniLMv2-L12-H384-v1'}

# %% [markdown]
# ## Fetch pool documents for Neural-Sparse Model

# %%
from sentence_transformers.sparse_encoder import SparseEncoder

# %%
# Download from the 🤗 Hub
sparse_model = SparseEncoder("opensearch-project/opensearch-neural-sparse-encoding-multilingual-v1")

# %%
def encode_sparse_for_qdrant(text: str) -> models.SparseVector:
    # Encode text into sparse tensor representation (1D, vocab_size).
    tensor = sparse_model.encode_document(text)
    tensor = tensor.coalesce()  # Ensure indices are merged and canonical.

    # Extract non-zero token indices and corresponding weights.
    idx = tensor.indices()   # Shape: [1, nnz]
    vals = tensor.values()   # Shape: [nnz]

    token_indices = idx[0].tolist()
    token_values = vals.tolist()

    # Convert to Qdrant-compatible SparseVector.
    return models.SparseVector(
        indices=token_indices,
        values=token_values,
    )

# %%
# Iterate over evaluation queries and perform sparse retrieval.
for idx, query in enumerate(queries_for_pooling):
    print(query)

    # Execute sparse vector search against Qdrant collection.
    response = client.query_points(
        collection_name="expert_data_structured_and_fulltext_sparse",
        query=encode_sparse_for_qdrant(query),   # Convert query to sparse vector.
        using="neural_sparse_vector",            # Named sparse vector field.
        limit=LIMIT,
        with_vectors=True,
        with_payload=True
    )

    print(idx)
    print("Found Docs: ", len(response.points))

    # Append sparse retrieval results to pooling DataFrame.
    pool_df = append_retrieval_results_to_pool(
        pool_df,
        search_method="opensearch-neural-sparse-encoding-multilingual-v1",
        query=query,
        rel_docs=response.points,
    )
# Out:
# IT-Systemadministration
# 0
# Found Docs:  5
# Information Technology
# 1
# Found Docs:  5
# Wissensmanagement
# 2
# Found Docs:  5
# Konstruktion
# 3
# Found Docs:  5
# Metallhandwerk
# 4
# Found Docs:  5
# Mechanik
# 5
# Found Docs:  5
# Automatisierungstechnik
# 6
# Found Docs:  5
# Elektrotechnik
# 7
# Found Docs:  5
# Konstruktion, Metallhandwerk
# 8
# Found Docs:  5
# Mechanik, Elektrotechnik
# 9
# Found Docs:  5
# Metallhandwerk, Mechanik
# 10
# Found Docs:  5
# Metallhandwerk, Elektrotechnik
# 11
# Found Docs:  5
# Mechanik, Automatisierungstechnik
# 12
# Found Docs:  5
# Automatisierungstechnik, Elektrotechnik
# 13
# Found Docs:  5
# KI
# 14
# Found Docs:  5
# Public Relations
# 15
# Found Docs:  5
# Sales
# 16
# Found Docs:  5
# Social Media Marketing
# 17
# Found Docs:  5
# Public Relations, Social Media Marketing
# 18
# Found Docs:  5
# Marketing
# 19
# Found Docs:  5
# Brand Management
# 20
# Found Docs:  5
# Marketing, Social Media Marketing
# 21
# Found Docs:  5
# Marketing, Brand Management
# 22
# Found Docs:  5
# Social Media Marketing, Brand Management
# 23
# Found Docs:  5
# Employee Development
# 24
# Found Docs:  5
# Personalentwicklung und Mentoring
# 25
# Found Docs:  5
# Human Resources
# 26
# Found Docs:  5
# Coaching
# 27
# Found Docs:  5
# Business Development, Employee Development
# 28
# Found Docs:  5
# Business Development, Personalentwicklung und Mentoring
# 29
# Found Docs:  5
# Business Development, Human Resources
# 30
# Found Docs:  5
# Business Development, Coaching
# 31
# Found Docs:  5
# Employee Development, Personalentwicklung und Mentoring
# 32
# Found Docs:  5
# Employee Development, Human Resources
# 33
# Found Docs:  5
# Employee Development, Coaching
# 34
# Found Docs:  5
# Personalentwicklung und Mentoring, Human Resources
# 35
# Found Docs:  5
# Personalentwicklung und Mentoring, Coaching
# 36
# Found Docs:  5
# Human Resources, Coaching
# 37
# Found Docs:  5
# Bau- und Ausbauhandwerk
# 38
# Found Docs:  5
# Holzhandwerk
# 39
# Found Docs:  5
# Anlagenbau
# 40
# Found Docs:  5
# Bau- und Ausbauhandwerk, Anlagenbau
# 41
# Found Docs:  5
# Finance
# 42
# Found Docs:  5
# Financial Management
# 43
# Found Docs:  5
# Budget Planning
# 44
# Found Docs:  5
# Business Planning, Finance
# 45
# Found Docs:  5
# Business Planning, Financial Management
# 46
# Found Docs:  5
# Business Planning, Budget Planning
# 47
# Found Docs:  5
# Business Planning, Business Development
# 48
# Found Docs:  5
# Finance, Financial Management
# 49
# Found Docs:  5
# Finance, Budget Planning
# 50
# Found Docs:  5
# Finance, Business Development
# 51
# Found Docs:  5
# Financial Management, Budget Planning
# 52
# Found Docs:  5
# Financial Management, Business Development
# 53
# Found Docs:  5
# Budget Planning, Business Development
# 54
# Found Docs:  5
# Business Planning
# 55
# Found Docs:  5
# Business Development
# 56
# Found Docs:  5
# Controlling
# 57
# Found Docs:  5
# Change Management, Business Planning
# 58
# Found Docs:  5
# Change Management, Business Development
# 59
# Found Docs:  5
# Change Management, Controlling
# 60
# Found Docs:  5
# Business Planning, Controlling
# 61
# Found Docs:  5
# Business Development, Controlling
# 62
# Found Docs:  5
# Cloud-Computing
# 63
# Found Docs:  5
# IT-Management
# 64
# Found Docs:  5
# Datenbankverwaltung
# 65
# Found Docs:  5
# Softwareentwicklung
# 66
# Found Docs:  5
# Data Analysis
# 67
# Found Docs:  5
# Cloud-Computing, IT-Management
# 68
# Found Docs:  5
# Cloud-Computing, Digital Ethics
# 69
# Found Docs:  5
# Cloud-Computing, Datenbankverwaltung
# 70
# Found Docs:  5
# Cloud-Computing, Softwareentwicklung
# 71
# Found Docs:  5
# Cloud-Computing, Data Analysis
# 72
# Found Docs:  5
# IT-Management, Softwareentwicklung
# 73
# Found Docs:  5
# IT-Management, Data Analysis
# 74
# Found Docs:  5
# Softwareentwicklung, Data Analysis
# 75
# Found Docs:  5
# Change Management
# 76
# Found Docs:  5
# Digital Ethics
# 77
# Found Docs:  5
# Business Process Analysis
# 78
# Found Docs:  5
# Change Management, Digital Ethics
# 79
# Found Docs:  5
# Change Management, Business Process Analysis
# 80
# Found Docs:  5
# Digital Ethics, Business Development
# 81
# Found Docs:  5
# Business Planning, Business Process Analysis
# 82
# Found Docs:  5
# Business Development, Business Process Analysis
# 83
# Found Docs:  5

# %%
pool_df
# Out:
#                                           search_method  \
# 0                  distiluse-base-multilingual-cased-v2
# 1                  distiluse-base-multilingual-cased-v2
# 2                  distiluse-base-multilingual-cased-v2
# 3                  distiluse-base-multilingual-cased-v2
# 4                  distiluse-base-multilingual-cased-v2
# ...                                                 ...
# 1255  opensearch-neural-sparse-encoding-multilingual-v1
# 1256  opensearch-neural-sparse-encoding-multilingual-v1
# 1257  opensearch-neural-sparse-encoding-multilingual-v1
# 1258  opensearch-neural-sparse-encoding-multilingual-v1
# 1259  opensearch-neural-sparse-encoding-multilingual-v1
#
#                                                 query  \
# 0                             IT-Systemadministration
# 1                             IT-Systemadministration
# 2                             IT-Systemadministration
# 3                             IT-Systemadministration
# 4                             IT-Systemadministration
# ...                                               ...
# 1255  Business Development, Business Process Analysis
# 1256  Business Development, Business Process Analysis
# 1257  Business Development, Business Process Analysis
# 1258  Business Development, Business Process Analysis
# 1259  Business Development, Business Process Analysis
#
#                         doc_id  \
# 0     67251b202f496742be0ea207
# 1     671f67692f496742be0b1d80
# 2     6670848036b0c2e419593c7c
# 3     65b0d5453897d6f0e6516f88
# 4     671f67082f496742be0b1d07
# ...                        ...
# 1255  67d44084b5308acb98802c45
# 1256  65c5352ec8a0f67c4c5cfdb0
# 1257  66d1a5de528e751260e38ff3
# 1258  67487abbb546838eefc5467d
# 1259  65b24b733897d6f0e651f94b
#
#                                                 doc_raw     score
# 0     {'branches': [], 'companyLocationCity': 'Wuppe...  0.207031
# 1     {'branches': ['Technologie'], 'companyLocation...  0.109566
# 2     {'branches': ['Technologie'], 'companyLocation...  0.107298
# 3     {'branches': ['Technologie'], 'companyLocation...  0.105019
# 4     {'branches': ['Technologie', 'Unternehmensdien...  0.094808
# ...                                                 ...       ...
# 1255  {'branches': ['Technologie', 'Immobilien', 'Me...  9.613712
# 1256  {'branches': ['Immobilien'], 'companyLocationC...  9.471822
# 1257  {'branches': ['Technologie'], 'companyLocation...  9.155007
# 1258  {'branches': ['Unternehmensdienstleistungen'],...  8.847045
# 1259  {'branches': ['Technologie', 'Immobilien', 'Me...  8.823762
#
# [1260 rows x 5 columns]

# %%
# nach jedem Methodenlauf oder Query
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# Added data from  {'opensearch-neural-sparse-encoding-multilingual-v1'}

# %% [markdown]
# ## Fetch pool documents for Late-Interaction Model

# %%
from fastembed import LateInteractionTextEmbedding

late_model = LateInteractionTextEmbedding("jinaai/jina-colbert-v2")
print(late_model.embedding_size)
# Out:
# 128

# %%
# Iterate over evaluation queries and perform late-interaction retrieval.
for idx, query in enumerate(queries_for_pooling):

    # Generate late-interaction query embedding (e.g., ColBERT-style).
    query_embedding = next(
        late_model.query_embed([query])
    ).tolist()

    # Execute late-interaction search in Qdrant.
    rel_docs = client.query_points(
        collection_name="expert_data_structured_and_fulltext_late",
        query=query_embedding,
        using="late_interaction",
        limit=LIMIT,
    ).points

    # Basic logging.
    print(idx)
    print(query)
    print("Found Docs: ", len(rel_docs))

    # Append retrieval results to pooling DataFrame.
    pool_df = append_retrieval_results_to_pool(
        pool_df,
        search_method="jina-colbert-v2",
        query=query,
        rel_docs=rel_docs,
    )
# Out:
# 0
# IT-Systemadministration
# Found Docs:  5
# 1
# Information Technology
# Found Docs:  5
# 2
# Wissensmanagement
# Found Docs:  5
# 3
# Konstruktion
# Found Docs:  5
# 4
# Metallhandwerk
# Found Docs:  5
# 5
# Mechanik
# Found Docs:  5
# 6
# Automatisierungstechnik
# Found Docs:  5
# 7
# Elektrotechnik
# Found Docs:  5
# 8
# Konstruktion, Metallhandwerk
# Found Docs:  5
# 9
# Mechanik, Elektrotechnik
# Found Docs:  5
# 10
# Metallhandwerk, Mechanik
# Found Docs:  5
# 11
# Metallhandwerk, Elektrotechnik
# Found Docs:  5
# 12
# Mechanik, Automatisierungstechnik
# Found Docs:  5
# 13
# Automatisierungstechnik, Elektrotechnik
# Found Docs:  5
# 14
# KI
# Found Docs:  5
# 15
# Public Relations
# Found Docs:  5
# 16
# Sales
# Found Docs:  5
# 17
# Social Media Marketing
# Found Docs:  5
# 18
# Public Relations, Social Media Marketing
# Found Docs:  5
# 19
# Marketing
# Found Docs:  5
# 20
# Brand Management
# Found Docs:  5
# 21
# Marketing, Social Media Marketing
# Found Docs:  5
# 22
# Marketing, Brand Management
# Found Docs:  5
# 23
# Social Media Marketing, Brand Management
# Found Docs:  5
# 24
# Employee Development
# Found Docs:  5
# 25
# Personalentwicklung und Mentoring
# Found Docs:  5
# 26
# Human Resources
# Found Docs:  5
# 27
# Coaching
# Found Docs:  5
# 28
# Business Development, Employee Development
# Found Docs:  5
# 29
# Business Development, Personalentwicklung und Mentoring
# Found Docs:  5
# 30
# Business Development, Human Resources
# Found Docs:  5
# 31
# Business Development, Coaching
# Found Docs:  5
# 32
# Employee Development, Personalentwicklung und Mentoring
# Found Docs:  5
# 33
# Employee Development, Human Resources
# Found Docs:  5
# 34
# Employee Development, Coaching
# Found Docs:  5
# 35
# Personalentwicklung und Mentoring, Human Resources
# Found Docs:  5
# 36
# Personalentwicklung und Mentoring, Coaching
# Found Docs:  5
# 37
# Human Resources, Coaching
# Found Docs:  5
# 38
# Bau- und Ausbauhandwerk
# Found Docs:  5
# 39
# Holzhandwerk
# Found Docs:  5
# 40
# Anlagenbau
# Found Docs:  5
# 41
# Bau- und Ausbauhandwerk, Anlagenbau
# Found Docs:  5
# 42
# Finance
# Found Docs:  5
# 43
# Financial Management
# Found Docs:  5
# 44
# Budget Planning
# Found Docs:  5
# 45
# Business Planning, Finance
# Found Docs:  5
# 46
# Business Planning, Financial Management
# Found Docs:  5
# 47
# Business Planning, Budget Planning
# Found Docs:  5
# 48
# Business Planning, Business Development
# Found Docs:  5
# 49
# Finance, Financial Management
# Found Docs:  5
# 50
# Finance, Budget Planning
# Found Docs:  5
# 51
# Finance, Business Development
# Found Docs:  5
# 52
# Financial Management, Budget Planning
# Found Docs:  5
# 53
# Financial Management, Business Development
# Found Docs:  5
# 54
# Budget Planning, Business Development
# Found Docs:  5
# 55
# Business Planning
# Found Docs:  5
# 56
# Business Development
# Found Docs:  5
# 57
# Controlling
# Found Docs:  5
# 58
# Change Management, Business Planning
# Found Docs:  5
# 59
# Change Management, Business Development
# Found Docs:  5
# 60
# Change Management, Controlling
# Found Docs:  5
# 61
# Business Planning, Controlling
# Found Docs:  5
# 62
# Business Development, Controlling
# Found Docs:  5
# 63
# Cloud-Computing
# Found Docs:  5
# 64
# IT-Management
# Found Docs:  5
# 65
# Datenbankverwaltung
# Found Docs:  5
# 66
# Softwareentwicklung
# Found Docs:  5
# 67
# Data Analysis
# Found Docs:  5
# 68
# Cloud-Computing, IT-Management
# Found Docs:  5
# 69
# Cloud-Computing, Digital Ethics
# Found Docs:  5
# 70
# Cloud-Computing, Datenbankverwaltung
# Found Docs:  5
# 71
# Cloud-Computing, Softwareentwicklung
# Found Docs:  5
# 72
# Cloud-Computing, Data Analysis
# Found Docs:  5
# 73
# IT-Management, Softwareentwicklung
# Found Docs:  5
# 74
# IT-Management, Data Analysis
# Found Docs:  5
# 75
# Softwareentwicklung, Data Analysis
# Found Docs:  5
# 76
# Change Management
# Found Docs:  5
# 77
# Digital Ethics
# Found Docs:  5
# 78
# Business Process Analysis
# Found Docs:  5
# 79
# Change Management, Digital Ethics
# Found Docs:  5
# 80
# Change Management, Business Process Analysis
# Found Docs:  5
# 81
# Digital Ethics, Business Development
# Found Docs:  5
# 82
# Business Planning, Business Process Analysis
# Found Docs:  5
# 83
# Business Development, Business Process Analysis
# Found Docs:  5

# %%
pool_df
# Out:
#                              search_method  \
# 0     distiluse-base-multilingual-cased-v2
# 1     distiluse-base-multilingual-cased-v2
# 2     distiluse-base-multilingual-cased-v2
# 3     distiluse-base-multilingual-cased-v2
# 4     distiluse-base-multilingual-cased-v2
# ...                                    ...
# 1675                       jina-colbert-v2
# 1676                       jina-colbert-v2
# 1677                       jina-colbert-v2
# 1678                       jina-colbert-v2
# 1679                       jina-colbert-v2
#
#                                                 query  \
# 0                             IT-Systemadministration
# 1                             IT-Systemadministration
# 2                             IT-Systemadministration
# 3                             IT-Systemadministration
# 4                             IT-Systemadministration
# ...                                               ...
# 1675  Business Development, Business Process Analysis
# 1676  Business Development, Business Process Analysis
# 1677  Business Development, Business Process Analysis
# 1678  Business Development, Business Process Analysis
# 1679  Business Development, Business Process Analysis
#
#                         doc_id  \
# 0     67251b202f496742be0ea207
# 1     671f67692f496742be0b1d80
# 2     6670848036b0c2e419593c7c
# 3     65b0d5453897d6f0e6516f88
# 4     671f67082f496742be0b1d07
# ...                        ...
# 1675  65c4d290c8a0f67c4c5ce5fb
# 1676  66eacb9b41f659468bdda50c
# 1677  6749c74eb546838eefc6115b
# 1678  67487abbb546838eefc5467d
# 1679  6613ac1db5bb2b1c9a9501e5
#
#                                                 doc_raw      score
# 0     {"branches": [], "companyLocationCity": "Wuppe...   0.207031
# 1     {"branches": ["Technologie"], "companyLocation...   0.109566
# 2     {"branches": ["Technologie"], "companyLocation...   0.107298
# 3     {"branches": ["Technologie"], "companyLocation...   0.105019
# 4     {"branches": ["Technologie", "Unternehmensdien...   0.094808
# ...                                                 ...        ...
# 1675  {'branches': ['Technologie', 'Medien & Werbung...  17.635206
# 1676  {'branches': ['Automobilindustrie'], 'companyL...  17.618885
# 1677  {'branches': ['Technologie', 'Immobilien', 'Me...  17.507235
# 1678  {'branches': ['Unternehmensdienstleistungen'],...  17.500910
# 1679  {'branches': ['Technologie', 'Immobilien', 'Me...  17.448984
#
# [1680 rows x 5 columns]

# %%
# nach jedem Methodenlauf oder Query
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# No data to add

# %% [markdown]
# ## Fetch pool documents for TFIDF

# %%
# source: https://snowballstem.org/algorithms/german/stop.txt

GERMAN_STOPWORDS = [
    "aber",
    "alle", "allem", "allen", "aller", "alles",
    "als", "also", "am", "an",
    "ander", "andere", "anderem", "anderen", "anderer", "anderes",
    "anderm", "andern", "anderr", "anders",
    "auch", "auf", "aus", "bei",
    "bin", "bis", "bist",
    "da", "damit", "dann",
    "der", "den", "des", "dem", "die", "das",
    "daß",
    "derselbe", "derselben", "denselben", "desselben", "demselben",
    "dieselbe", "dieselben", "dasselbe",
    "dazu",
    "dein", "deine", "deinem", "deinen", "deiner", "deines",
    "denn",
    "derer", "dessen",
    "dich", "dir", "du",
    "dies", "diese", "diesem", "diesen", "dieser", "dieses",
    "doch", "dort",
    "durch",
    "ein", "eine", "einem", "einen", "einer", "eines",
    "einig", "einige", "einigem", "einigen", "einiger", "einiges",
    "einmal",
    "er", "ihn", "ihm",
    "es", "etwas",
    "euer", "eure", "eurem", "euren", "eurer", "eures",
    "für", "gegen",
    "gewesen",
    "hab", "habe", "haben", "hat", "hatte", "hatten",
    "hier", "hin", "hinter",
    "ich", "mich", "mir",
    "ihr", "ihre", "ihrem", "ihren", "ihrer", "ihres",
    "euch",
    "im", "in", "indem", "ins",
    "ist",
    "jede", "jedem", "jeden", "jeder", "jedes",
    "jene", "jenem", "jenen", "jener", "jenes",
    "jetzt",
    "kann",
    "kein", "keine", "keinem", "keinen", "keiner", "keines",
    "können", "könnte",
    "machen",
    "man",
    "manche", "manchem", "manchen", "mancher", "manches",
    "mein", "meine", "meinem", "meinen", "meiner", "meines",
    "mit",
    "muss", "musste",
    "nach",
    "nicht", "nichts",
    "noch", "nun", "nur",
    "ob", "oder", "ohne",
    "sehr",
    "sein", "seine", "seinem", "seinen", "seiner", "seines",
    "selbst", "sich",
    "sie", "ihnen",
    "sind",
    "so",
    "solche", "solchem", "solchen", "solcher", "solches",
    "soll", "sollte",
    "sondern", "sonst",
    "über",
    "um",
    "und",
    "uns", "unse", "unsem", "unsen", "unser", "unses",
    "unter",
    "viel",
    "vom", "von", "vor",
    "während",
    "war", "waren", "warst",
    "was",
    "weg",
    "weil",
    "weiter",
    "welche", "welchem", "welchen", "welcher", "welches",
    "wenn",
    "werde", "werden",
    "wie",
    "wieder",
    "will",
    "wir",
    "wird",
    "wirst",
    "wo",
    "wollen", "wollte",
    "würde", "würden",
    "zu", "zum", "zur",
    "zwar",
    "zwischen"
]

# %%
import json
import re
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
_whitespace = re.compile(r"\s+")

def json_to_text(doc: dict) -> str:
    """
    Serialisiert das komplette Expertenprofil zu einem String.
    """
    # Deterministic JSON serialization for indexing or scoring.
    return json.dumps(doc, ensure_ascii=False)


def normalize(text: str) -> str:
    """
    Minimale Normalisierung
    """
    # Lowercase for case-insensitive comparison.
    text = text.lower()

    # Collapse multiple whitespace characters into single space.
    text = _whitespace.sub(" ", text).strip()

    return text

# %%
def build_tfidf_index(
    expert_profiles: list[dict],
    min_df: int | float = 2,
    max_df: int | float = 0.95,
    ngram_range: tuple[int, int] = (1, 1),
):
    """
    Baut den TF-IDF Index über vollständige JSON-Profile.
    """

    # Convert each expert profile to normalized text representation.
    texts = [
        normalize(json_to_text(profile))
        for profile in expert_profiles
    ]

    print(texts)  # Debug: inspect generated corpus

    # Configure TF-IDF vectorizer with controlled preprocessing.
    vectorizer = TfidfVectorizer(
        lowercase=True,
        stop_words=GERMAN_STOPWORDS,
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        sublinear_tf=False,
        norm="l2",
        token_pattern=r"(?u)\b\w\w+\b",
    )

    # Fit vectorizer and transform corpus into sparse TF-IDF matrix.
    X = vectorizer.fit_transform(texts)  # shape: (n_docs, n_terms)

    return vectorizer, X

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidf_search(
    query: str,
    vectorizer: TfidfVectorizer,
    X,
    expert_profiles: list[dict],
    top_k: int = 10,
):
    """
    Führt eine TF-IDF Suche aus und gibt Top-k Treffer im benötigten Format zurück.

    Output pro Treffer:
      - id: bevorzugt expert_profile["id"], sonst doc_index
      - payload: komplettes Expertenprofil (dict)
      - score: TF-IDF Similarity Score (float)
    """

    # Transform normalized query into TF-IDF vector.
    q = vectorizer.transform([normalize(query)])   # shape: (1, n_terms)

    # Compute cosine similarity via dot product (L2-normalized).
    scores = (X @ q.T).toarray().ravel()           # shape: (n_docs,)

    # Select top-k indices (partial sort for efficiency).
    k = min(top_k, len(scores))
    idx = np.argpartition(-scores, k - 1)[:k]
    idx = idx[np.argsort(-scores[idx])]            # sort top-k by score desc

    results = []

    for i in idx:
        payload = expert_profiles[int(i)]

        # Prefer explicit document ID if available.
        doc_id = (
            payload.get("id", int(i))
            if isinstance(payload, dict)
            else int(i)
        )

        results.append({
            "id": doc_id,
            "payload": payload,
            "score": float(scores[int(i)]),
        })

    return results

# %%
vectorizer, X = build_tfidf_index(expert_data)
# Out:
# ['{"branches": ["technologie", "medien & werbung", "unternehmensdienstleistungen"], "companylocationcity": "lennestadt", "companylocationstreet": "hagener straße 64", "companylocationzip": 57368.0, "companyname": "lenne.tech gmbh", "companytypes": ["dienstleistung"], "companywebsite": "https://lenne.tech", "description": "seit über 15 jahren begleite ich digitale projekte von der konzeption bis zur \\"schlüsselfertigen\\" anwendung. als mitglied im team von lenne.tech (https://lenne.tech) entwickle ich apps & webanwendungen und unterstütze unternehmen beim aufbau sowie bei der weiterbildung von entwicklungsteams. im rahmen unserer lenne.learning akademie (https://lennelearning.de) organisiere ich gemeinsam mit anderen tutoren & mentoren das recruiting sowie das onboarding neuer entwickler für partnerunternehmen.", "employeeofinstitutionnames": [], "firstname": "ege", "gender": "male", "id": "65acfb5a3897d6f0e6506db1", "jobtitle": "softwareentwickler", "lastname": "siebert", "projectsdescription": "lenne.tech unterstützt unternehmen, selbstständige, bildungsinstitutionen und gründungs- sowie technikinteressierte bei allen fragen rund um die themen app- & webentwicklung sowie digitalisierung.", "skills": ["softwareentwicklung", "web-entwicklung", "it-systemadministration", "programmierkenntnisse", "design", "cloud-computing", "devops", "content management", "data analysis", "systemverwaltung"], "title": null, "full_text": "ege siebert ist softwareentwickler mit umfangreichen kompetenzen in softwareentwicklung, web-entwicklung, it-systemadministration, programmierkenntnissen, design, cloud-computing, devops, content management, data analysis und systemverwaltung. seit über 15 jahren begleitet er digitale projekte von der konzeption bis zur schlüsselfertigen anwendung. als mitglied des teams von lenne.tech (https://lenne.tech) entwickelt er apps und webanwendungen und unterstützt unternehmen beim aufbau sowie bei der weiterbildung von entwicklungsteams. im rahmen der lenne.learning akademie (https://lennelearning.de) organisiert er gemeinsam mit anderen tutoren & mentoren das recruiting sowie das onboarding neuer entwickler für partnerunternehmen. die von lenne.tech betreuten projekte richten sich an unternehmen, selbstständige, bildungsinstitutionen sowie gründungs- und technikinteressierte und behandeln fragen rund um app- und webentwicklung sowie digitalisierung. der arbeitskontext umfasst technologie, medien & werbung sowie unternehmensdienstleistungen."}', '{"branches": ["unternehmensdienstleistungen"], "companylocationcity": "lüdenscheid", "companylocationstreet": "sauerfelder straße 5", "companylocationzip": 58511.0, "companyname": "regiokonnex", "companytypes": ["dienstleistung"], "companywebsite": "www.regiokonnex.de", "description": "ich bin mitglied von team regiokonnex und stehe ihnen bei fragen und anmerkungen gerne zur verfügung.\\n\\nfür die swf beratung gmbh unterstütze ich sie in sachen phishing-awareness \\nund sicherheit zu aktuellen betrugsszenarien in ihrer financial chain.\\nfür die volksbank in südwestfalen eg stehe ich als zert. zahlungsverkehrsberater in sachen electronic banking zur verfügung", "employeeofinstitutionnames": ["regiokonnex"], "firstname": "hendrik", "gender": "male", "id": "65ad7c463897d6f0e6508e88", "jobtitle": "administrator, projektmanager", "lastname": "nöh", "projectsdescription": "als angebot der swf beratung gmbh unterstützen wir sie bei themen zu:\\n- gründung und nachfolge\\n- businessplanerstellung\\n- fördermittelberatung\\n- netzwerken und konnexen", "skills": ["financial management", "cybersecurity", "finance", "business process analysis", "business continuity", "customer relationship management"], "title": null, "full_text": "hendrik nöh ist administrator und projektmanager bei regiokonnex, einem dienstleistungsunternehmen in lüdenscheid, im bereich unternehmensdienstleistungen. er verfügt über kompetenzen in financial management, cybersecurity, finance, business process analy ...

# %%
# Optional: local accumulator (currently unused).
pool_rows = []

# Iterate over evaluation queries and perform TF-IDF retrieval.
for query in queries_for_pooling:

    # Execute sparse lexical search.
    results = tfidf_search(
        query=query,
        vectorizer=vectorizer,
        X=X,
        expert_profiles=expert_data,
        top_k=LIMIT,
    )

    # Basic logging.
    print(query)
    print(results)
    print("Found Docs: ", len(results))

    # Append retrieval results to pooling DataFrame.
    pool_df = append_retrieval_results_to_pool(
        pool_df,
        search_method="tf-idf",
        query=query,
        rel_docs=results,
    )
# Out:
# IT-Systemadministration
# [{'id': '6682c449680d5b5995b4229d', 'payload': {'branches': ['Technologie', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Hagen', 'companyLocationStreet': 'Hochofenstr. 22 ', 'companyLocationZip': 58135.0, 'companyName': 'stepIT.net Operations GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.stepIT.net', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Domenic', 'gender': 'MALE', 'id': '6682c449680d5b5995b4229d', 'jobTitle': 'CEO', 'lastName': 'Wartenberg', 'projectsDescription': None, 'skills': ['IT-Management', 'IT-Systemadministration', 'Human Resources', 'Information Technology', 'Cybersecurity'], 'title': None, 'full_text': 'Domenic Wartenberg verfügt als CEO der stepIT.net Operations GmbH über ausgeprägte Kompetenzen in IT-Management, IT-Systemadministration, Information Technology, Human Resources und Cybersecurity. In den Bereichen Technologie und Unternehmensdienstleistungen setzt er seine Expertise gezielt ein.'}, 'score': 0.30855802333953886}, {'id': '660fe785b5bb2b1c9a9440b3', 'payload': {'branches': ['Technologie', 'Unternehmensdienstleistungen', 'Konsum und Handel'], 'companyLocationCity': 'Soest', 'companyLocationStreet': 'Giselherweg 6', 'companyLocationZip': 59494.0, 'companyName': 'MERSMANN PRUDLO GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'mersmann-prudlo.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Jarno', 'gender': 'MALE', 'id': '660fe785b5bb2b1c9a9440b3', 'jobTitle': 'Geschäftsführer', 'lastName': 'Reichardt', 'projectsDescription': None, 'skills': ['Cybersecurity', 'Networking', 'Cloud-Computing', 'IT-Management', 'IT-Systemadministration', 'Datenbankverwaltung', 'Programmierkenntnisse', 'Programmiersprachen', 'Softwareentwicklung', 'Web-Entwicklung'], 'title': None, 'full_text': 'Jarno Reichardt ist Geschäftsführer und verfügt über umfassende Kompetenzen in Cybersecurity, Networking, Cloud-Computing, IT-Management, IT-Systemadministration, Datenbankverwaltung, Programmierkenntnisse, Programmiersprachen, Softwareentwicklung und Web-Entwicklung. Er wendet seine Fähigkeiten in den Bereichen Technologie, Unternehmensdienstleistungen und Konsum und Handel an.'}, 'score': 0.3005553782298499}, {'id': '65ba06be3897d6f0e653f0cc', 'payload': {'branches': ['Technologie', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Balve', 'companyLocationStreet': 'Am Bahnhof 5', 'companyLocationZip': 58802.0, 'companyName': 'WKN Datentechnik GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'https://www.wkn-datentechnik.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Tarik', 'gender': 'MALE', 'id': '65ba06be3897d6f0e653f0cc', 'jobTitle': 'Geschäftsführer', 'lastName': 'Erdmann', 'projectsDescription': 'IT-Systemhaus, IT-Infrastruktur, IT-Sicherheit, Managed Services\nGebäudesicherheit, Kameratechnik, Gefahrenmeldeanlagen, Zutrittskontrolle\nSoftware, SAP Business One, ELO Dokumentenmanagement, Microsoft 365, Zeiterfassung\nKommunikation, Telefonanlagen, 3CX, Microsoft Teams, Collaboration\nBeratung, Infrastrukturanalysen, IT-Strategie, Cyber Risk Check, IT-Notfallpläne, Cert+, Fördermittel', 'skills': ['Cybersecurity', 'Cloud-Computing', 'IT-Management', 'IT-Systemadministration', 'Risk Assessment', 'Business Continuity', 'Coaching', 'Business Process Analysis', 'Strategy Planning', 'Risikomanagement'], 'title': None, 'full_text': 'Tarik Erdmann ist Geschäftsführer und verfügt über umfassende Kompetenzen in Cybersecurity, Cloud-Computing, IT-Management, IT-Systemadministration, Risk Assessment, Business Continuity, Coaching, Business Process Analysis, Strategy Planning und Risikomanagement. Er deckt ein breites Spektrum ab, darunter IT-Systemhaus, IT-Infrastruktur, IT-Sicherheit und Managed Services sowie Gebäudesicherheit, Kameratechnik, Gefahrenmeldeanlagen und Zutrittskontrolle. In der Softwarelandschaft arbeitet er mit SAP Business One, ELO Dokumentenmanagement, Microsoft 365 und Zeit ...
# Found Docs:  5
# Information Technology
# [{'id': '67c7fc6871a73f24d52ba5fb', 'payload': {'branches': ['Unternehmensdienstleistungen'], 'companyLocationCity': 'Hagen', 'companyLocationStreet': 'Bahnhofstr. 18', 'companyLocationZip': 58095.0, 'companyName': 'SIHK zu Hagen', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.sihk.de', 'description': '', 'employeeOfInstitutionNames': [], 'firstName': 'Lion', 'gender': 'MALE', 'id': '67c7fc6871a73f24d52ba5fb', 'jobTitle': 'Team Digitale Chancen', 'lastName': 'Bogdashin', 'projectsDescription': None, 'skills': ['Cybersecurity', 'Information Technology', 'Texterstellung', 'Storytelling', 'Change Management'], 'title': 'DR', 'full_text': 'Lion Bogdashin verfügt über fundierte Kompetenzen in Cybersecurity, Information Technology, Texterstellung, Storytelling und Change Management. Er arbeitet im Team Digitale Chancen der SIHK zu Hagen im Bereich Unternehmensdienstleistungen.'}, 'score': 0.3153060829610826}, {'id': '66f6a8daea427f28c0170fdd', 'payload': {'branches': ['Automobilindustrie', 'Technologie', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Siegen', 'companyLocationStreet': 'Mörikestr. 83', 'companyLocationZip': 57074.0, 'companyName': 'MWTEST GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'mwtest.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Phil', 'gender': 'MALE', 'id': '66f6a8daea427f28c0170fdd', 'jobTitle': 'Geschäftsführer', 'lastName': 'Hauke', 'projectsDescription': None, 'skills': ['Data Analysis', 'Fahrzeug- und Maschinentechnik', 'Information Technology', 'Ingenieurwesen', 'Programmierkenntnisse', 'Programmiersprachen', 'Projektmanagement', 'Softwareentwicklung'], 'title': None, 'full_text': 'Phil Hauke ist Geschäftsführer der MWTEST GmbH. Er verfügt über fundierte Kompetenzen in Data Analysis, Fahrzeug- und Maschinentechnik, Information Technology, Ingenieurwesen, Programmierkenntnisse, Programmiersprachen, Projektmanagement sowie Softwareentwicklung. In der Automobilindustrie, Technologie und Unternehmensdienstleistungen setzt er seine Fähigkeiten gezielt ein.'}, 'score': 0.30719545940083137}, {'id': '6682c449680d5b5995b4229d', 'payload': {'branches': ['Technologie', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Hagen', 'companyLocationStreet': 'Hochofenstr. 22 ', 'companyLocationZip': 58135.0, 'companyName': 'stepIT.net Operations GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.stepIT.net', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Domenic', 'gender': 'MALE', 'id': '6682c449680d5b5995b4229d', 'jobTitle': 'CEO', 'lastName': 'Wartenberg', 'projectsDescription': None, 'skills': ['IT-Management', 'IT-Systemadministration', 'Human Resources', 'Information Technology', 'Cybersecurity'], 'title': None, 'full_text': 'Domenic Wartenberg verfügt als CEO der stepIT.net Operations GmbH über ausgeprägte Kompetenzen in IT-Management, IT-Systemadministration, Information Technology, Human Resources und Cybersecurity. In den Bereichen Technologie und Unternehmensdienstleistungen setzt er seine Expertise gezielt ein.'}, 'score': 0.2941960200346737}, {'id': '673f9e67b546838eefbfc16f', 'payload': {'branches': ['Medien & Werbung', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Hamm', 'companyLocationStreet': 'Sternstrasse 4', 'companyLocationZip': 59065.0, 'companyName': 'Institut für Barrierefreheit', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'https://ifba.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Antonio', 'gender': 'MALE', 'id': '673f9e67b546838eefbfc16f', 'jobTitle': None, 'lastName': 'Cleem', 'projectsDescription': 'Institut für Barrierefreiheit\nBildungsträger\nWirtschaftsinformatiker', 'skills': ['Information Technology', 'Programmierkenntnisse', 'Marketing', 'Social Media Marketing', 'Google AdWords', 'Suchmaschinenoptimierung (SEO)'], 'title': None, 'full_text': 'Antonio Cleem verfügt über Kompetenzen in Information Technology, Programmierkenntniss ...
# Found Docs:  5
# Wissensmanagement
# [{'id': '667509fc7be18d55a064b5ee', 'payload': {'branches': ['Automobilindustrie'], 'companyLocationCity': 'Neuenrade', 'companyLocationStreet': 'Hönnestr. 32', 'companyLocationZip': 58809.0, 'companyName': 'ALCAR Leichtmetallräder Produktion GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.alcar-produktion.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Leyla', 'gender': 'FEMALE', 'id': '667509fc7be18d55a064b5ee', 'jobTitle': 'Teamleitung Einkauf', 'lastName': 'Hardy', 'projectsDescription': 'Aluminiumräder für KFZ', 'skills': ['Projektmanagement', 'Wissensmanagement', 'Supply Chain Management', 'Personalmanagement', 'Fach- und Methodenkenntnisse'], 'title': None, 'full_text': 'Diese Expertin Leyla Hardy verfügt über ausgeprägte Kompetenzen in Projektmanagement, Wissensmanagement, Supply Chain Management, Personalmanagement sowie Fach- und Methodenkenntnisse. In ihrer Rolle als Teamleitung Einkauf bei der Aluminiumräderproduktion für Kraftfahrzeuge fokussiert sie sich auf Aluminiumräder für KFZ in der Automobilindustrie und setzt ihr Know-how ein, um Beschaffungsprozesse, Wissensmanagement und die Personalführung zu optimieren.'}, 'score': 0.23388886023443353}, {'id': '66d5c842528e751260e5401d', 'payload': {'branches': ['Technologie', 'Immobilien', 'Medien & Werbung', 'Logistik', 'Bildung und Weiterbildung', 'Gesundheitswesen', 'Automobilindustrie', 'Reisen und Unterhaltung', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Unternehmensdienstleistungen', 'Investor (Eigenkapital)', 'Wissenschaft und Forschung'], 'companyLocationCity': 'Meschede', 'companyLocationStreet': 'Lindenstraße 53', 'companyLocationZip': 59872.0, 'companyName': 'Fachhochschule Südwestfalen', 'companyTypes': ['Dienstleistung'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Andrea', 'gender': 'FEMALE', 'id': '66d5c842528e751260e5401d', 'jobTitle': 'Wissenschaftliche Mitarbeiterin', 'lastName': 'Nagel', 'projectsDescription': None, 'skills': ['Change Management', 'Projektmanagement', 'Personalmanagement', 'Coaching', 'Communication', 'Forschung', 'Human Resources', 'Marketing', 'Stakeholder Management', 'Wissensmanagement'], 'title': None, 'full_text': 'Andrea Nagel ist eine Wissenschaftliche Mitarbeiterin. Sie verfügt über ausgeprägte Kompetenzen in Change Management, Projektmanagement, Personalmanagement, Coaching, Communication, Forschung, Human Resources, Marketing, Stakeholder Management und Wissensmanagement. Zu ihrem Arbeitsfeld gehören Branchen wie Technologie, Immobilien, Medien & Werbung, Logistik, Bildung und Weiterbildung, Gesundheitswesen, Automobilindustrie, Reisen und Unterhaltung, Energie und Umwelt, Bau und Infrastruktur, Unternehmensdienstleistungen, Investor (Eigenkapital) sowie Wissenschaft und Forschung.'}, 'score': 0.19638183200516862}, {'id': '66714a7036b0c2e419598eb7', 'payload': {'branches': ['Technologie', 'Immobilien', 'Medien & Werbung', 'Logistik', 'Bildung und Weiterbildung', 'Gesundheitswesen', 'Automobilindustrie', 'Reisen und Unterhaltung', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Unternehmensdienstleistungen', 'Investor (Eigenkapital)', 'Wissenschaft und Forschung'], 'companyLocationCity': 'Hagen ', 'companyLocationStreet': 'Universitätsstraße 47', 'companyLocationZip': 58097.0, 'companyName': 'FernUniversität in Hagen', 'companyTypes': ['Industrie'], 'companyWebsite': 'https://www.fernuni-hagen.de/', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Ahmad', 'gender': 'MALE', 'id': '66714a7036b0c2e419598eb7', 'jobTitle': 'Wissenschaftlicher Mitarbeiter', 'lastName': 'Hessler', 'projectsDescription': None, 'skills': ['Wissensmanagement', 'Relationship Management', 'Forschung', 'Data Analysis', 'Projektmanagement'], 'title': None, 'full_text': 'Ahmad Hessler verfügt über ausgeprägte Kompetenzen im Wissensmanagement, Relationship Management, Forschung, Data Analysis und Projektmanagement. In seiner Rolle als Wissensch ...
# Found Docs:  5
# Konstruktion
# [{'id': '66fa95b8b8bd3932bf709599', 'payload': {'branches': ['Bau und Infrastruktur', 'Handwerk'], 'companyLocationCity': 'Meschede', 'companyLocationStreet': 'Bremkeweg 33', 'companyLocationZip': 59872.0, 'companyName': 'Winterhoff GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.winterhoff-holzbau.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Robin', 'gender': 'MALE', 'id': '66fa95b8b8bd3932bf709599', 'jobTitle': 'Holzbauunternehmer', 'lastName': 'Liebold', 'projectsDescription': None, 'skills': ['Bau- und Ausbauhandwerk', 'Holzhandwerk', 'Ingenieurwesen', 'Konstruktion'], 'title': None, 'full_text': 'Robin Liebold ist Holzbauunternehmer und verfügt über Kompetenzen im Bau- und Ausbauhandwerk, Holzhandwerk, Ingenieurwesen und Konstruktion. Bei der Winterhoff GmbH in Meschede setzt er diese Fähigkeiten im Bereich Bau und Infrastruktur sowie Handwerk gezielt ein, um Holzbauten zu planen, zu konstruieren und umzusetzen.'}, 'score': 0.2127718872535578}, {'id': '66ea8cfe41f659468bdd6b30', 'payload': {'branches': ['Unternehmensdienstleistungen', 'Maschinenbau und Industrieprodukte', 'Technologie'], 'companyLocationCity': 'Soest', 'companyLocationStreet': 'Lübecker Ring 2', 'companyLocationZip': 59494.0, 'companyName': 'Fachhochschule Südwestfalen', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'https://digitalise-swf.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Vincent', 'gender': 'MALE', 'id': '66ea8cfe41f659468bdd6b30', 'jobTitle': 'Koordinator VI GF Digitalise_SWF', 'lastName': 'Tschiers', 'projectsDescription': None, 'skills': ['Autodesk Inventor', 'CAD-Systeme', 'Design', 'Fach- und Methodenkenntnisse', 'Forschung', 'Konstruktion'], 'title': None, 'full_text': 'Vincent Tschiers ist Koordinator VI GF Digitalise_SWF und verfügt über Kompetenzen in Autodesk Inventor, CAD-Systemen, Design sowie Fach- und Methodenkenntnisse, Forschung und Konstruktion. Er setzt diese Fähigkeiten in den Branchen Unternehmensdienstleistungen, Maschinenbau und Industrieprodukte sowie Technologie ein.'}, 'score': 0.19801987371870355}, {'id': '6602b09eadfff2e2b6505922', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Lüdenscheid', 'companyLocationStreet': 'Gielster Stück 4', 'companyLocationZip': 58513.0, 'companyName': 'Mickenhagen GmbH & Co.KG', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.mickenhagen.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Cecilia', 'gender': 'FEMALE', 'id': '6602b09eadfff2e2b6505922', 'jobTitle': 'Geschäftsführerin', 'lastName': 'Schley', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Elektroinstallation', 'Elektrotechnik', 'Ingenieurwesen', 'Installationstechnik', 'Konstruktion'], 'title': None, 'full_text': 'Frau Cecilia Schley verfügt über ausgeprägte Kompetenzen im Anlagenbau, der Elektroinstallation, Elektrotechnik, Ingenieurwesen, Installationstechnik und Konstruktion. Als Geschäftsführerin der Mickenhagen GmbH & Co.KG in Lüdenscheid setzt sie diese Fähigkeiten in einem industriell geprägten Umfeld ein, das Branchen wie Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau umfasst.'}, 'score': 0.1884536062567227}, {'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutio ...
# Found Docs:  5
# Metallhandwerk
# [{'id': '65d64dc361580d8db5016c26', 'payload': {'branches': ['Handwerk'], 'companyLocationCity': 'Iserlohn', 'companyLocationStreet': 'Stennerstr 8', 'companyLocationZip': 58636.0, 'companyName': 'Hörkunst Imhoff', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'Www.hoerkunst.net', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Miray', 'gender': 'FEMALE', 'id': '65d64dc361580d8db5016c26', 'jobTitle': 'Hörakustikmeisterin', 'lastName': 'Bräutigam', 'projectsDescription': None, 'skills': ['Cloud-Computing', 'Elektroinstallation', 'Elektrotechnik', 'Holzhandwerk', 'Metallhandwerk', 'Programmiersprachen', 'SAP', 'Softwareentwicklung', 'Web-Entwicklung'], 'title': None, 'full_text': 'Miray Bräutigam ist Hörakustikmeisterin und im Handwerk tätig. Sie verfügt über umfangreiche handwerkliche Kompetenzen in Elektroinstallation, Elektrotechnik, Holz- und Metallhandwerk sowie über fundierte IT- und Softwarekenntnisse in Cloud-Computing, Programmiersprachen, SAP, Softwareentwicklung und Web-Entwicklung.'}, 'score': 0.1806895975057869}, {'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Fabian', 'gender': 'MALE', 'id': '65e6c43a763465cfa7de8ad9', 'jobTitle': 'Vertrieb', 'lastName': 'Lewin', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Metallhandwerk', 'Mechanik', 'Konstruktion', 'Schweißen', 'Bau- und Ausbauhandwerk', 'CAD-Systeme', 'Elektrotechnik', 'Installationstechnik', 'Logistik'], 'title': None, 'full_text': 'Fabian Lewin ist im Vertrieb der Industriebranche bei Rappstahl tätig, Standort Plettenberg. Er verfügt über umfassende Fähigkeiten in Anlagenbau, Metallhandwerk, Mechanik, Konstruktion, Schweißen, Bau- und Ausbauhandwerk, CAD-Systeme, Elektrotechnik, Installationstechnik und Logistik. Seine Branchenkompetenz deckt die Bereiche Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau ab.'}, 'score': 0.15833753403997178}, {'id': '65e5e245763465cfa7de5cda', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstrasse 30', 'companyLocationZip': 58840.0, 'companyName': 'RAPP GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Yannick', 'gender': 'MALE', 'id': '65e5e245763465cfa7de5cda', 'jobTitle': 'Stahlkaufmann , Geschäftsleitung', 'lastName': 'Axmann', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Automatisierungstechnik', 'Elektrotechnik', 'Fahrzeug- und Maschinentechnik', 'Handwerk in der Gesundheitsbranche', 'Mechanik', 'Metallhandwerk', 'Projektmanagement', 'Schweißen', 'Supply Chain Management'], 'title': None, 'full_text': 'Yannick Axmann ist Stahlkaufmann in der Geschäftsleitung. Er verfügt über fundierte Kompetenzen in Anlagenbau, Automatisierungstechnik, Elektrotechnik, Fahrzeug- und Maschinentechnik, Mechanik, Metallhandwerk, Schweißen, Projektmanagement sowie Supply Chain Management; zudem bringt er handwerkliche Erfahrungen aus der Gesundheitsbranche mit. Diese Fähigkeiten wendet er branchenübergreifend an, unter anderem in Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau.'},  ...
# Found Docs:  5
# Mechanik
# [{'id': '65b8e06c3897d6f0e653ab47', 'payload': {'branches': ['Handwerk', 'Maschinenbau und Industrieprodukte', 'Verpackungsindustrie'], 'companyLocationCity': 'Neuenrade', 'companyLocationStreet': '4 Neue Mühle', 'companyLocationZip': 58809.0, 'companyName': 'H.Büsche GmbH Antonio Mazziotti', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.buesche.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Juri', 'gender': 'MALE', 'id': '65b8e06c3897d6f0e653ab47', 'jobTitle': 'Vetriebsleitung', 'lastName': 'Wischer', 'projectsDescription': None, 'skills': ['Design', 'Benutzeroberflächen-Design', 'Prototyping', 'Autodesk Inventor', 'Adobe Creative Cloud', 'Elektroinstallation', 'Mechanik'], 'title': None, 'full_text': 'Dieser Experte verfügt über fundierte Kompetenzen im Design, in der Benutzeroberflächen-Gestaltung und im Prototyping. Er beherrscht Autodesk Inventor sowie Adobe Creative Cloud und wendet seine Fähigkeiten in Elektroinstallation und Mechanik praktisch an. In der Vetriebsleitung tätig, arbeitet er branchenübergreifend in Handwerk, Maschinenbau und Industrieprodukte sowie in der Verpackungsindustrie.'}, 'score': 0.1866090842110637}, {'id': '67bcce17d72097890fc3c3d8', 'payload': {'branches': ['Maschinenbau und Industrieprodukte', 'Unternehmensdienstleistungen', 'Konsum und Handel'], 'companyLocationCity': 'Meinerzhagen', 'companyLocationStreet': 'Heerstr. 7', 'companyLocationZip': 58540.0, 'companyName': 'tim tools-in-motion GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'Www.tools-in-motion.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Niclas', 'gender': 'MALE', 'id': '67bcce17d72097890fc3c3d8', 'jobTitle': 'Geschäftsführer', 'lastName': 'Mayer', 'projectsDescription': None, 'skills': ['Supply Chain Management', 'Unternehmensführung', 'Sales', 'Anlagenbau', 'Automatisierungstechnik', 'Mechanik', 'Qualitätssicherung'], 'title': None, 'full_text': 'Niclas Mayer ist Geschäftsführer der tim tools-in-motion GmbH. In dieser Funktion leitet er ein Unternehmen, das in den Bereichen Maschinenbau und Industrieprodukte, Unternehmensdienstleistungen sowie Konsum und Handel tätig ist. Seine Kernkompetenzen umfassen Supply Chain Management, Unternehmensführung, Sales, Anlagenbau, Automatisierungstechnik, Mechanik und Qualitätssicherung, die er gezielt in der Steuerung von Lieferketten, Fertigungsprozessen und qualitätsorientierten Abläufen einsetzt.'}, 'score': 0.17056982933685133}, {'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Fabian', 'gender': 'MALE', 'id': '65e6c43a763465cfa7de8ad9', 'jobTitle': 'Vertrieb', 'lastName': 'Lewin', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Metallhandwerk', 'Mechanik', 'Konstruktion', 'Schweißen', 'Bau- und Ausbauhandwerk', 'CAD-Systeme', 'Elektrotechnik', 'Installationstechnik', 'Logistik'], 'title': None, 'full_text': 'Fabian Lewin ist im Vertrieb der Industriebranche bei Rappstahl tätig, Standort Plettenberg. Er verfügt über umfassende Fähigkeiten in Anlagenbau, Metallhandwerk, Mechanik, Konstruktion, Schweißen, Bau- und Ausbauhandwerk, CAD-Systeme, Elektrotechnik, Installationstechnik und Logistik. Seine Branchenkompetenz deckt die Bereiche Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau ab.'}, 'score': 0.16741566690146406}, {'id': '65e5e245763465cfa7de5cda', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackun ...
# Found Docs:  5
# Automatisierungstechnik
# [{'id': '67bcce17d72097890fc3c3d8', 'payload': {'branches': ['Maschinenbau und Industrieprodukte', 'Unternehmensdienstleistungen', 'Konsum und Handel'], 'companyLocationCity': 'Meinerzhagen', 'companyLocationStreet': 'Heerstr. 7', 'companyLocationZip': 58540.0, 'companyName': 'tim tools-in-motion GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'Www.tools-in-motion.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Niclas', 'gender': 'MALE', 'id': '67bcce17d72097890fc3c3d8', 'jobTitle': 'Geschäftsführer', 'lastName': 'Mayer', 'projectsDescription': None, 'skills': ['Supply Chain Management', 'Unternehmensführung', 'Sales', 'Anlagenbau', 'Automatisierungstechnik', 'Mechanik', 'Qualitätssicherung'], 'title': None, 'full_text': 'Niclas Mayer ist Geschäftsführer der tim tools-in-motion GmbH. In dieser Funktion leitet er ein Unternehmen, das in den Bereichen Maschinenbau und Industrieprodukte, Unternehmensdienstleistungen sowie Konsum und Handel tätig ist. Seine Kernkompetenzen umfassen Supply Chain Management, Unternehmensführung, Sales, Anlagenbau, Automatisierungstechnik, Mechanik und Qualitätssicherung, die er gezielt in der Steuerung von Lieferketten, Fertigungsprozessen und qualitätsorientierten Abläufen einsetzt.'}, 'score': 0.1680679599478748}, {'id': '67487abbb546838eefc5467d', 'payload': {'branches': ['Unternehmensdienstleistungen'], 'companyLocationCity': 'Arnsberg', 'companyLocationStreet': 'Voßwinkler Straße 19', 'companyLocationZip': 59757.0, 'companyName': 'aiXtrusion GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'https://aixtrusion.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Pius', 'gender': 'MALE', 'id': '67487abbb546838eefc5467d', 'jobTitle': 'Business Development Manager', 'lastName': 'Erhardt', 'projectsDescription': 'Hard- und Softwareentwicklung, Embedded Systems, Informations Systeme, Industrielle Bildverarbeitung, Automationstechnik', 'skills': ['Business Development', 'Marketing', 'Business Planning', 'Projektmanagement', 'Automatisierungstechnik', 'Unternehmensführung'], 'title': None, 'full_text': 'Dieser Experte ist Pius Erhardt. Als Business Development Manager arbeitet er in der Unternehmensdienstleistungen-Branche. Er verfügt über fundierte Kompetenzen in Business Development, Marketing, Business Planning, Projektmanagement, Automatisierungstechnik und Unternehmensführung. In seinen Projekten deckt er Hard- und Softwareentwicklung, Embedded Systems, Informations Systeme, Industrielle Bildverarbeitung und Automationstechnik ab.'}, 'score': 0.16643939821153342}, {'id': '65e5e245763465cfa7de5cda', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstrasse 30', 'companyLocationZip': 58840.0, 'companyName': 'RAPP GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Yannick', 'gender': 'MALE', 'id': '65e5e245763465cfa7de5cda', 'jobTitle': 'Stahlkaufmann , Geschäftsleitung', 'lastName': 'Axmann', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Automatisierungstechnik', 'Elektrotechnik', 'Fahrzeug- und Maschinentechnik', 'Handwerk in der Gesundheitsbranche', 'Mechanik', 'Metallhandwerk', 'Projektmanagement', 'Schweißen', 'Supply Chain Management'], 'title': None, 'full_text': 'Yannick Axmann ist Stahlkaufmann in der Geschäftsleitung. Er verfügt über fundierte Kompetenzen in Anlagenbau, Automatisierungstechnik, Elektrotechnik, Fahrzeug- und Maschinentechnik, Mechanik, Metallhandwerk, Schweißen, Projektmanagement sowie Supply Chain Management; zudem bringt er handwerkliche Erfahrungen aus der Gesundheitsbranche mit. Diese Fähigkeiten wendet er branchenübergreifend an, unter anderem in Technologie, Automobilindustrie, Verpa ...
# Found Docs:  5
# Elektrotechnik
# [{'id': '673e38c7b546838eefbed554', 'payload': {'branches': ['Technologie', 'Energie und Umwelt'], 'companyLocationCity': 'Netphen', 'companyLocationStreet': 'Obere Industriestraße 8', 'companyLocationZip': 57250.0, 'companyName': 'effexx green GmbH', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.effexx.com', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Corvin', 'gender': 'MALE', 'id': '673e38c7b546838eefbed554', 'jobTitle': 'Vertriebsbeauftragter', 'lastName': 'Rautenkranz', 'projectsDescription': None, 'skills': ['Elektroinstallation', 'Elektrotechnik'], 'title': None, 'full_text': 'Corvin Rautenkranz arbeitet als Vertriebsbeauftragter und verfügt über Kompetenzen in Elektroinstallation und Elektrotechnik. Sein Einsatz erfolgt im Umfeld der Technologie- sowie der Energie- und Umweltbranche.'}, 'score': 0.22038613815536587}, {'id': '67502162cc9cf2f9a1e5dd7d', 'payload': {'branches': ['Technologie', 'Konsum und Handel'], 'companyLocationCity': 'Schalksmühle', 'companyLocationStreet': 'Langenstück 5', 'companyLocationZip': 58579.0, 'companyName': '2direct GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.2direct.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Hassan', 'gender': 'MALE', 'id': '67502162cc9cf2f9a1e5dd7d', 'jobTitle': 'Geschäftsführender Gesellschafter', 'lastName': 'Gabler', 'projectsDescription': None, 'skills': ['Business Analysis', 'Coaching', 'Datentechnik', 'Elektrotechnik', 'Finanzplanung', 'Marketing', 'Performance Management', 'Sales', 'Unternehmensführung', 'Strategy Planning'], 'title': None, 'full_text': 'Hassan Gabler verfügt über ausgeprägte Kompetenzen in Business Analysis, Coaching, Datentechnik, Elektrotechnik, Finanzplanung, Marketing, Performance Management, Sales, Unternehmensführung und Strategy Planning. Als Geschäftsführender Gesellschafter nutzt er diese Fähigkeiten in Führungs- und Strategieaufgaben, insbesondere in den Branchen Technologie sowie Konsum und Handel.'}, 'score': 0.18412915820411502}, {'id': '65d64dc361580d8db5016c26', 'payload': {'branches': ['Handwerk'], 'companyLocationCity': 'Iserlohn', 'companyLocationStreet': 'Stennerstr 8', 'companyLocationZip': 58636.0, 'companyName': 'Hörkunst Imhoff', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'Www.hoerkunst.net', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Miray', 'gender': 'FEMALE', 'id': '65d64dc361580d8db5016c26', 'jobTitle': 'Hörakustikmeisterin', 'lastName': 'Bräutigam', 'projectsDescription': None, 'skills': ['Cloud-Computing', 'Elektroinstallation', 'Elektrotechnik', 'Holzhandwerk', 'Metallhandwerk', 'Programmiersprachen', 'SAP', 'Softwareentwicklung', 'Web-Entwicklung'], 'title': None, 'full_text': 'Miray Bräutigam ist Hörakustikmeisterin und im Handwerk tätig. Sie verfügt über umfangreiche handwerkliche Kompetenzen in Elektroinstallation, Elektrotechnik, Holz- und Metallhandwerk sowie über fundierte IT- und Softwarekenntnisse in Cloud-Computing, Programmiersprachen, SAP, Softwareentwicklung und Web-Entwicklung.'}, 'score': 0.18308159048278347}, {'id': '6602b09eadfff2e2b6505922', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Lüdenscheid', 'companyLocationStreet': 'Gielster Stück 4', 'companyLocationZip': 58513.0, 'companyName': 'Mickenhagen GmbH & Co.KG', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.mickenhagen.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Cecilia', 'gender': 'FEMALE', 'id': '6602b09eadfff2e2b6505922', 'jobTitle': 'Geschäftsführerin', 'lastName': 'Schley', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Elektroinstallation', 'Elektrotechnik', 'Ingenieurwesen', 'Installationstechnik', 'Konstruktion'], 'title': None, 'full_text': 'Frau Cecilia Schley verfügt über ausgeprägte K ...
# Found Docs:  5
# Konstruktion, Metallhandwerk
# [{'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Fabian', 'gender': 'MALE', 'id': '65e6c43a763465cfa7de8ad9', 'jobTitle': 'Vertrieb', 'lastName': 'Lewin', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Metallhandwerk', 'Mechanik', 'Konstruktion', 'Schweißen', 'Bau- und Ausbauhandwerk', 'CAD-Systeme', 'Elektrotechnik', 'Installationstechnik', 'Logistik'], 'title': None, 'full_text': 'Fabian Lewin ist im Vertrieb der Industriebranche bei Rappstahl tätig, Standort Plettenberg. Er verfügt über umfassende Fähigkeiten in Anlagenbau, Metallhandwerk, Mechanik, Konstruktion, Schweißen, Bau- und Ausbauhandwerk, CAD-Systeme, Elektrotechnik, Installationstechnik und Logistik. Seine Branchenkompetenz deckt die Bereiche Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau ab.'}, 'score': 0.24152230318791948}, {'id': '6825a43b0b2e403ede005227', 'payload': {'branches': ['Automobilindustrie', 'Handwerk'], 'companyLocationCity': 'LUEDENSCHEID', 'companyLocationStreet': 'STABERGER STRASSE 15', 'companyLocationZip': 58511.0, 'companyName': 'Eugen Plate Werkzeugbau e.kfm. Inh. Janis Keizer', 'companyTypes': ['Industrie'], 'companyWebsite': 'https://www.eugenplate-werkzeugbau.de/', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Merlin', 'gender': 'MALE', 'id': '6825a43b0b2e403ede005227', 'jobTitle': None, 'lastName': 'Gutschank', 'projectsDescription': None, 'skills': ['Anlagenbau', 'CAD-Systeme', 'Fach- und Methodenkenntnisse', 'Fahrzeug- und Maschinentechnik', 'Metallhandwerk', 'Konstruktion', 'Prototyping', 'Projektmanagement', 'Automatisierungstechnik'], 'title': None, 'full_text': 'Merlin Gutschank ist ein erfahrener Fachmann im Anlagenbau und in der Fahrzeug- und Maschinentechnik. Er verfügt über fundierte Kenntnisse in CAD-Systemen, im Metallhandwerk sowie in Konstruktion und Prototyping. Zudem bringt er Fach- und Methodenkenntnisse, Projektmanagement und Automatisierungstechnik mit, die er gezielt zur Planung, Entwicklung und Umsetzung technischer Lösungen einsetzt. Seine Arbeitsschwerpunkte liegen in der Automobilindustrie und im Handwerk, wo er komplexe Systeme entwirft, baut und optimiert.'}, 'score': 0.22998763028570826}, {'id': '6787e53d5d12164fde53eb7a', 'payload': {'branches': ['Handwerk', 'Maschinenbau und Industrieprodukte', 'Verpackungsindustrie'], 'companyLocationCity': 'Niederkrüchten', 'companyLocationStreet': None, 'companyLocationZip': 41372.0, 'companyName': 'Ich bin privat hier...', 'companyTypes': ['Industrie'], 'companyWebsite': 'https://youtu.be/t0348EKSPME', 'description': 'Was sagt Ihr zu meiner Erfindung ? \nIch freue mich über jede Info ! \nAch ja mein zweites Gebrauchsmuster ist auch fertig. Inklusiv Prototyp.\nTitel: Drehbarer Pumpenkörper in modularer Bauweise.', 'employeeOfInstitutionNames': [], 'firstName': 'Eric', 'gender': 'MALE', 'id': '6787e53d5d12164fde53eb7a', 'jobTitle': 'Betriebsschlosser und Erfinder', 'lastName': 'Herberger', 'projectsDescription': 'https://youtu.be/t0348EKSPME', 'skills': ['Anlagenbau', 'Installationstechnik', 'Klempnerarbeiten', 'Konstruktion', 'Mechanik', 'Metallhandwerk'], 'title': None, 'full_text': 'Eric Herberger ist Betriebsschlosser und Erfinder. Er verfügt über Kompetenzen im Anlagenbau, Installationstechnik, Klempnerarbeiten, Konstruktion, Mechanik und Metallhandwerk. In seinen Projekten präsentiert er techniknahe Lösungen, darunter eine Erfindung mit dem Titel Dre ...
# Found Docs:  5
# Mechanik, Elektrotechnik
# [{'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Fabian', 'gender': 'MALE', 'id': '65e6c43a763465cfa7de8ad9', 'jobTitle': 'Vertrieb', 'lastName': 'Lewin', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Metallhandwerk', 'Mechanik', 'Konstruktion', 'Schweißen', 'Bau- und Ausbauhandwerk', 'CAD-Systeme', 'Elektrotechnik', 'Installationstechnik', 'Logistik'], 'title': None, 'full_text': 'Fabian Lewin ist im Vertrieb der Industriebranche bei Rappstahl tätig, Standort Plettenberg. Er verfügt über umfassende Fähigkeiten in Anlagenbau, Metallhandwerk, Mechanik, Konstruktion, Schweißen, Bau- und Ausbauhandwerk, CAD-Systeme, Elektrotechnik, Installationstechnik und Logistik. Seine Branchenkompetenz deckt die Bereiche Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau ab.'}, 'score': 0.23187702415642536}, {'id': '65e5e245763465cfa7de5cda', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstrasse 30', 'companyLocationZip': 58840.0, 'companyName': 'RAPP GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Yannick', 'gender': 'MALE', 'id': '65e5e245763465cfa7de5cda', 'jobTitle': 'Stahlkaufmann , Geschäftsleitung', 'lastName': 'Axmann', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Automatisierungstechnik', 'Elektrotechnik', 'Fahrzeug- und Maschinentechnik', 'Handwerk in der Gesundheitsbranche', 'Mechanik', 'Metallhandwerk', 'Projektmanagement', 'Schweißen', 'Supply Chain Management'], 'title': None, 'full_text': 'Yannick Axmann ist Stahlkaufmann in der Geschäftsleitung. Er verfügt über fundierte Kompetenzen in Anlagenbau, Automatisierungstechnik, Elektrotechnik, Fahrzeug- und Maschinentechnik, Mechanik, Metallhandwerk, Schweißen, Projektmanagement sowie Supply Chain Management; zudem bringt er handwerkliche Erfahrungen aus der Gesundheitsbranche mit. Diese Fähigkeiten wendet er branchenübergreifend an, unter anderem in Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau.'}, 'score': 0.23055425069766414}, {'id': '673e3883b546838eefbed497', 'payload': {'branches': ['Handwerk', 'Logistik'], 'companyLocationCity': 'Haiger', 'companyLocationStreet': 'Kaltreiche-Ring 4', 'companyLocationZip': 35708.0, 'companyName': 'Kstom Factory GmbH & Co.KG', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'http://www.kstom-factory.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Maksim', 'gender': 'MALE', 'id': '673e3883b546838eefbed497', 'jobTitle': None, 'lastName': 'Felke', 'projectsDescription': 'KFZ Meisterbetrieb, Fahrzeugaus- und Sonderbau, Blaulicht, Handwerker, Camper', 'skills': ['Coaching', 'Elektroinstallation', 'Elektrotechnik', 'Fach- und Methodenkenntnisse', 'Fahrzeug- und Maschinentechnik', 'Logistik', 'Mechanik'], 'title': None, 'full_text': 'Maksim Felke verfügt über umfassende Kompetenzen in Coaching, Elektroinstallation, Elektrotechnik, Fach- und Methodenkenntnisse, Fahrzeug- und Maschinentechnik, Logistik sowie Mechanik. Zu seinen Projekten gehören der KFZ Meisterbetrieb, Fahrzeugaus- und  ...
# Found Docs:  5
# Metallhandwerk, Mechanik
# [{'id': '65e6c43a763465cfa7de8ad9', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstraße', 'companyLocationZip': 58840.0, 'companyName': 'Rappstahl', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.rappstahl.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Fabian', 'gender': 'MALE', 'id': '65e6c43a763465cfa7de8ad9', 'jobTitle': 'Vertrieb', 'lastName': 'Lewin', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Metallhandwerk', 'Mechanik', 'Konstruktion', 'Schweißen', 'Bau- und Ausbauhandwerk', 'CAD-Systeme', 'Elektrotechnik', 'Installationstechnik', 'Logistik'], 'title': None, 'full_text': 'Fabian Lewin ist im Vertrieb der Industriebranche bei Rappstahl tätig, Standort Plettenberg. Er verfügt über umfassende Fähigkeiten in Anlagenbau, Metallhandwerk, Mechanik, Konstruktion, Schweißen, Bau- und Ausbauhandwerk, CAD-Systeme, Elektrotechnik, Installationstechnik und Logistik. Seine Branchenkompetenz deckt die Bereiche Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau ab.'}, 'score': 0.23043172570182519}, {'id': '65e5e245763465cfa7de5cda', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Plettenberg', 'companyLocationStreet': 'Bannewerthstrasse 30', 'companyLocationZip': 58840.0, 'companyName': 'RAPP GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Yannick', 'gender': 'MALE', 'id': '65e5e245763465cfa7de5cda', 'jobTitle': 'Stahlkaufmann , Geschäftsleitung', 'lastName': 'Axmann', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Automatisierungstechnik', 'Elektrotechnik', 'Fahrzeug- und Maschinentechnik', 'Handwerk in der Gesundheitsbranche', 'Mechanik', 'Metallhandwerk', 'Projektmanagement', 'Schweißen', 'Supply Chain Management'], 'title': None, 'full_text': 'Yannick Axmann ist Stahlkaufmann in der Geschäftsleitung. Er verfügt über fundierte Kompetenzen in Anlagenbau, Automatisierungstechnik, Elektrotechnik, Fahrzeug- und Maschinentechnik, Mechanik, Metallhandwerk, Schweißen, Projektmanagement sowie Supply Chain Management; zudem bringt er handwerkliche Erfahrungen aus der Gesundheitsbranche mit. Diese Fähigkeiten wendet er branchenübergreifend an, unter anderem in Technologie, Automobilindustrie, Verpackungsindustrie, Maschinenbau und Industrieprodukte, Energie und Umwelt, Bau und Infrastruktur, Chemie und Kunststoff sowie Bergbau.'}, 'score': 0.22911719714116321}, {'id': '65d6500661580d8db5016d93', 'payload': {'branches': ['Technologie', 'Automobilindustrie', 'Verpackungsindustrie', 'Maschinenbau und Industrieprodukte', 'Energie und Umwelt', 'Bau und Infrastruktur', 'Chemie und Kunststoff', 'Bergbau'], 'companyLocationCity': 'Hemer', 'companyLocationStreet': 'Otto-Rentzing Str.10', 'companyLocationZip': 58675.0, 'companyName': 'Althaus Gosch GmbH ', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.althaus-Rohrschellen.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Zara', 'gender': 'FEMALE', 'id': '65d6500661580d8db5016d93', 'jobTitle': 'Geschäftsführerin', 'lastName': 'Bender', 'projectsDescription': None, 'skills': ['Anlagenbau', 'Automatisierungstechnik', 'Bau- und Ausbauhandwerk', 'Elektroinstallation', 'Fahrzeug- und Maschinentechnik', 'Mechanik', 'Metallhandwerk', 'Sanitär- und Versorgungstechnik', 'Schweißen'], 'title': None, 'full_text': 'Diese Expertin verfügt über ausgeprägte Kompetenzen im Anlagenbau, Automatisierungstechnik, Bau- und Ausba ...
# Found Docs:  5
# Metallhandwerk, Elektrotechnik
# ...
# Found Docs:  5
# Digital Ethics, Business Development
# [{'id': '65e1c8cc61580d8db503d8d9', 'payload': {'branches': ['Automobilindustrie'], 'companyLocationCity': 'Neuenrade', 'companyLocationStreet': 'Hüttenweg 6', 'companyLocationZip': 58809.0, 'companyName': 'A. Wendland GmbH', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.wendland.tech', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Lorenz', 'gender': 'MALE', 'id': '65e1c8cc61580d8db503d8d9', 'jobTitle': 'Geschäftsführer', 'lastName': 'Mohr', 'projectsDescription': None, 'skills': ['Business Development', 'Change Management', 'Cloud-Computing', 'Controlling', 'Content Management', 'Data Analysis', 'Digital Ethics', 'Entrepreneurship', 'Marketing', 'Projektmanagement'], 'title': None, 'full_text': 'Dieser Geschäftsführer verfügt über umfangreiche Fähigkeiten in Business Development, Change Management, Cloud-Computing, Controlling, Content Management, Data Analysis, Digital Ethics, Entrepreneurship, Marketing sowie Projektmanagement. In der Automobilindustrie setzt er diese Kompetenzen als Geschäftsführer der A. Wendland GmbH gezielt ein.'}, 'score': 0.34012505519657465}, {'id': '661bbe92b5bb2b1c9a96b6df', 'payload': {'branches': ['Automobilindustrie', 'Maschinenbau und Industrieprodukte'], 'companyLocationCity': 'Neuenrade', 'companyLocationStreet': 'Hönnestraße 32 ', 'companyLocationZip': 58809.0, 'companyName': 'ALCAR Leichtmetallräder Produktion GmbH ', 'companyTypes': ['Industrie'], 'companyWebsite': 'www.alcar-produktion.de', 'description': 'Hallo- ich bin Geschäftsführer eines „Autoräderhersteller“ aus Aluminium. Ich suche hierüber Vernetzung um Kooperationen im Personal-, Einkaufsbereich und Energiebereich zu finden.', 'employeeOfInstitutionNames': [], 'firstName': 'Marlon', 'gender': 'MALE', 'id': '661bbe92b5bb2b1c9a96b6df', 'jobTitle': 'Geschäftsführer ', 'lastName': 'Schuff', 'projectsDescription': None, 'skills': ['Business Planning', 'Projektmanagement', 'Digital Ethics', 'Business Development', 'Business Analysis', 'Change Management', 'Budget Planning', 'Entrepreneurship', 'Financial Management'], 'title': None, 'full_text': 'Dieser Experte verfügt über ausgeprägte Kompetenzen in Business Planning, Projektmanagement, Digital Ethics, Business Development, Business Analysis, Change Management, Budget Planning, Entrepreneurship und Financial Management. Als Geschäftsführer eines Aluminium-Autoräderherstellers sucht er gezielt nach Vernetzung, um Kooperationen im Personal-, Einkaufs- und Energiebereich zu ermöglichen. Er arbeitet in den Branchen Automobilindustrie sowie Maschinenbau und Industrieprodukte.'}, 'score': 0.2653879945245216}, {'id': '65d7231961580d8db501a564', 'payload': {'branches': ['Reisen und Unterhaltung'], 'companyLocationCity': 'Meschede', 'companyLocationStreet': 'Rietbüsche 49', 'companyLocationZip': 59872.0, 'companyName': 'SeaLand-pro', 'companyTypes': ['Einzelhandel'], 'companyWebsite': 'www.sealand-pro.de', 'description': 'Leidenschaft für das etwas "andere"....', 'employeeOfInstitutionNames': [], 'firstName': 'Michel', 'gender': 'MALE', 'id': '65d7231961580d8db501a564', 'jobTitle': 'Inhaber', 'lastName': 'Riethmüller', 'projectsDescription': None, 'skills': ['Marketing', 'Sales', 'Supply Chain Management', 'Digital Ethics', 'Customer Relationship Management', 'Business Development', 'Google Analytics', 'Public Relations'], 'title': None, 'full_text': 'Michel Riethmüller ist Inhaber von SeaLand-pro, einem Einzelhandelsunternehmen mit Sitz in Meschede. Er verfügt über Kompetenzen in Marketing, Sales, Supply Chain Management, Digital Ethics, Customer Relationship Management, Business Development, Google Analytics und Public Relations. Seine Beschreibung betont eine Leidenschaft für das etwas "andere".... Der Kontext seiner Tätigkeit wird durch die Branche Reisen und Unterhaltung ergänzt.'}, 'score': 0.25318962690480284}, {'id': '67840dda5d12164fde5177c0', 'payload': {'branches': [], 'companyLocationCity': 'Kierspe', 'companyLocationStreet': 'Fliedertsraße 26', 'comp ...
# Found Docs:  5
# Business Planning, Business Process Analysis
# [{'id': '65ca9b4561580d8db5ff02b9', 'payload': {'branches': ['Immobilien', 'Unternehmensdienstleistungen'], 'companyLocationCity': 'Lüdenscheid', 'companyLocationStreet': 'Sauerfelder Str. 5', 'companyLocationZip': 58509.0, 'companyName': 'Volksbank in Südwestfalen eG', 'companyTypes': ['Dienstleistung'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Liv', 'gender': 'FEMALE', 'id': '65ca9b4561580d8db5ff02b9', 'jobTitle': 'Abteilungsleitung Firmenkundenassistenz', 'lastName': 'Verzi', 'projectsDescription': None, 'skills': ['Change Management', 'Business Planning', 'Business Process Analysis', 'Operations Management', 'Planning', 'Strategy Planning', 'Supply Chain Management', 'Controlling', 'Performance Management'], 'title': None, 'full_text': 'Diese Expertin verfügt über ausgeprägte Kompetenzen in Change Management, Business Planning, Business Process Analysis, Operations Management, Planning, Strategy Planning, Supply Chain Management, Controlling und Performance Management. In ihrer Rolle als Abteilungsleitung Firmenkundenassistenz setzt sie diese Fähigkeiten in den Bereichen Immobilien und Unternehmensdienstleistungen gezielt ein.'}, 'score': 0.3213381082474787}, {'id': '65d64dae61580d8db5016c17', 'payload': {'branches': ['Unternehmensdienstleistungen'], 'companyLocationCity': 'Iserlohn', 'companyLocationStreet': 'Corunnastr. 1', 'companyLocationZip': 58636.0, 'companyName': 'Top Glory Marine Service GmbH & Co. KG', 'companyTypes': ['Dienstleistung'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Bianca', 'gender': 'FEMALE', 'id': '65d64dae61580d8db5016c17', 'jobTitle': 'Geschäftsführerin ', 'lastName': 'Salzmann', 'projectsDescription': None, 'skills': ['Business Planning', 'Business Analysis', 'Business Development', 'Finance', 'Budget Planning', 'Controlling', 'Financial Management', 'Business Process Analysis', 'Accounting', 'Budgeting'], 'title': None, 'full_text': 'Bianca Salzmann verfügt über umfassende Kompetenzen in Business Planning, Business Analysis, Business Development, Finance, Budget Planning, Controlling, Financial Management, Business Process Analysis, Accounting und Budgeting. Sie ist in der Branche Unternehmensdienstleistungen tätig und führt als Geschäftsführerin die Top Glory Marine Service GmbH & Co. KG in Iserlohn.'}, 'score': 0.30929733917558777}, {'id': '65b138fe3897d6f0e651ac75', 'payload': {'branches': ['Medien & Werbung'], 'companyLocationCity': '58095 Hagen', 'companyLocationStreet': 'Bahnhofstraße 18', 'companyLocationZip': 58095.0, 'companyName': 'SIHK zu Hagen', 'companyTypes': ['Dienstleistung'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Iven', 'gender': 'MALE', 'id': '65b138fe3897d6f0e651ac75', 'jobTitle': 'Teamleiter', 'lastName': 'Camara', 'projectsDescription': None, 'skills': ['Projektmanagement', 'Planning', 'Change Management', 'Business Planning', 'Business Process Analysis', 'Operations Management', 'Strategy Planning', 'Programmierkenntnisse'], 'title': None, 'full_text': 'Iven Camara verfügt über ausgeprägte Kompetenzen in Projektmanagement, Planning, Change Management, Business Planning, Business Process Analysis, Operations Management, Strategy Planning sowie Programmierkenntnisse. In seiner Rolle als Teamleiter plant er Strategien, leitet Teams, optimiert Geschäftsprozesse und setzt Veränderungsmanagement um. Sein Einsatz erfolgt im Bereich Medien & Werbung.'}, 'score': 0.30078297067841}, {'id': '65b1525c3897d6f0e651b697', 'payload': {'branches': ['Unternehmensdienstleistungen', 'Investor (Eigenkapital)'], 'companyLocationCity': 'Lüdenscheid', 'companyLocationStreet': 'Zur Normandie 7', 'companyLocationZip': 58507.0, 'companyName': 'Steuerberater Hoeder Widua Krägeloh ', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.stb-hwk.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Emre', 'gender': 'MALE' ...
# Found Docs:  5
# Business Development, Business Process Analysis
# [{'id': '65b1525c3897d6f0e651b697', 'payload': {'branches': ['Unternehmensdienstleistungen', 'Investor (Eigenkapital)'], 'companyLocationCity': 'Lüdenscheid', 'companyLocationStreet': 'Zur Normandie 7', 'companyLocationZip': 58507.0, 'companyName': 'Steuerberater Hoeder Widua Krägeloh ', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.stb-hwk.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Emre', 'gender': 'MALE', 'id': '65b1525c3897d6f0e651b697', 'jobTitle': 'Steuerberater ', 'lastName': 'Mohrhard', 'projectsDescription': None, 'skills': ['Accounting', 'Buchhaltung', 'Business Development', 'Business Planning', 'Business Process Analysis', 'Entrepreneurship', 'Financial Management', 'Finanzplanung', 'Geschäftsmodellentwicklung', 'Unternehmensführung'], 'title': None, 'full_text': 'Dieser Experte verfügt über umfassende Kompetenzen in Accounting, Buchhaltung, Business Development, Business Planning, Business Process Analysis, Entrepreneurship, Financial Management, Finanzplanung, Geschäftsmodellentwicklung und Unternehmensführung. Als Steuerberater arbeitet er im Bereich Unternehmensdienstleistungen und Investor (Eigenkapital).'}, 'score': 0.29307731822842253}, {'id': '65d64dae61580d8db5016c17', 'payload': {'branches': ['Unternehmensdienstleistungen'], 'companyLocationCity': 'Iserlohn', 'companyLocationStreet': 'Corunnastr. 1', 'companyLocationZip': 58636.0, 'companyName': 'Top Glory Marine Service GmbH & Co. KG', 'companyTypes': ['Dienstleistung'], 'companyWebsite': None, 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Bianca', 'gender': 'FEMALE', 'id': '65d64dae61580d8db5016c17', 'jobTitle': 'Geschäftsführerin ', 'lastName': 'Salzmann', 'projectsDescription': None, 'skills': ['Business Planning', 'Business Analysis', 'Business Development', 'Finance', 'Budget Planning', 'Controlling', 'Financial Management', 'Business Process Analysis', 'Accounting', 'Budgeting'], 'title': None, 'full_text': 'Bianca Salzmann verfügt über umfassende Kompetenzen in Business Planning, Business Analysis, Business Development, Finance, Budget Planning, Controlling, Financial Management, Business Process Analysis, Accounting und Budgeting. Sie ist in der Branche Unternehmensdienstleistungen tätig und führt als Geschäftsführerin die Top Glory Marine Service GmbH & Co. KG in Iserlohn.'}, 'score': 0.29055321645695775}, {'id': '6638bc9268131729196ea198', 'payload': {'branches': ['Investor (Eigenkapital)', 'Unternehmensdienstleistungen', 'Immobilien'], 'companyLocationCity': 'Attendorn', 'companyLocationStreet': 'Niederste Straße 22-24', 'companyLocationZip': 57439.0, 'companyName': 'Volksbank Sauerland eG', 'companyTypes': ['Dienstleistung'], 'companyWebsite': 'www.vb-sauerland.de', 'description': None, 'employeeOfInstitutionNames': [], 'firstName': 'Caspar', 'gender': 'MALE', 'id': '6638bc9268131729196ea198', 'jobTitle': 'Regionalmarktleiter Firmenkunden', 'lastName': 'Kofferschlager', 'projectsDescription': None, 'skills': ['Business Planning', 'Business Analysis', 'Business Development', 'Finance', 'Budget Planning', 'Controlling', 'Financial Management', 'Business Process Analysis', 'Accounting', 'Budgeting'], 'title': None, 'full_text': 'Caspar Kofferschlager ist Regionalmarktleiter Firmenkunden. Er verfügt über ausgeprägte Kompetenzen in Business Planning, Business Analysis, Business Development, Finance, Budget Planning, Controlling, Financial Management, Business Process Analysis, Accounting und Budgeting. In dieser Funktion plant, analysiert und steuert er das Firmenkundengeschäft, bewertet Finanzkennzahlen und Budgets, entwickelt strategische Ansätze und optimiert Prozesse sowie Finanzabläufe. Er arbeitet in den Branchen Investor (Eigenkapital), Unternehmensdienstleistungen und Immobilien.'}, 'score': 0.2701501681044074}, {'id': '65c5e1d861580d8db5fe02d4', 'payload': {'branches': ['Investor (Eigenkapital)', 'Unternehmensdienstleistungen', 'Immobilien'], 'companyLocationCity': 'Lüdensc ...
# Found Docs:  5

# %%
# nach jedem Methodenlauf oder Query
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# Added data from  {'tf-idf'}

# %% [markdown]
# ## Fetch pool documents for BM25

# %%
#https://dl.acm.org/doi/10.1145/2682862.2682863

# %%
# !pip install rank-bm25
# Out:
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rank-bm25) (2.0.2)

# %%
from __future__ import annotations

from rank_bm25 import BM25Okapi
import json
import re
from typing import Iterable, Sequence
import numpy as np


# Precompiled regex for performance (used in normalize / tokenize)
_whitespace = re.compile(r"\s+")
_token_re = re.compile(r"(?u)\b\w\w+\b")  # gleiche Token-Definition wie TF-IDF


def json_to_text(doc: dict) -> str:
    """Serialisiert ein Expertenprofil (dict) deterministisch zu Text."""
    return json.dumps(doc, ensure_ascii=False)


def normalize(text: str) -> str:
    """Lowercase + Whitespace-Normalisierung."""
    text = text.lower()
    text = _whitespace.sub(" ", text).strip()
    return text


def tokenize(text: str) -> list[str]:
    """
    Tokenisierung analog zur TF-IDF-Konfiguration:
    - mindestens 2 Wortzeichen
    - Unicode-aware
    """
    return _token_re.findall(text)


def preprocess_for_retrieval(
    text: str,
    *,
    stop_words: set[str] | None = None,
    ngram_range: tuple[int, int] = (1, 1),
) -> list[str]:
    """
    Einheitliches Preprocessing für Retrieval (TF-IDF / BM25).

    Pipeline:
      1. normalize
      2. tokenize
      3. optional Stopwort-Filter
      4. optional N-Gram-Generierung
    """
    tokens = tokenize(normalize(text))

    # Stopwort-Filter optional
    if stop_words:
        tokens = [t for t in tokens if t not in stop_words]

    n_min, n_max = ngram_range
    if (n_min, n_max) == (1, 1):
        return tokens  # Baseline: Unigrams

    # N-Gram-Generierung (nur falls explizit gewünscht)
    out: list[str] = []
    L = len(tokens)

    for n in range(n_min, n_max + 1):
        if n <= 0:
            continue
        for i in range(0, L - n + 1):
            out.append(" ".join(tokens[i : i + n]))

    return out


def build_bm25_index(
    expert_profiles: Sequence[dict],
    *,
    stop_words: set[str] | None = None,
    ngram_range: tuple[int, int] = (1, 1),   # Default: Unigrams
    k1: float = 2,
    b: float = 0.5,
) -> tuple[BM25Okapi, list[list[str]]]:
    """
    Baut einen BM25-Index über Expertenprofile.

    Rückgabe:
      - bm25 Instanz
      - tokenisierte Dokumente (für Debugging / Analyse)
    """
    tokenized_docs = [
        preprocess_for_retrieval(
            json_to_text(p),
            stop_words=stop_words,
            ngram_range=ngram_range,
        )
        for p in expert_profiles
    ]

    bm25 = BM25Okapi(tokenized_docs, k1=k1, b=b)
    return bm25, tokenized_docs


def bm25_search(
    query: str,
    bm25: BM25Okapi,
    expert_profiles: Sequence[dict],
    *,
    stop_words: set[str] | None = None,
    ngram_range: tuple[int, int] = (1, 1),  # Default: Unigrams
    top_k: int = 10,
):
    """
    Führt eine BM25-Suche aus.

    Rückgabeformat (kompatibel zu TF-IDF-Variante):
      - id
      - payload (Originalprofil)
      - score (BM25)
    """
    # Query-Preprocessing identisch zur Indexierung
    q_tokens = preprocess_for_retrieval(
        query,
        stop_words=stop_words,
        ngram_range=ngram_range,
    )

    # BM25 Score-Berechnung (Shape: n_docs,)
    scores = bm25.get_scores(q_tokens)

    k = min(top_k, len(scores))

    # Effiziente Top-k Selektion ohne vollständiges Sorting
    idx = np.argpartition(-scores, k - 1)[:k]
    idx = idx[np.argsort(-scores[idx])]  # finale Sortierung

    results = []

    for i in idx:
        payload = expert_profiles[i]
        doc_id = payload.get("id") if isinstance(payload, dict) else None

        results.append({
            "id": doc_id,
            "payload": payload,
            "score": float(scores[i]),
        })

    return results

# %%
tokenized_docs = [
    preprocess_for_retrieval(json_to_text(p), stop_words=GERMAN_STOPWORDS, ngram_range=(1, 1))
    for p in expert_data
]

tokenized_docs[:1]

# %%
# Build the BM25 index using identical preprocessing as TF-IDF
# → ensures a fair methodological comparison in the retrieval experiment
bm25, tokenized_docs = build_bm25_index(
    expert_data,
    stop_words=GERMAN_STOPWORDS,   # same stopword list as TF-IDF
    ngram_range=(1, 1),            # baseline: unigrams
    k1=2,
    b=0.5,
)


# Iterate over all evaluation queries (pooling setup)
for query in queries_for_pooling:

    # Execute retrieval with preprocessing parameters consistent with indexing
    results = bm25_search(
        query,
        bm25,
        expert_data,
        stop_words=GERMAN_STOPWORDS,
        ngram_range=(1, 1),
        top_k=LIMIT,               # only top-k documents contribute to the pool
    )

    # Append results to the shared relevance pool
    # → forms the basis for manual relevance assessment and method comparison
    pool_df = append_retrieval_results_to_pool(
          pool_df,
          search_method="okapi_bm25",
          query=query,
          rel_docs=results,
    )

# %%
pool_df
# Out:
#                              search_method  \
# 0     distiluse-base-multilingual-cased-v2
# 1     distiluse-base-multilingual-cased-v2
# 2     distiluse-base-multilingual-cased-v2
# 3     distiluse-base-multilingual-cased-v2
# 4     distiluse-base-multilingual-cased-v2
# ...                                    ...
# 2515                            okapi_bm25
# 2516                            okapi_bm25
# 2517                            okapi_bm25
# 2518                            okapi_bm25
# 2519                            okapi_bm25
#
#                                                 query  \
# 0                             IT-Systemadministration
# 1                             IT-Systemadministration
# 2                             IT-Systemadministration
# 3                             IT-Systemadministration
# 4                             IT-Systemadministration
# ...                                               ...
# 2515  Business Development, Business Process Analysis
# 2516  Business Development, Business Process Analysis
# 2517  Business Development, Business Process Analysis
# 2518  Business Development, Business Process Analysis
# 2519  Business Development, Business Process Analysis
#
#                         doc_id  \
# 0     67251b202f496742be0ea207
# 1     671f67692f496742be0b1d80
# 2     6670848036b0c2e419593c7c
# 3     65b0d5453897d6f0e6516f88
# 4     671f67082f496742be0b1d07
# ...                        ...
# 2515  65d64dae61580d8db5016c17
# 2516  65b1525c3897d6f0e651b697
# 2517  6638bc9268131729196ea198
# 2518  65aff66a3897d6f0e6512478
# 2519  65c5e1d861580d8db5fe02d4
#
#                                                 doc_raw     score
# 0     {"branches": [], "companyLocationCity": "Wuppe...  0.207031
# 1     {"branches": ["Technologie"], "companyLocation...  0.109566
# 2     {"branches": ["Technologie"], "companyLocation...  0.107298
# 3     {"branches": ["Technologie"], "companyLocation...  0.105019
# 4     {"branches": ["Technologie", "Unternehmensdien...  0.094808
# ...                                                 ...       ...
# 2515  {'branches': ['Unternehmensdienstleistungen'],...  7.047387
# 2516  {'branches': ['Unternehmensdienstleistungen', ...  6.887179
# 2517  {'branches': ['Investor (Eigenkapital)', 'Unte...  6.785589
# 2518  {'branches': ['Unternehmensdienstleistungen'],...  6.726348
# 2519  {'branches': ['Investor (Eigenkapital)', 'Unte...  6.593943
#
# [2520 rows x 5 columns]

# %%
# nach jedem Methodenlauf oder Query
append_pool_df_to_csv(pool_df, PATH_TEST_COLLECTION_DATA + "pooling_results_raw.csv")
# Out:
# Added data from  {'okapi_bm25'}

# %% [markdown]
# ## Generate cleaned pool
#
# After the raw pooling results are generated the data needs to be depulicated to get the final pool.
#
# **Caution**:
# The following code cells should only be run if the raw data includes search results from every of the above pooling methods. This leads to that the raw data must contain a combined amount of 5040 datarows. Otherwise some of the methods had not run yet or they run multiple times. So ensure that each method produces 840 rows in the dataset.

# %%
import pandas as pd
from pathlib import Path

# Construct absolute path to the raw pooling results file
pool_path = Path(PATH_TEST_COLLECTION_DATA) / "pooling_results_raw.csv"

# Load existing pooling results if available
if pool_path.exists():
    print("Found")
    pool_df = pd.read_csv(pool_path)
else:
    # No prior pooling file found (e.g., first experimental run)
    print("Not Found")
# Out:
# Found

# %%
pool_df
# Out:
#                              search_method  \
# 0     distiluse-base-multilingual-cased-v2
# 1     distiluse-base-multilingual-cased-v2
# 2     distiluse-base-multilingual-cased-v2
# 3     distiluse-base-multilingual-cased-v2
# 4     distiluse-base-multilingual-cased-v2
# ...                                    ...
# 2515                            okapi_bm25
# 2516                            okapi_bm25
# 2517                            okapi_bm25
# 2518                            okapi_bm25
# 2519                            okapi_bm25
#
#                                                 query  \
# 0                             IT-Systemadministration
# 1                             IT-Systemadministration
# 2                             IT-Systemadministration
# 3                             IT-Systemadministration
# 4                             IT-Systemadministration
# ...                                               ...
# 2515  Business Development, Business Process Analysis
# 2516  Business Development, Business Process Analysis
# 2517  Business Development, Business Process Analysis
# 2518  Business Development, Business Process Analysis
# 2519  Business Development, Business Process Analysis
#
#                         doc_id  \
# 0     67251b202f496742be0ea207
# 1     671f67692f496742be0b1d80
# 2     6670848036b0c2e419593c7c
# 3     65b0d5453897d6f0e6516f88
# 4     671f67082f496742be0b1d07
# ...                        ...
# 2515  65d64dae61580d8db5016c17
# 2516  65b1525c3897d6f0e651b697
# 2517  6638bc9268131729196ea198
# 2518  65aff66a3897d6f0e6512478
# 2519  65c5e1d861580d8db5fe02d4
#
#                                                 doc_raw     score
# 0     {"branches": [], "companyLocationCity": "Wuppe...  0.207031
# 1     {"branches": ["Technologie"], "companyLocation...  0.109566
# 2     {"branches": ["Technologie"], "companyLocation...  0.107298
# 3     {"branches": ["Technologie"], "companyLocation...  0.105019
# 4     {"branches": ["Technologie", "Unternehmensdien...  0.094808
# ...                                                 ...       ...
# 2515  {"branches": ["Unternehmensdienstleistungen"],...  7.047387
# 2516  {"branches": ["Unternehmensdienstleistungen", ...  6.887179
# 2517  {"branches": ["Investor (Eigenkapital)", "Unte...  6.785589
# 2518  {"branches": ["Unternehmensdienstleistungen"],...  6.726348
# 2519  {"branches": ["Investor (Eigenkapital)", "Unte...  6.593943
#
# [2520 rows x 5 columns]

# %%
# Deduplicate pooled documents by document ID
# ensures each document appears only once in the final assessment set
unique_docs_df = (
    pool_df
    .drop_duplicates(subset=["doc_id"])
    .loc[:, ["doc_id", "doc_raw"]]  # keep only relevant columns
    .reset_index(drop=True)         # clean sequential indexing
)

# Log size reduction after deduplication (sanity check)
print(len(pool_df), "→", len(unique_docs_df))

# Preview resulting unique document set
unique_docs_df.head()
# Out:
# 2520 → 259
#                      doc_id                                            doc_raw
# 0  67251b202f496742be0ea207  {"branches": [], "companyLocationCity": "Wuppe...
# 1  671f67692f496742be0b1d80  {"branches": ["Technologie"], "companyLocation...
# 2  6670848036b0c2e419593c7c  {"branches": ["Technologie"], "companyLocation...
# 3  65b0d5453897d6f0e6516f88  {"branches": ["Technologie"], "companyLocation...
# 4  671f67082f496742be0b1d07  {"branches": ["Technologie", "Unternehmensdien...

# %%
# Map original expert profiles back into the pooled DataFrame
import json

# Build lookup table: profile_id (str) → full profile dict
# → enables deterministic reconstruction of original payload
expert_map = {str(p["id"]): p for p in expert_data if "id" in p}

# Ensure consistent ID type for mapping (string-based join key)
unique_docs_df["doc_id"] = unique_docs_df["doc_id"].astype(str)

# Attach full profile dictionary to each pooled document
unique_docs_df["profile_dict"] = unique_docs_df["doc_id"].map(expert_map)

# Overwrite raw document field with canonical JSON serialization
# → guarantees consistent representation for later relevance assessment
unique_docs_df["doc_raw"] = unique_docs_df["profile_dict"].apply(
    lambda d: json.dumps(d, ensure_ascii=False, default=str)
    if isinstance(d, dict) else None
)

# %%
unique_docs_df
# Out:
#                        doc_id  \
# 0    67251b202f496742be0ea207
# 1    671f67692f496742be0b1d80
# 2    6670848036b0c2e419593c7c
# 3    65b0d5453897d6f0e6516f88
# 4    671f67082f496742be0b1d07
# ..                        ...
# 254  65b817053897d6f0e6537dce
# 255  65fae369763465cfa7e2b79f
# 256  6683ea8108d4ee614ef75c50
# 257  673328df51c382bea60f7ef8
# 258  65aff66a3897d6f0e6512478
#
#                                                doc_raw  \
# 0    {"branches": [], "companyLocationCity": "Wuppe...
# 1    {"branches": ["Technologie"], "companyLocation...
# 2    {"branches": ["Technologie"], "companyLocation...
# 3    {"branches": ["Technologie"], "companyLocation...
# 4    {"branches": ["Technologie", "Unternehmensdien...
# ..                                                 ...
# 254  {"branches": ["Technologie", "Immobilien", "Me...
# 255  {"branches": ["Investor (Eigenkapital)", "Unte...
# 256  {"branches": ["Gesundheitswesen"], "companyLoc...
# 257  {"branches": ["Technologie", "Automobilindustr...
# 258  {"branches": ["Unternehmensdienstleistungen"],...
#
#                                           profile_dict
# 0    {'branches': [], 'companyLocationCity': 'Wuppe...
# 1    {'branches': ['Technologie'], 'companyLocation...
# 2    {'branches': ['Technologie'], 'companyLocation...
# 3    {'branches': ['Technologie'], 'companyLocation...
# 4    {'branches': ['Technologie', 'Unternehmensdien...
# ..                                                 ...
# 254  {'branches': ['Technologie', 'Immobilien', 'Me...
# 255  {'branches': ['Investor (Eigenkapital)', 'Unte...
# 256  {'branches': ['Gesundheitswesen'], 'companyLoc...
# 257  {'branches': ['Technologie', 'Automobilindustr...
# 258  {'branches': ['Unternehmensdienstleistungen'],...
#
# [259 rows x 3 columns]

# %%
## to json

final_path = Path(PATH_TEST_COLLECTION_DATA) / "pooling_results_final.json"

unique_docs_df.to_json(
    final_path,
    orient="records",
    force_ascii=False,
    indent=2
)
